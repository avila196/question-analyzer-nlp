# %% [markdown]
# ## Logistic Regression using Stopwords - Stack Overflow
# The present model builds on top of the Logistic Regression presented in NLP Course offered by DeepLearning.ai in Coursera.
# It creates a model of logistic regression using stopwords and NLTK module

# %% [markdown]
# ## Import functions and data

# %%
# run this cell to import nltk
import csv
import re
from os import getcwd
import nltk                                # Python library for NLP
from nltk.corpus import twitter_samples    # sample Twitter dataset from NLTK
import matplotlib.pyplot as plt            # library for visualization
import random                              # pseudo-random number generator

# %% [markdown]
# ### Imported functions
#
# Download the data needed for this assignment. Check out the [documentation for the twitter_samples dataset](http://www.nltk.org/howto/twitter.html).
#
# * twitter_samples: if you're running this notebook on your local computer, you will need to download it using:
# ```Python
# nltk.download('twitter_samples')
# ```
#
# * stopwords: if you're running this notebook on your local computer, you will need to download it using:
# ```python
# nltk.download('stopwords')
# ```
#
# #### Import some helper functions that we provided in the utils.py file:
# * `process_tweet()`: cleans the text, tokenizes it into separate words, removes stopwords, and converts words to stems.
# * `build_freqs()`: this counts how often a word in the 'corpus' (the entire set of tweets) was associated with a positive label '1' or a negative label '0', then builds the `freqs` dictionary, where each key is a (word,label) tuple, and the value is the count of its frequency within the corpus of tweets.

# %%
# add folder, tmp2, from our local workspace containing pre-downloaded corpora files to nltk's data path
# this enables importing of these files without downloading it again when we refresh our workspace
filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
import numpy as np
import pandas as pd
from nltk.corpus import twitter_samples 
from utils import process_tweet, build_freqs, iterate_file

# %% [markdown]
# ### Prepare the data
# * The `twitter_samples` contains subsets of 5,000 positive tweets, 5,000 negative tweets, and the full set of 10,000 tweets.
#     * If you used all three datasets, we would introduce duplicates of the positive tweets and negative tweets.
#     * You will select just the five thousand positive tweets and five thousand negative tweets.

# %%
# select the set of positive and negative tweets
# nltk.download('twitter_samples')
# all_positive_tweets = twitter_samples.strings('positive_tweets.json')
# all_negative_tweets = twitter_samples.strings('negative_tweets.json')
# print(all_positive_tweets[0:20])

# %%
#Iterator for given file
def iterate_file(file_path):
    with open(file_path, "r", encoding = 'utf8') as f:
        reader = csv.DictReader(f, delimiter=",")
        for row in reader:
            yield row

#Clean sentence (remove non alpha chars)
def cleanSentence(sentence):
    p = re.compile(r'<.*?>')
    sentence = p.sub('', sentence) 
    sentence = ''.join([i.lower() if i.isalpha() else " " if (i==" " or i=="-" or i=="_") else "" for i in sentence])
    return sentence
            
def load_questions(file_path, n=float("inf")):
    positive_questions = []
    negative_questions = []
    cont = 0
    for row in iterate_file(file_path):
        cont += 1 
        if cont %100000==0:
            print("idx:",cont)
        sentence = cleanSentence(row["title"])+cleanSentence(row["body"])+cleanSentence("".join(row["tags"].split("|")))
        words = sentence.split(" ")
        if float(row["stars"])>= 3.0:
            positive_questions.append(sentence)
        else:
            negative_questions.append(sentence)
        if cont==n:
            break
    
    return positive_questions, negative_questions

train_pos, train_neg = load_questions("data_stackoverflow_train.csv", 90000)
test_pos, test_neg = load_questions("data_stackoverflow_test.csv", 5000)

print(train_pos[0:20])
print("positive questions:", len(train_pos))
print("negative questions:", len(train_neg))
# Out:
# ['stop firefox rendering inline colours in rgb formpim trying to write a javascript tool to work on items of a certain colour  on a test page i set the colour using an inline style to mimic the target pages but when the page is rendered the colour is specified using the css rgb functionppthe html tries to emulate the gmail container i want to change the background colour on  when i inspect the element in firebug the colour is displayed as rgbpprecodeltdiv stylewidth  height px border px solid black     background e none repeat scroll  gt    ltdivgtcodeprephow can i stop the colour being converted from codeecode to codergb  codepcss', 'javascript ie change input typepthe following javascript snippet will change the type of an input for instance from text to password its being used to allow users to display their password on screen when typing it inpprecodedocumentsave formpassword confirmtype textdocumentsave formpassword confirmtype passwordcodeprepthis works great in ffchrome but in ie im getting a this command is not supported error message pjavascripthtmlinternet explorer', 'installing sql server and net framework from a visual studio setup projectpi have to do  four things install net framework  install sql server  and run my sql script on the server and create the database and install my application how to do it in a single setup project using visual studio  pcnetsetup deployment', 'how do i grep recursivelyphow do i recursively codegrepcode all directories and subdirectoriespprecodefind   xargs grep texthere codeprelinuxunixgrep', 'getting a user country name from originating ip address with ruby on railspi want to extract a user country name from visitors ip addressesppi could get the ip address with coderemote ipcode but what could bethe easiest way to get the country nameppit doesnt have to be super accurate any ruby library gem or plugin to do thisppi want an simple and easy solution for thispruby on railsip geolocation', 'how do i use su to execute the rest of the bash script as that userpive written a script that takes as an argument a string that is a concatenation of a username and a project the script is supposed to switch su to the username cd to a specific directory based upon the project stringppi basically want to dopprecodesu username  cd homeusernameproject  svn update  codeprepthe problem is that once i do an su it just waits there which makes sense since the flow of execution has passed to switching to the user once i exit then the rest of the things execute but it doesnt work as desiredppi prepended su to the svn command but the command failed ie it didnt update svn in the directory desiredpphow do i write a script that allows the user to switch user and invoke svn among other thingspbashpermissionssudouser permissionssu', 'how to process formula by prologpifpprecodeabcabcabccodeprepthenpprecodeabccodeprepive known the result is but how to calculate it by prologppi tried this but failedpprecode    abcabcabcerror unhandled exception  arguments are not sufficiently instantiatedcodepreprologformula', 'how to create an immutable mapset from a seqpi am try to construct immutable setsmaps from a seq  i am currently doing the followingpprecodeval input seqstring object  mapstring object  inputcodeprepand for setspprecodeval input seqstring  setstring  inputcodeprepwhich seems a little convoluted is there a better waypscalaimmutability', 'rails action caching with querystring parametersphow can i cache my rest controller with rails where my actions have query string parameterspprecodeexample get productsallxmlmax pricecodeprepthxpruby on railscachingcontroller', 'do message queues provide transactional supportpsay i load messages in a queue from multiple nodesppthen one or many nodes are pulling messages from the queueppis it possible or is this normal usage that the queue guarantees to not hand out a message to more than one servernodeppand does that servernode have to tell the queue it has completed the opera ...
# positive tweets: 40364
# negative tweets: 49636

# %% [markdown]
# * Train test split: 20% will be in the test set, and 80% in the training set.

# %%
# split the data into two pieces, one for training and one for testing (validation set) 
# test_pos = all_positive_tweets[10000:]
# train_pos = all_positive_tweets[:10000]
# test_neg = all_negative_tweets[10000:]
# train_neg = all_negative_tweets[:10000]


train_x = train_pos + train_neg 
test_x = test_pos + test_neg

# %% [markdown]
# * Create the numpy array of positive labels and negative labels.

# %%
# combine positive and negative labels
train_y = np.append(np.ones((len(train_pos), 1)), np.zeros((len(train_neg), 1)), axis=0)
test_y = np.append(np.ones((len(test_pos), 1)), np.zeros((len(test_neg), 1)), axis=0)

# %%
# Print the shape train and test sets
print("train_y.shape = " + str(train_y.shape))
print("test_y.shape = " + str(test_y.shape))
print(train_y[:5])
# Out:
# train_y.shape = (90000, 1)
# test_y.shape = (5000, 1)
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]]

# %% [markdown]
# * Create the frequency dictionary using the imported `build_freqs()` function.
#     * We highly recommend that you open `utils.py` and read the `build_freqs()` function to understand what it is doing.
#     * To view the file directory, go to the menu and click File->Open.
#
# ```Python
#     for y,tweet in zip(ys, tweets):
#         for word in process_tweet(tweet):
#             pair = (word, y)
#             if pair in freqs:
#                 freqs[pair] += 1
#             else:
#                 freqs[pair] = 1
# ```
# * Notice how the outer for loop goes through each tweet, and the inner for loop steps through each word in a tweet.
# * The `freqs` dictionary is the frequency dictionary that's being built.
# * The key is the tuple (word, label), such as ("happy",1) or ("happy",0).  The value stored for each key is the count of how many times the word "happy" was associated with a positive label, or how many times "happy" was associated with a negative label.

# %%
# create frequency dictionary
nltk.download('stopwords')
freqs = build_freqs(train_x, train_y)

# check the output
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Bull\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# type(freqs) = <class 'dict'>
# len(freqs) = 1013951

# %% [markdown]
# #### Expected output
# ```
# type(freqs) = <class 'dict'>
# len(freqs) = 11346
# ```

# %% [markdown]
# ### Process tweet
# The given function `process_tweet()` tokenizes the tweet into individual words, removes stop words and applies stemming.

# %%
print("data values:")
print(freqs[('java', 1.0)])
print(freqs[('java', 0.0)])
# test the function below
print('This is an example of a positive tweet: \n', train_x[0])
print('\nThis is an example of the processed version of the tweet: \n', process_tweet(train_x[0]))
# Out:
# data values:
# 4221
# 3358
# This is an example of a positive tweet:
#  stop firefox rendering inline colours in rgb formpim trying to write a javascript tool to work on items of a certain colour  on a test page i set the colour using an inline style to mimic the target pages but when the page is rendered the colour is specified using the css rgb functionppthe html tries to emulate the gmail container i want to change the background colour on  when i inspect the element in firebug the colour is displayed as rgbpprecodeltdiv stylewidth  height px border px solid black     background e none repeat scroll  gt    ltdivgtcodeprephow can i stop the colour being converted from codeecode to codergb  codepcss
#
# This is an example of the processed version of the tweet:
#  ['stop', 'firefox', 'render', 'inlin', 'colour', 'rgb', 'formpim', 'tri', 'write', 'javascript', 'tool', 'work', 'item', 'certain', 'colour', 'test', 'page', 'set', 'colour', 'use', 'inlin', 'style', 'mimic', 'target', 'page', 'page', 'render', 'colour', 'specifi', 'use', 'css', 'rgb', 'functionppth', 'html', 'tri', 'emul', 'gmail', 'contain', 'want', 'chang', 'background', 'colour', 'inspect', 'element', 'firebug', 'colour', 'display', 'rgbpprecodeltdiv', 'stylewidth', 'height', 'px', 'border', 'px', 'solid', 'black', 'background', 'e', 'none', 'repeat', 'scroll', 'gt', 'ltdivgtcodeprephow', 'stop', 'colour', 'convert', 'codeecod', 'codergb', 'codepcss']

# %%
# freqs0 = freqs.copy()
# freqs = freqs0

# %%
# Get highest value and normalize everything
max_val = 0
max_key = "key"
for key,val in freqs.items():
    if val > max_val:
        max_val = val
        max_key = key

print("max key,val:", max_key, max_val)

for key,val in freqs.items():
    freqs[key] = val/max_val
# Out:
# max key,val: ('use', 0.0) 43.153

# %%
print("data values:")
print(freqs[('java', 1.0)])
print(freqs[('java', 0.0)])
# test the function below
print('This is an example of a positive tweet: \n', train_x[0])
print('\nThis is an example of the processed version of the tweet: \n', process_tweet(train_x[0]))
# Out:
# data values:
# 0.09781475216091581
# 0.07781614256251014
# This is an example of a positive tweet:
#  stop firefox rendering inline colours in rgb formpim trying to write a javascript tool to work on items of a certain colour  on a test page i set the colour using an inline style to mimic the target pages but when the page is rendered the colour is specified using the css rgb functionppthe html tries to emulate the gmail container i want to change the background colour on  when i inspect the element in firebug the colour is displayed as rgbpprecodeltdiv stylewidth  height px border px solid black     background e none repeat scroll  gt    ltdivgtcodeprephow can i stop the colour being converted from codeecode to codergb  codepcss
#
# This is an example of the processed version of the tweet:
#  ['stop', 'firefox', 'render', 'inlin', 'colour', 'rgb', 'formpim', 'tri', 'write', 'javascript', 'tool', 'work', 'item', 'certain', 'colour', 'test', 'page', 'set', 'colour', 'use', 'inlin', 'style', 'mimic', 'target', 'page', 'page', 'render', 'colour', 'specifi', 'use', 'css', 'rgb', 'functionppth', 'html', 'tri', 'emul', 'gmail', 'contain', 'want', 'chang', 'background', 'colour', 'inspect', 'element', 'firebug', 'colour', 'display', 'rgbpprecodeltdiv', 'stylewidth', 'height', 'px', 'border', 'px', 'solid', 'black', 'background', 'e', 'none', 'repeat', 'scroll', 'gt', 'ltdivgtcodeprephow', 'stop', 'colour', 'convert', 'codeecod', 'codergb', 'codepcss']

# %% [markdown]
# #### Expected output
# ```
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processes version:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ```

# %% [markdown]
# # Part 1: Logistic regression
#
#
# ### Part 1.1: Sigmoid
# You will learn to use logistic regression for text classification.
# * The sigmoid function is defined as:
#
# $$ h(z) = \frac{1}{1+\exp^{-z}} \tag{1}$$
#
# It maps the input 'z' to a value that ranges between 0 and 1, and so it can be treated as a probability.
#
# <div style="width:image width px; font-size:100%; text-align:center;"><img src='../tmp2/sigmoid_plot.jpg' alt="alternate text" width="width" height="height" style="width:300px;height:200px;" /> Figure 1 </div>

# %% [markdown]
# #### Instructions: Implement the sigmoid function
# * You will want this function to work if z is a scalar as well as if it is an array.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li><a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.exp.html" > numpy.exp </a> </li>
#
# </ul>
# </p>

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def sigmoid(z): 
    '''
    Input:
        z: is the input (can be a scalar or an array)
    Output:
        h: the sigmoid of z
    '''
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # calculate the sigmoid of z
    h = 1.0/(1+np.exp(-z))
    ### END CODE HERE ###
    
    return h

# %%
# Testing your function 
if (sigmoid(0) == 0.5):
    print('SUCCESS!')
else:
    print('Oops!')

if (sigmoid(4.92) == 0.9927537604041685):
    print('CORRECT!')
else:
    print('Oops again!')
# Out:
# SUCCESS!
# CORRECT!

# %% [markdown]
# ### Logistic regression: regression and a sigmoid
#
# Logistic regression takes a regular linear regression, and applies a sigmoid to the output of the linear regression.
#
# Regression:
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# Note that the $\theta$ values are "weights". If you took the Deep Learning Specialization, we referred to the weights with the `w` vector.  In this course, we're using a different variable $\theta$ to refer to the weights.
#
# Logistic regression
# $$ h(z) = \frac{1}{1+\exp^{-z}}$$
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# We will refer to 'z' as the 'logits'.

# %% [markdown]
# ### Part 1.2 Cost function and Gradient
#
# The cost function used for logistic regression is the average of the log loss across all training examples:
#
# $$J(\theta) = -\frac{1}{m} \sum_{i=1}^m y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)}))\tag{5} $$
# * $m$ is the number of training examples
# * $y^{(i)}$ is the actual label of the i-th training example.
# * $h(z(\theta)^{(i)})$ is the model's prediction for the i-th training example.
#
# The loss function for a single training example is
# $$ Loss = -1 \times \left( y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)})) \right)$$
#
# * All the $h$ values are between 0 and 1, so the logs will be negative. That is the reason for the factor of -1 applied to the sum of the two loss terms.
# * Note that when the model predicts 1 ($h(z(\theta)) = 1$) and the label $y$ is also 1, the loss for that training example is 0.
# * Similarly, when the model predicts 0 ($h(z(\theta)) = 0$) and the actual label is also 0, the loss for that training example is 0.
# * However, when the model prediction is close to 1 ($h(z(\theta)) = 0.9999$) and the label is 0, the second term of the log loss becomes a large negative number, which is then multiplied by the overall factor of -1 to convert it to a positive loss value. $-1 \times (1 - 0) \times log(1 - 0.9999) \approx 9.2$ The closer the model prediction gets to 1, the larger the loss.

# %%
# verify that when the model predicts close to 1, but the actual label is 0, the loss is a large positive value
-1 * (1 - 0) * np.log(1 - 0.9999) # loss is about 9.2
# Out:
# 9.210340371976294

# %% [markdown]
# * Likewise, if the model predicts close to 0 ($h(z) = 0.0001$) but the actual label is 1, the first term in the loss function becomes a large number: $-1 \times log(0.0001) \approx 9.2$.  The closer the prediction is to zero, the larger the loss.

# %%
# verify that when the model predicts close to 0 but the actual label is 1, the loss is a large positive value
-1 * np.log(0.0001) # loss is about 9.2
# Out:
# 9.210340371976182

# %% [markdown]
# #### Update the weights
#
# To update your weight vector $\theta$, you will apply gradient descent to iteratively improve your model's predictions.
# The gradient of the cost function $J$ with respect to one of the weights $\theta_j$ is:
#
# $$\nabla_{\theta_j}J(\theta) = \frac{1}{m} \sum_{i=1}^m(h^{(i)}-y^{(i)})x_j \tag{5}$$
# * 'i' is the index across all 'm' training examples.
# * 'j' is the index of the weight $\theta_j$, so $x_j$ is the feature associated with weight $\theta_j$
#
# * To update the weight $\theta_j$, we adjust it by subtracting a fraction of the gradient determined by $\alpha$:
# $$\theta_j = \theta_j - \alpha \times \nabla_{\theta_j}J(\theta) $$
# * The learning rate $\alpha$ is a value that we choose to control how big a single update will be.

# %% [markdown]
# ## Instructions: Implement gradient descent function
# * The number of iterations `num_iters` is the number of times that you'll use the entire training set.
# * For each iteration, you'll calculate the cost function using all training examples (there are `m` training examples), and for all features.
# * Instead of updating a single weight $\theta_i$ at a time, we can update all the weights in the column vector:
# $$\mathbf{\theta} = \begin{pmatrix}
# \theta_0
# \\
# \theta_1
# \\
# \theta_2
# \\
# \vdots
# \\
# \theta_n
# \end{pmatrix}$$
# * $\mathbf{\theta}$ has dimensions (n+1, 1), where 'n' is the number of features, and there is one more element for the bias term $\theta_0$ (note that the corresponding feature value $\mathbf{x_0}$ is 1).
# * The 'logits', 'z', are calculated by multiplying the feature matrix 'x' with the weight vector 'theta'.  $z = \mathbf{x}\mathbf{\theta}$
#     * $\mathbf{x}$ has dimensions (m, n+1)
#     * $\mathbf{\theta}$: has dimensions (n+1, 1)
#     * $\mathbf{z}$: has dimensions (m, 1)
# * The prediction 'h', is calculated by applying the sigmoid to each element in 'z': $h(z) = sigmoid(z)$, and has dimensions (m,1).
# * The cost function $J$ is calculated by taking the dot product of the vectors 'y' and 'log(h)'.  Since both 'y' and 'h' are column vectors (m,1), transpose the vector to the left, so that matrix multiplication of a row vector with column vector performs the dot product.
# $$J = \frac{-1}{m} \times \left(\mathbf{y}^T \cdot log(\mathbf{h}) + \mathbf{(1-y)}^T \cdot log(\mathbf{1-h}) \right)$$
# * The update of theta is also vectorized.  Because the dimensions of $\mathbf{x}$ are (m, n+1), and both $\mathbf{h}$ and $\mathbf{y}$ are (m, 1), we need to transpose the $\mathbf{x}$ and place it on the left in order to perform matrix multiplication, which then yields the (n+1, 1) answer we need:
# $$\mathbf{\theta} = \mathbf{\theta} - \frac{\alpha}{m} \times \left( \mathbf{x}^T \cdot \left( \mathbf{h-y} \right) \right)$$

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>use np.dot for matrix multiplication.</li>
#     <li>To ensure that the fraction -1/m is a decimal value, cast either the numerator or denominator (or both), like `float(1)`, or write `1.` for the float version of 1. </li>
# </ul>
# </p>

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def minibatch_gradientDescent(x, y, theta, alpha, num_iters, batch_size):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector
    Hint: you might want to print the cost to make sure that it is going down.
    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # get 'm', the number of rows in matrix x
    m = x.shape[0]
    
    for i in range(0, num_iters):
        
        for j in range(0, m, batch_size):

            # get z, the dot product of x and theta
            xj = x[j:j+batch_size,:]
            yj = y[j:j+batch_size,:]
            z = np.dot(xj ,theta)
            #mx1

            # get the sigmoid of z
            h = sigmoid(z)
            #mx1

            #print("shape z", z.shape)
            #print("shape h", h.shape)


            # calculate the cost function
            J = (-1/batch_size)*( np.dot(yj.T,np.log(h)) + np.dot((1-yj).T,np.log(1-h)) )
                


            # update the weights theta
            theta = theta - (alpha/batch_size)*np.dot(xj.T,h-yj)
    
        print(i,":", J)
        
    ### END CODE HERE ###
    J = float(J)
    return J, theta

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def gradientDescent(x, y, theta, alpha, num_iters):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector
    Hint: you might want to print the cost to make sure that it is going down.
    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # get 'm', the number of rows in matrix x
    m = x.shape[0]
    
    for i in range(0, num_iters):
        
        # get z, the dot product of x and theta
        z = np.dot(x,theta)
        #mx1
        
        # get the sigmoid of z
        h = sigmoid(z)
        #mx1
        
        #print("shape z", z.shape)
        #print("shape h", h.shape)
        
        
        # calculate the cost function
        J = (-1/m)*( np.dot(y.T,np.log(h)) + np.dot((1-y).T,np.log(1-h)) )
        if i%100==0:
            print(i,":", J)
            

        # update the weights theta
        theta = theta - (alpha/m)*np.dot(x.T,h-y)
        
    ### END CODE HERE ###
    J = float(J)
    return J, theta

# %%
# Check the function
# Construct a synthetic test case using numpy PRNG functions
np.random.seed(1)
# X input is 10 x 3 with ones for the bias terms
tmp_X = np.append(np.ones((10, 1)), np.random.rand(10, 2) * 2000, axis=1)
# Y Labels are 10 x 1
tmp_Y = (np.random.rand(10, 1) > 0.35).astype(float)

# Apply gradient descent
tmp_J, tmp_theta = gradientDescent(tmp_X, tmp_Y, np.zeros((3, 1)), 1e-8, 700)
print(f"The cost after training is {tmp_J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(tmp_theta)]}")
# Out:
# 0 : [[0.69314718]]
# 100 : [[0.68600073]]
# 200 : [[0.68163567]]
# 300 : [[0.67862941]]
# 400 : [[0.67630475]]
# 500 : [[0.67433793]]
# 600 : [[0.67257295]]
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]

# %% [markdown]
# #### Expected output
# ```
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]
# ```

# %% [markdown]
# ## Part 2: Extracting the features
#
# * Given a list of tweets, extract the features and store them in a matrix. You will extract two features.
#     * The first feature is the number of positive words in a tweet.
#     * The second feature is the number of negative words in a tweet.
# * Then train your logistic regression classifier on these features.
# * Test the classifier on a validation set.
#
# ### Instructions: Implement the extract_features function.
# * This function takes in a single tweet.
# * Process the tweet using the imported `process_tweet()` function and save the list of tweet words.
# * Loop through each word in the list of processed words
#     * For each word, check the `freqs` dictionary for the count when that word has a positive '1' label. (Check for the key (word, 1.0)
#     * Do the same for the count for when the word is associated with the negative label '0'. (Check for the key (word, 0.0).)

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Make sure you handle cases when the (word, label) key is not found in the dictionary. </li>
#     <li> Search the web for hints about using the `.get()` method of a Python dictionary.  Here is an <a href="https://www.programiz.com/python-programming/methods/dictionary/get" > example </a> </li>
# </ul>
# </p>

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)

def extract_features(tweet, freqs):
    '''
    Input: 
        tweet: a list of words for one tweet
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    Output: 
        x: a feature vector of dimension (1,3)
    '''
    # process_tweet tokenizes, stems, and removes stopwords
    word_l = process_tweet(tweet)
            #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#     word_l = tweet.split()
    
    # 3 elements in the form of a 1 x 3 vector
    x = np.zeros((1, 3)) 
    
    #bias term is set to 1
    x[0,0] = 1 
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # loop through each word in the list of words
    for word in word_l:
        
        # increment the word count for the positive label 1
        x[0,1] += freqs.get((word, 1.0),0)
        
        # increment the word count for the negative label 0
        x[0,2] += freqs.get((word, 0.0),0)
        
    ### END CODE HERE ###
    assert(x.shape == (1, 3))
    return x

# %%
# Check your function

# test 1
# test on training data
tmp1 = extract_features(train_x[0], freqs)
print(tmp1)
# Out:
# [[1.         6.0035687  7.77786017]]

# %% [markdown]
# #### Expected output
# ```
# [[1.00e+00 3.02e+03 6.10e+01]]
# ```

# %%
# test 2:
# check for when the words are not in the freqs dictionary
tmp2 = extract_features('blorb bleeeeb bloooob', freqs)
print(tmp2)
# Out:
# [[1. 0. 0.]]

# %% [markdown]
# #### Expected output
# ```
# [[1. 0. 0.]]
# ```

# %% [markdown]
# ## Part 3: Training Your Model
#
# To train the model:
# * Stack the features for all training examples into a matrix `X`.
# * Call `gradientDescent`, which you've implemented above.
#
# This section is given to you.  Please read it for understanding and run the cell.

# %%
# collect the features 'x' and stack them into a matrix 'X'
X = np.zeros((len(train_x), 3))
print("extract_features:",train_x[0], extract_features(train_x[0], freqs) )
for i in range(len(train_x)):
    X[i, :]= extract_features(train_x[i], freqs)
#     if i%1000000==0:
#         print("extracting features:", i)
Y = train_y
# Out:
# extract_features: stop firefox rendering inline colours in rgb formpim trying to write a javascript tool to work on items of a certain colour  on a test page i set the colour using an inline style to mimic the target pages but when the page is rendered the colour is specified using the css rgb functionppthe html tries to emulate the gmail container i want to change the background colour on  when i inspect the element in firebug the colour is displayed as rgbpprecodeltdiv stylewidth  height px border px solid black     background e none repeat scroll  gt    ltdivgtcodeprephow can i stop the colour being converted from codeecode to codergb  codepcss [[1.         6.0035687  7.77786017]]

# %%
# training labels corresponding to X


# Apply gradient descent
from sklearn.utils import shuffle
Xs, Ys = shuffle(X, Y, random_state=0)

# J, theta = minibatch_gradientDescent(Xs, Ys, np.zeros((3, 1)), 1E-4, 1000, 5000)
J, theta = gradientDescent(Xs, Ys, np.zeros((3, 1)), 3E-3, 20000)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# 0 : [[0.69314718]]
# 100 : [[0.68969543]]
# 200 : [[0.68926565]]
# 300 : [[0.68884956]]
# 400 : [[0.68844679]]
# 500 : [[0.68805689]]
# 600 : [[0.68767934]]
# 700 : [[0.6873136]]
# 800 : [[0.68695912]]
# 900 : [[0.68661539]]
# 1000 : [[0.68628192]]
# 1100 : [[0.68595831]]
# 1200 : [[0.68564414]]
# 1300 : [[0.68533908]]
# 1400 : [[0.68504277]]
# 1500 : [[0.68475492]]
# 1600 : [[0.68447521]]
# 1700 : [[0.68420337]]
# 1800 : [[0.68393913]]
# 1900 : [[0.68368221]]
# 2000 : [[0.68343238]]
# 2100 : [[0.68318938]]
# 2200 : [[0.68295297]]
# 2300 : [[0.68272295]]
# 2400 : [[0.68249907]]
# 2500 : [[0.68228115]]
# 2600 : [[0.68206897]]
# 2700 : [[0.68186234]]
# 2800 : [[0.68166108]]
# 2900 : [[0.68146502]]
# 3000 : [[0.68127397]]
# 3100 : [[0.68108779]]
# 3200 : [[0.6809063]]
# 3300 : [[0.68072938]]
# 3400 : [[0.68055686]]
# 3500 : [[0.68038861]]
# 3600 : [[0.6802245]]
# 3700 : [[0.68006441]]
# 3800 : [[0.6799082]]
# 3900 : [[0.67975577]]
# 4000 : [[0.679607]]
# 4100 : [[0.67946179]]
# 4200 : [[0.67932002]]
# 4300 : [[0.6791816]]
# 4400 : [[0.67904643]]
# 4500 : [[0.67891441]]
# 4600 : [[0.67878547]]
# 4700 : [[0.67865951]]
# 4800 : [[0.67853644]]
# 4900 : [[0.67841619]]
# 5000 : [[0.67829868]]
# 5100 : [[0.67818384]]
# 5200 : [[0.67807158]]
# 5300 : [[0.67796185]]
# 5400 : [[0.67785457]]
# 5500 : [[0.67774968]]
# 5600 : [[0.67764712]]
# 5700 : [[0.67754682]]
# 5800 : [[0.67744872]]
# 5900 : [[0.67735277]]
# 6000 : [[0.67725892]]
# 6100 : [[0.6771671]]
# 6200 : [[0.67707727]]
# 6300 : [[0.67698937]]
# 6400 : [[0.67690336]]
# 6500 : [[0.67681919]]
# 6600 : [[0.67673681]]
# 6700 : [[0.67665618]]
# 6800 : [[0.67657725]]
# 6900 : [[0.6765]]
# 7000 : [[0.67642436]]
# 7100 : [[0.67635031]]
# 7200 : [[0.6762778]]
# 7300 : [[0.6762068]]
# 7400 : [[0.67613728]]
# 7500 : [[0.67606919]]
# 7600 : [[0.6760025]]
# 7700 : [[0.67593719]]
# 7800 : [[0.67587321]]
# 7900 : [[0.67581054]]
# 8000 : [[0.67574914]]
# 8100 : [[0.675689]]
# 8200 : [[0.67563007]]
# 8300 : [[0.67557233]]
# 8400 : [[0.67551575]]
# 8500 : [[0.67546031]]
# 8600 : [[0.67540598]]
# 8700 : [[0.67535274]]
# 8800 : [[0.67530056]]
# 8900 : [[0.67524941]]
# 9000 : [[0.67519928]]
# 9100 : [[0.67515015]]
# 9200 : [[0.67510198]]
# 9300 : [[0.67505476]]
# 9400 : [[0.67500846]]
# 9500 : [[0.67496308]]
# 9600 : [[0.67491858]]
# 9700 : [[0.67487495]]
# 9800 : [[0.67483217]]
# 9900 : [[0.67479023]]
# 10000 : [[0.67474909]]
# 10100 : [[0.67470875]]
# 10200 : [[0.67466919]]
# 10300 : [[0.67463039]]
# 10400 : [[0.67459234]]
# 10500 : [[0.67455502]]
# 10600 : [[0.67451841]]
# 10700 : [[0.6744825]]
# 10800 : [[0.67444728]]
# 10900 : [[0.67441273]]
# 11000 : [[0.67437884]]
# 11100 : [[0.67434558]]
# 11200 : [[0.67431296]]
# 11300 : [[0.67428096]]
# 11400 : [[0.67424956]]
# 11500 : [[0.67421875]]
# 11600 : [[0.67418852]]
# 11700 : [[0.67415886]]
# 11800 : [[0.67412975]]
# 11900 : [[0.67410119]]
# 12000 : [[0.67407316]]
# 12100 : [[0.67404566]]
# 12200 : [[0.67401867]]
# 12300 : [[0.67399218]]
# 12400 : [[0.67396618]]
# 12500 : [[0.67394067]]
# 12600 : [[0.67391562]]
# 12700 : [[0.67389104]]
# 12800 : [[0.67386691]]
# 12900 : [[0.67384323]]
# 13000 : [[0.67381999]]
# 13100 : [[0.67379717]]
# 13200 : [[0.67377477]]
# 13300 : [[0.67375278]]
# 13400 : [[0.67373119]]
# 13500 : [[0.67371]]
# 13600 : [[0.67368919]]
# 13700 : [[0.67366877]]
# 13800 : [[0.67364872]]
# 13900 : [[0.67362903]]
# 14000 : [[0.67360969]]
# 14100 : [[0.67359071]]
# 14200 : [[0.67357208]]
# 14300 : [[0.67355378]]
# 14400 : [[0.67353581]]
# 14500 : [[0.67351816]]
# 14600 : [[0.67350084]]
# 14700 : [[0.67348382]]
# 14800 : [[0.67346711]]
# 14900 : [[0.67345071]]
# 15000 : [[0.67343459]]
# 15100 : [[0.67341877]]
# 15200 : [[0.67340323]]
# 15300 : [[0.67338796]]
# 15400 : [[0.67337297]]
# 15500 : [[0.67335825]]
# 15600 : [[0.67334379]]
# 15700 : [[0.67332959]]
# 15800 : [[0.67331564]]
# 15900 : [[0.67330194]]
# 16000 : [[0.67328848]]
# 16100 : [[0.67327526]]
# 16200 : [[0.67326227]]
# 16300 : [[0.67324952]]
# 16400 : [[0.67323699]]
# 16500 : [[0.67322468]]
# 16600 : [[0.67321259]]
# 16700 : [[0.67320071]]
# 16800 : [[0.67318904]]
# 16900 : [[0.67317758]]
# 17000 : [[0.67316632]]
# 17100 : [[0.67315525]]
# 17200 : [[0.67314439]]
# 17300 : [[0.67313371]]
# 17400 : [[0.67312322]]
# 17500 : [[0.67311291]]
# 17600 : [[0.67310278]]
# 17700 : [[0.67309283]]
# 17800 : [[0.67308305]]
# 17900 : [[0.67307345]]
# 18000 : [[0.67306401]]
# 18100 : [[0.67305474]]
# 18200 : [[0.67304562]]
# 18300 : [[0.67303667]]
# 18400 : [[0.67302787]]
# 18500 : [[0.67301923]]
# 18600 : [[0.67301073]]
# 18700 : [[0.67300238]]
# 18800 : [[0.67299418]]
# 18900 : [[0.67298612]]
# 19000 : [[0.6729782]]
# 19100 : [[0.67297041]]
# 19200 : [[0.67296276]]
# 19300 : [[0.67295524]]
# 19400 : [[0.67294786]]
# 19500 : [[0.6729406]]
# 19600 : [[0.67293346]]
# 19700 : [[0.67292645]]
# 19800 : [[0.67291955]]
# 19900 : [[0.67291278]]
# The cost after training is 0.67290619.
# The resulting vector of weights is [-0.29115149, 0.63252054, -0.50548972]

# %% [markdown]
# **Expected Output**:
#
# ```
# The cost after training is 0.24216529.
# The resulting vector of weights is [7e-08, 0.0005239, -0.00055517]
# ```

# %% [markdown]
# # Part 4: Test your logistic regression
#
# It is time for you to test your logistic regression function on some new input that your model has not seen before.
#
# #### Instructions: Write `predict_tweet`
# Predict whether a tweet is positive or negative.
#
# * Given a tweet, process it, then extract the features.
# * Apply the model's learned weights on the features to get the logits.
# * Apply the sigmoid to the logits to get the prediction (a value between 0 and 1).
#
# $$y_{pred} = sigmoid(\mathbf{x} \cdot \theta)$$

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def predict_tweet(tweet, freqs, theta):
    '''
    Input: 
        tweet: a string
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
        theta: (3,1) vector of weights
    Output: 
        y_pred: the probability of a tweet being positive or negative
    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # extract the features of the tweet and store it into x
    x = extract_features(tweet, freqs)
    
    # make the prediction using x and theta
    y_pred = sigmoid(np.dot(x, theta))
    
    ### END CODE HERE ###
    
    return y_pred

# %%
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    print( '%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))
# Out:
# I am happy -> 0.427927
# I am bad -> 0.428318
# this movie should have been great. -> 0.427671
# great -> 0.428051
# great great -> 0.428380
# great great great -> 0.428709
# great great great great -> 0.429039

# %% [markdown]
# **Expected Output**:
# ```
# I am happy -> 0.518580
# I am bad -> 0.494339
# this movie should have been great. -> 0.515331
# great -> 0.515464
# great great -> 0.530898
# great great great -> 0.546273
# great great great great -> 0.561561
# ```

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'love be in the air tonight'
predict_tweet(my_tweet, freqs, theta)
# Out:
# array([[0.42804029]])

# %% [markdown]
# ## Check performance using the test set
# After training your model using the training set above, check how your model might perform on real, unseen data, by testing it against the test set.
#
# #### Instructions: Implement `test_logistic_regression`
# * Given the test data and the weights of your trained model, calculate the accuracy of your logistic regression model.
# * Use your `predict_tweet()` function to make predictions on each tweet in the test set.
# * If the prediction is > 0.5, set the model's classification `y_hat` to 1, otherwise set the model's classification `y_hat` to 0.
# * A prediction is accurate when `y_hat` equals `test_y`.  Sum up all the instances when they are equal and divide by `m`.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Use np.asarray() to convert a list to a numpy array</li>
#     <li>Use np.squeeze() to make an (m,1) dimensional array into an (m,) array </li>
# </ul>
# </p>

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def test_logistic_regression(test_x, test_y, freqs, theta):
    """
    Input: 
        test_x: a list of tweets
        test_y: (m, 1) vector with the corresponding labels for the list of tweets
        freqs: a dictionary with the frequency of each pair (or tuple)
        theta: weight vector of dimension (3, 1)
    Output: 
        accuracy: (# of tweets classified correctly) / (total # of tweets)
    """
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # the list for storing predictions
    y_hat = []
    
    for tweet in test_x:
        # get the label prediction for the tweet
        y_pred = predict_tweet(tweet, freqs, theta)
        
        if y_pred > 0.5:
            # append 1.0 to the list
            y_hat.append(1.0)
        else:
            # append 0 to the list
            y_hat.append(0.0)

    # With the above implementation, y_hat is a list, but test_y is (m,1) array
    # convert both to one-dimensional arrays in order to compare them using the '==' operator
    accuracy = np.sum(np.array(y_hat)==test_y.reshape(-1))/len(y_hat)

    ### END CODE HERE ###
    
    return accuracy

# %%
tmp_accuracy = test_logistic_regression(test_x, test_y, freqs, theta)
print(f"Logistic regression model's accuracy = {tmp_accuracy:.4f}")
# Out:
# Logistic regression model's accuracy = 0.5864

# %% [markdown]
# #### Expected Output:
# ```0.9950```
# Pretty good!

# %% [markdown]
# # Part 5: Error Analysis
#
# In this part you will see some tweets that your model misclassified. Why do you think the misclassifications happened? Specifically what kind of tweets does your model misclassify?

# %%
# Some error analysis done for you
print('Label Predicted Tweet')
for x,y in zip(test_x,test_y):
    y_hat = predict_tweet(x, freqs, theta)

    if np.abs(y - (y_hat > 0.5)) > 0:
        print('THE TWEET IS:', x)
        print('THE PROCESSED TWEET IS:', process_tweet(x))
        print('%d\t%0.8f\t%s' % (y, y_hat, ' '.join(process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# C:\Users\Bull\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: overflow encountered in exp
#   if sys.path[0] == '':
# Label Predicted Tweet
# THE TWEET IS: get pixels and colours from nsimage
# THE PROCESSED TWEET IS: ['get', 'pixel', 'colour', 'nsimag']
# 1	0.00000000	b'get pixel colour nsimag'
# THE TWEET IS: how can i list all deployed jax ws webservices
# THE PROCESSED TWEET IS: ['list', 'deploy', 'jax', 'ws', 'webservic']
# 1	0.00000000	b'list deploy jax ws webservic'
# THE TWEET IS: google app engine jsonpickle
# THE PROCESSED TWEET IS: ['googl', 'app', 'engin', 'jsonpickl']
# 1	0.00000000	b'googl app engin jsonpickl'
# THE TWEET IS: flash lite   javascript
# THE PROCESSED TWEET IS: ['flash', 'lite', 'javascript']
# 1	0.00000000	b'flash lite javascript'
# THE TWEET IS: from html to servlet
# THE PROCESSED TWEET IS: ['html', 'servlet']
# 1	0.00000000	b'html servlet'
# THE TWEET IS: htaccess redirect all files in one folder to exact same in another folder
# THE PROCESSED TWEET IS: ['htaccess', 'redirect', 'file', 'one', 'folder', 'exact', 'anoth', 'folder']
# 1	0.00000000	b'htaccess redirect file one folder exact anoth folder'
# THE TWEET IS: android how to stop reading getview function again if the content is already downloaded in the listview
# THE PROCESSED TWEET IS: ['android', 'stop', 'read', 'getview', 'function', 'content', 'alreadi', 'download', 'listview']
# 1	0.00000000	b'android stop read getview function content alreadi download listview'
# THE TWEET IS: qt application simulating modal behaviour enabledisable user input
# THE PROCESSED TWEET IS: ['qt', 'applic', 'simul', 'modal', 'behaviour', 'enabledis', 'user', 'input']
# 1	0.00000000	b'qt applic simul modal behaviour enabledis user input'
# THE TWEET IS: sending an sms message with aspnet
# THE PROCESSED TWEET IS: ['send', 'sm', 'messag', 'aspnet']
# 1	0.00000000	b'send sm messag aspnet'
# THE TWEET IS: how to create class instance inside that class method
# THE PROCESSED TWEET IS: ['creat', 'class', 'instanc', 'insid', 'class', 'method']
# 1	0.00000000	b'creat class instanc insid class method'
# THE TWEET IS: mvc model get and set vs straight up model var  val
# THE PROCESSED TWEET IS: ['mvc', 'model', 'get', 'set', 'vs', 'straight', 'model', 'var', 'val']
# 1	0.00000000	b'mvc model get set vs straight model var val'
# THE TWEET IS: how to filter rows with null refrences in google app engine db
# THE PROCESSED TWEET IS: ['filter', 'row', 'null', 'refrenc', 'googl', 'app', 'engin', 'db']
# 1	0.00000000	b'filter row null refrenc googl app engin db'
# THE TWEET IS: cant resolve tree conflict with svn
# THE PROCESSED TWEET IS: ['cant', 'resolv', 'tree', 'conflict', 'svn']
# 1	0.00000000	b'cant resolv tree conflict svn'
# THE TWEET IS: db cant connect from clients after restart
# THE PROCESSED TWEET IS: ['db', 'cant', 'connect', 'client', 'restart']
# 1	0.00000000	b'db cant connect client restart'
# THE TWEET IS: java miglayout how to use hidemode
# THE PROCESSED TWEET IS: ['java', 'miglayout', 'use', 'hidemod']
# 1	0.00000000	b'java miglayout use hidemod'
# THE TWEET IS: mysql update  select query
# THE PROCESSED TWEET IS: ['mysql', 'updat', 'select', 'queri']
# 1	0.00000000	b'mysql updat select queri'
# THE TWEET IS: git do i need to commit my branch before checking out another branch what about stashing
# THE PROCESSED TWEET IS: ['git', 'need', 'commit', 'branch', 'check', 'anoth', 'branch', 'stash']
# 1	0.00000000	b'git need commit branch check anoth branch stash'
# THE TWEET IS: iis ftp  extensibility iftplogprovider and logging ftp failures to the event log
# THE PROCESSED TWEET IS: ['ii', 'ftp', 'extens', 'iftplogprovid', 'log', 'ftp', 'failur', 'event', 'log']
# 1	0.00000000	b'ii ftp extens iftplogprovid log ftp failur event log'
# THE TWEET IS: wp list categories does not show current category
# THE PROCESSED TWEET IS: ['wp', 'list', 'categori', 'show', 'current', 'categori']
# 1	0.00000000	b'wp list categori show current categori'
# THE TWEET IS: boost shared ptr vs weak ptr which to use when
# THE PROCESSED TWEET IS: ['boost', 'share', 'ptr', 'vs', 'weak', 'ptr', 'use']
# 1	0.00000000	b'boost share ptr vs weak ptr use'
# THE TWEET IS: reporting engine guidance pentaho jasperreports birt
# THE PROCESSED TWEET IS: ['report', 'engin', 'guidanc', 'pentaho', 'jasperreport', 'birt']
# 1	0.00000000	b'report engin guidanc pentaho jasperreport birt'
# THE TWEET IS: alternative to httpcontext when using ninject with a wcf service hosted in was using msmq binding
# THE PROCESSED TWEET IS: ['altern', 'httpcontext', 'use', 'ninject', 'wcf', 'servic', 'host', 'use', 'msmq', 'bind']
# 1	0.00000000	b'altern httpcontext use ninject wcf servic host use msmq bind'
# THE TWEET IS: how to delete mysql database through shell command
# THE PROCESSED TWEET IS: ['delet', 'mysql', 'databas', 'shell', 'command']
# 1	0.00000000	b'delet mysql databas shell command'
# THE TWEET IS: problem with binding dependency property on a usercontrol
# THE PROCESSED TWEET IS: ['problem', 'bind', 'depend', 'properti', 'usercontrol']
# 1	0.00000000	b'problem bind depend properti usercontrol'
# THE TWEET IS: jquerychange firing on page load
# THE PROCESSED TWEET IS: ['jquerychang', 'fire', 'page', 'load']
# 1	0.00000000	b'jquerychang fire page load'
# THE TWEET IS: dynamically expanding the width of a td
# THE PROCESSED TWEET IS: ['dynam', 'expand', 'width', 'td']
# 1	0.00000000	b'dynam expand width td'
# THE TWEET IS: could not find any resources appropriate for the specified culture or the neutral culture
# THE PROCESSED TWEET IS: ['could', 'find', 'resourc', 'appropri', 'specifi', 'cultur', 'neutral', 'cultur']
# 1	0.00000000	b'could find resourc appropri specifi cultur neutral cultur'
# THE TWEET IS: c type parameters specification
# THE PROCESSED TWEET IS: ['c', 'type', 'paramet', 'specif']
# 1	0.00000000	b'c type paramet specif'
# THE TWEET IS: how do i iterate over faces in cgal
# THE PROCESSED TWEET IS: ['iter', 'face', 'cgal']
# 1	0.00054792	b'iter face cgal'
# THE TWEET IS: music recognition and signal processing
# THE PROCESSED TWEET IS: ['music', 'recognit', 'signal', 'process']
# 1	0.00000000	b'music recognit signal process'
# THE TWEET IS: search and delete multiple lines
# THE PROCESSED TWEET IS: ['search', 'delet', 'multipl', 'line']
# 1	0.00000000	b'search delet multipl line'
# THE TWEET IS: java beans annotations what do they do how do they help me
# THE PROCESSED TWEET IS: ['java', 'bean', 'annot', 'help']
# 1	0.00000000	b'java bean annot help'
# THE TWEET IS: silverlight  making content size to page size
# THE PROCESSED TWEET IS: ['silverlight', 'make', 'content', 'size', 'page', 'size']
# 1	0.00000000	b'silverlight make content size page size'
# THE TWEET IS: format as gmtutc time when default timezone is something else
# THE PROCESSED TWEET IS: ['format', 'gmtutc', 'time', 'default', 'timezon', 'someth', 'els']
# 1	0.00000000	b'format gmtutc time default timezon someth els'
# THE TWEET IS: what is the most clever and easy approach to sync data between multiple entities
# THE PROCESSED TWEET IS: ['clever', 'easi', 'approach', 'sync', 'data', 'multipl', 'entiti']
# 1	0.00000000	b'clever easi approach sync data multipl entiti'
# THE TWEET IS: has anyone got experience with riak with a large dataset
# THE PROCESSED TWEET IS: ['anyon', 'got', 'experi', 'riak', 'larg', 'dataset']
# 1	0.00000000	b'anyon got experi riak larg dataset'
# THE TWEET IS: how to show iplmage format on the gui of c instead of showing it in another windows
# THE PROCESSED TWEET IS: ['show', 'iplmag', 'format', 'gui', 'c', 'instead', 'show', 'anoth', 'window']
# 1	0.00000000	b'show iplmag format gui c instead show anoth window'
# THE TWEET IS: deleting specific values from an array in ksh
# THE PROCESSED TWEET IS: ['delet', 'specif', 'valu', 'array', 'ksh']
# 1	0.00000000	b'delet specif valu array ksh'
# THE TWEET IS: what are all of the well known virtual folder guids
# THE PROCESSED TWEET IS: ['well', 'known', 'virtual', 'folder', 'guid']
# 1	0.00000000	b'well known virtual folder guid'
# THE TWEET IS: develop a bootloader in assembly
# THE PROCESSED TWEET IS: ['develop', 'bootload', 'assembl']
# 1	0.00000000	b'develop bootload assembl'
# THE TWEET IS: running all bound instances of a goal on the command line
# THE PROCESSED TWEET IS: ['run', 'bound', 'instanc', 'goal', 'command', 'line']
# 1	0.00000000	b'run bound instanc goal command line'
# THE TWEET IS: appengine mercurial error
# THE PROCESSED TWEET IS: ['appengin', 'mercuri', 'error']
# 1	0.00000000	b'appengin mercuri error'
# THE TWEET IS: how do i initialize an object of a class
# THE PROCESSED TWEET IS: ['initi', 'object', 'class']
# 1	0.00000000	b'initi object class'
# THE TWEET IS: iphone   how set uinavigationbar height
# THE PROCESSED TWEET IS: ['iphon', 'set', 'uinavigationbar', 'height']
# 1	0.00000000	b'iphon set uinavigationbar height'
# THE TWEET IS: use javascript to intercept all document link clicks
# THE PROCESSED TWEET IS: ['use', 'javascript', 'intercept', 'document', 'link', 'click']
# 1	0.00000000	b'use javascript intercept document link click'
# THE TWEET IS: how do i display appsettings in an aspnet mvc web application
# THE PROCESSED TWEET IS: ['display', 'appset', 'aspnet', 'mvc', 'web', 'applic']
# 1	0.00000000	b'display appset aspnet mvc web applic'
# THE TWEET IS: bddtdd mocking data the tricky way
# THE PROCESSED TWEET IS: ['bddtdd', 'mock', 'data', 'tricki', 'way']
# 1	0.00000000	b'bddtdd mock data tricki way'
# THE TWEET IS: is cookie phpsessid the only key to for a  session in php
# THE PROCESSED TWEET IS: ['cooki', 'phpsessid', 'key', 'session', 'php']
# 1	0.00000000	b'cooki phpsessid key session php'
# THE TWEET IS: why is this linq expression not working
# THE PROCESSED TWEET IS: ['linq', 'express', 'work']
# 1	0.00000000	b'linq express work'
# THE TWEET IS: how to sendreceive sms using at commands
# THE PROCESSED TWEET IS: ['sendrec', 'sm', 'use', 'command']
# 1	0.00001648	b'sendrec sm use command'
# THE TWEET IS: having both mousedownmouseup and dblclick in jquery
# THE PROCESSED TWEET IS: ['mousedownmouseup', 'dblclick', 'jqueri']
# 1	0.00117742	b'mousedownmouseup dblclick jqueri'
# THE TWEET IS: abort a thread started with delegatebegininvoke
# THE PROCESSED TWEET IS: ['abort', 'thread', 'start', 'delegatebegininvok']
# 1	0.00000000	b'abort thread start delegatebegininvok'
# THE TWEET IS: when should i use the addsubview method of a view controller
# THE PROCESSED TWEET IS: ['use', 'addsubview', 'method', 'view', 'control']
# 1	0.00000000	b'use addsubview method view control'
# THE TWEET IS: sql server   production db schema vs reporting db schema should they be the same
# THE PROCESSED TWEET IS: ['sql', 'server', 'product', 'db', 'schema', 'vs', 'report', 'db', 'schema']
# 1	0.00000000	b'sql server product db schema vs report db schema'
# THE TWEET IS: is it possible to get the previous day of the week using joda time
# THE PROCESSED TWEET IS: ['possibl', 'get', 'previou', 'day', 'week', 'use', 'joda', 'time']
# 1	0.00000000	b'possibl get previou day week use joda time'
# THE TWEET IS: in android browser link does not always execute onclick causing focus instead
# THE PROCESSED TWEET IS: ['android', 'browser', 'link', 'alway', 'execut', 'onclick', 'caus', 'focu', 'instead']
# 1	0.00000000	b'android browser link alway execut onclick caus focu instead'
# THE TWEET IS: change the volume in systemmediasoundplayer
# THE PROCESSED TWEET IS: ['chang', 'volum', 'systemmediasoundplay']
# 1	0.00000055	b'chang volum systemmediasoundplay'
# THE TWEET IS: sql server  transaction log is always too big
# THE PROCESSED TWEET IS: ['sql', 'server', 'transact', 'log', 'alway', 'big']
# 1	0.00000000	b'sql server transact log alway big'
# THE TWEET IS: soap client for ruby  and rails
# THE PROCESSED TWEET IS: ['soap', 'client', 'rubi', 'rail']
# 1	0.00000000	b'soap client rubi rail'
# THE TWEET IS: how to set the text of a back button on a uinavigationbar
# THE PROCESSED TWEET IS: ['set', 'text', 'back', 'button', 'uinavigationbar']
# 1	0.00000000	b'set text back button uinavigationbar'
# THE TWEET IS: hinputtext which is bound to string property is submitting empty string instead of null
# THE PROCESSED TWEET IS: ['hinputtext', 'bound', 'string', 'properti', 'submit', 'empti', 'string', 'instead', 'null']
# 1	0.00000000	b'hinputtext bound string properti submit empti string instead null'
# THE TWEET IS: ruby on rails   authlogic  periodically check if user session is valid
# THE PROCESSED TWEET IS: ['rubi', 'rail', 'authlog', 'period', 'check', 'user', 'session', 'valid']
# 1	0.00000000	b'rubi rail authlog period check user session valid'
# THE TWEET IS: error in installing windows service developed in net
# THE PROCESSED TWEET IS: ['error', 'instal', 'window', 'servic', 'develop', 'net']
# 1	0.00000000	b'error instal window servic develop net'
# THE TWEET IS: convert gd image back to binary data
# THE PROCESSED TWEET IS: ['convert', 'gd', 'imag', 'back', 'binari', 'data']
# 1	0.00000000	b'convert gd imag back binari data'
# THE TWEET IS: how to create those blackwhite icons used in the status bar
# THE PROCESSED TWEET IS: ['creat', 'blackwhit', 'icon', 'use', 'statu', 'bar']
# 1	0.00000000	b'creat blackwhit icon use statu bar'
# THE TWEET IS: sun studio  c compiler for linux is so slow
# THE PROCESSED TWEET IS: ['sun', 'studio', 'c', 'compil', 'linux', 'slow']
# 1	0.00000000	b'sun studio c compil linux slow'
# THE TWEET IS: js to keep active state of menu in relation to iframe content
# THE PROCESSED TWEET IS: ['js', 'keep', 'activ', 'state', 'menu', 'relat', 'ifram', 'content']
# 1	0.00000000	b'js keep activ state menu relat ifram content'
# THE TWEET IS: system wide shellexecute hooks
# THE PROCESSED TWEET IS: ['system', 'wide', 'shellexecut', 'hook']
# 1	0.00000000	b'system wide shellexecut hook'
# THE TWEET IS: deploying aspnet mvc app to multiple virtual directories issues with url references  js files
# THE PROCESSED TWEET IS: ['deploy', 'aspnet', 'mvc', 'app', 'multipl', 'virtual', 'directori', 'issu', 'url', 'refer', 'js', 'file']
# 1	0.00000000	b'deploy aspnet mvc app multipl virtual directori issu url refer js file'
# THE TWEET IS: which is a better method for storing images   folder or sql server as binary
# THE PROCESSED TWEET IS: ['better', 'method', 'store', 'imag', 'folder', 'sql', 'server', 'binari']
# 1	0.00000000	b'better method store imag folder sql server binari'
# THE TWEET IS: pushviewcontroller with tableviewcontroller in viewcontroller
# THE PROCESSED TWEET IS: ['pushviewcontrol', 'tableviewcontrol', 'viewcontrol']
# 1	0.00000055	b'pushviewcontrol tableviewcontrol viewcontrol'
# THE TWEET IS: report is being generated runs forever in ie but works with firefox
# THE PROCESSED TWEET IS: ['report', 'gener', 'run', 'forev', 'ie', 'work', 'firefox']
# 1	0.00000000	b'report gener run forev ie work firefox'
# THE TWEET IS: can if be a proper function rather than a special form
# THE PROCESSED TWEET IS: ['proper', 'function', 'rather', 'special', 'form']
# 1	0.00000000	b'proper function rather special form'
# THE TWEET IS: how to modify web page elements loaded in a browser
# THE PROCESSED TWEET IS: ['modifi', 'web', 'page', 'element', 'load', 'browser']
# 1	0.00000000	b'modifi web page element load browser'
# THE TWEET IS: f and visual studio  express edition
# THE PROCESSED TWEET IS: ['f', 'visual', 'studio', 'express', 'edit']
# 1	0.00000000	b'f visual studio express edit'
# THE TWEET IS: prevent exit fullscreen when esc is pressed in flex
# THE PROCESSED TWEET IS: ['prevent', 'exit', 'fullscreen', 'esc', 'press', 'flex']
# 1	0.00000000	b'prevent exit fullscreen esc press flex'
# THE TWEET IS: tomcat  webxml change web inflib directory
# THE PROCESSED TWEET IS: ['tomcat', 'webxml', 'chang', 'web', 'inflib', 'directori']
# 1	0.00000000	b'tomcat webxml chang web inflib directori'
# THE TWEET IS: how to generate a polygon number figure using metapost
# THE PROCESSED TWEET IS: ['gener', 'polygon', 'number', 'figur', 'use', 'metapost']
# 1	0.00000000	b'gener polygon number figur use metapost'
# THE TWEET IS: which platform is more convenient for web development os x or linux
# THE PROCESSED TWEET IS: ['platform', 'conveni', 'web', 'develop', 'os', 'x', 'linux']
# 1	0.00000000	b'platform conveni web develop os x linux'
# THE TWEET IS: set remote addr to x forwarded for in apache
# THE PROCESSED TWEET IS: ['set', 'remot', 'addr', 'x', 'forward', 'apach']
# 1	0.00000000	b'set remot addr x forward apach'
# THE TWEET IS: is there a way to make a query respect the order of the inputted parameters
# THE PROCESSED TWEET IS: ['way', 'make', 'queri', 'respect', 'order', 'input', 'paramet']
# 1	0.00000000	b'way make queri respect order input paramet'
# THE TWEET IS: referring to non final fields of an enclosing class inside an anonymous inner class in java
# THE PROCESSED TWEET IS: ['refer', 'non', 'final', 'field', 'enclos', 'class', 'insid', 'anonym', 'inner', 'class', 'java']
# 1	0.00000000	b'refer non final field enclos class insid anonym inner class java'
# THE TWEET IS: screwed up table in oracle
# THE PROCESSED TWEET IS: ['screw', 'tabl', 'oracl']
# 1	0.00000000	b'screw tabl oracl'
# THE TWEET IS: jquery with smarty and json
# THE PROCESSED TWEET IS: ['jqueri', 'smarti', 'json']
# 1	0.00000000	b'jqueri smarti json'
# THE TWEET IS: how can i change the ui language of qt creator
# THE PROCESSED TWEET IS: ['chang', 'ui', 'languag', 'qt', 'creator']
# 1	0.00000000	b'chang ui languag qt creator'
# THE TWEET IS: validation framework in net that can do edits between fields
# THE PROCESSED TWEET IS: ['valid', 'framework', 'net', 'edit', 'field']
# 1	0.00000000	b'valid framework net edit field'
# THE TWEET IS: how to get the value of a multiple option dropdown
# THE PROCESSED TWEET IS: ['get', 'valu', 'multipl', 'option', 'dropdown']
# 1	0.00000000	b'get valu multipl option dropdown'
# THE TWEET IS: webview crash with garbage collector on
# THE PROCESSED TWEET IS: ['webview', 'crash', 'garbag', 'collector']
# 1	0.00000000	b'webview crash garbag collector'
# THE TWEET IS: passing parameters in redirection rails
# THE PROCESSED TWEET IS: ['pass', 'paramet', 'redirect', 'rail']
# 1	0.00000000	b'pass paramet redirect rail'
# THE TWEET IS: maven tomcat plugin with mysql driver in catalina homelib
# THE PROCESSED TWEET IS: ['maven', 'tomcat', 'plugin', 'mysql', 'driver', 'catalina', 'homelib']
# 1	0.00000000	b'maven tomcat plugin mysql driver catalina homelib'
# THE TWEET IS: jquery first child of this
# THE PROCESSED TWEET IS: ['jqueri', 'first', 'child']
# 1	0.00000000	b'jqueri first child'
# THE TWEET IS: does zend acl suit my needs
# THE PROCESSED TWEET IS: ['zend', 'acl', 'suit', 'need']
# 1	0.00000000	b'zend acl suit need'
# THE TWEET IS: design time error while writing nested type in xaml
# THE PROCESSED TWEET IS: ['design', 'time', 'error', 'write', 'nest', 'type', 'xaml']
# 1	0.00000000	b'design time error write nest type xaml'
# THE TWEET IS: reading data metadata from jpeg xmp or exif in c
# THE PROCESSED TWEET IS: ['read', 'data', 'metadata', 'jpeg', 'xmp', 'exif', 'c']
# 1	0.00000000	b'read data metadata jpeg xmp exif c'
# THE TWEET IS: multithreaded c program how to kill processes spawned by threads
# THE PROCESSED TWEET IS: ['multithread', 'c', 'program', 'kill', 'process', 'spawn', 'thread']
# 1	0.00000000	b'multithread c program kill process spawn thread'
# THE TWEET IS: how do i get alt text to support vertical align middle
# THE PROCESSED TWEET IS: ['get', 'alt', 'text', 'support', 'vertic', 'align', 'middl']
# 1	0.00000000	b'get alt text support vertic align middl'
# THE TWEET IS: vb gui interface to run vbs script
# THE PROCESSED TWEET IS: ['vb', 'gui', 'interfac', 'run', 'vb', 'script']
# 1	0.00000000	b'vb gui interfac run vb script'
# THE TWEET IS: loading presentmodalviewcontroller in viewdidappear causes exc bad access
# THE PROCESSED TWEET IS: ['load', 'presentmodalviewcontrol', 'viewdidappear', 'caus', 'exc', 'bad', 'access']
# 1	0.00000000	b'load presentmodalviewcontrol viewdidappear caus exc bad access'
# THE TWEET IS: net  how to remove from list using the  functions
# THE PROCESSED TWEET IS: ['net', 'remov', 'list', 'use', 'function']
# 1	0.00000000	b'net remov list use function'
# THE TWEET IS: how to turn off mcafee programmatically
# THE PROCESSED TWEET IS: ['turn', 'mcafe', 'programmat']
# 1	0.00000000	b'turn mcafe programmat'
# THE TWEET IS: perform a sql join on django models that are not related
# THE PROCESSED TWEET IS: ['perform', 'sql', 'join', 'django', 'model', 'relat']
# 1	0.00000000	b'perform sql join django model relat'
# THE TWEET IS: propertiessettingssave only saves on first call
# THE PROCESSED TWEET IS: ['propertiessettingssav', 'save', 'first', 'call']
# 1	0.00000000	b'propertiessettingssav save first call'
# THE TWEET IS: how to force hibernate  or  to use cglib instead of javassist
# THE PROCESSED TWEET IS: ['forc', 'hibern', 'use', 'cglib', 'instead', 'javassist']
# 1	0.00000000	b'forc hibern use cglib instead javassist'
# THE TWEET IS: win application arent so object oriented and why there are so many pointers
# THE PROCESSED TWEET IS: ['win', 'applic', 'arent', 'object', 'orient', 'mani', 'pointer']
# 1	0.00000000	b'win applic arent object orient mani pointer'
# THE TWEET IS: spgridview current item in sharepoint
# THE PROCESSED TWEET IS: ['spgridview', 'current', 'item', 'sharepoint']
# 1	0.00000000	b'spgridview current item sharepoint'
# THE TWEET IS: flyweight and factory problem with idisposable
# THE PROCESSED TWEET IS: ['flyweight', 'factori', 'problem', 'idispos']
# 1	0.00000000	b'flyweight factori problem idispos'
# THE TWEET IS: functions returning char pointer
# THE PROCESSED TWEET IS: ['function', 'return', 'char', 'pointer']
# 1	0.00000000	b'function return char pointer'
# THE TWEET IS: simple insert works with phpmyadmin but not with php
# THE PROCESSED TWEET IS: ['simpl', 'insert', 'work', 'phpmyadmin', 'php']
# 1	0.00000000	b'simpl insert work phpmyadmin php'
# THE TWEET IS: controlling doxygens latex output for making pdf documentation
# THE PROCESSED TWEET IS: ['control', 'doxygen', 'latex', 'output', 'make', 'pdf', 'document']
# 1	0.00000000	b'control doxygen latex output make pdf document'
# THE TWEET IS: secure ways to reset password or to give old password
# THE PROCESSED TWEET IS: ['secur', 'way', 'reset', 'password', 'give', 'old', 'password']
# 1	0.00000000	b'secur way reset password give old password'
# THE TWEET IS: how to select a value in the same table as the value for an update for each row
# THE PROCESSED TWEET IS: ['select', 'valu', 'tabl', 'valu', 'updat', 'row']
# 1	0.00000000	b'select valu tabl valu updat row'
# THE TWEET IS: how would i use a socket to have several processes communicate with a central process
# THE PROCESSED TWEET IS: ['would', 'use', 'socket', 'sever', 'process', 'commun', 'central', 'process']
# 1	0.00000000	b'would use socket sever process commun central process'
# THE TWEET IS: error in processstart    the system cannot find the file specified
# THE PROCESSED TWEET IS: ['error', 'processstart', 'system', 'cannot', 'find', 'file', 'specifi']
# 1	0.00000000	b'error processstart system cannot find file specifi'
# THE TWEET IS: jquery  vs yui which one to choose
# THE PROCESSED TWEET IS: ['jqueri', 'vs', 'yui', 'one', 'choos']
# 1	0.00000000	b'jqueri vs yui one choos'
# THE TWEET IS: drupal form validation not working for me
# THE PROCESSED TWEET IS: ['drupal', 'form', 'valid', 'work']
# 1	0.00000000	b'drupal form valid work'
# THE TWEET IS: flash components with flex sdk
# THE PROCESSED TWEET IS: ['flash', 'compon', 'flex', 'sdk']
# 1	0.00000000	b'flash compon flex sdk'
# THE TWEET IS: need advice to design crack proof software
# THE PROCESSED TWEET IS: ['need', 'advic', 'design', 'crack', 'proof', 'softwar']
# 1	0.00000000	b'need advic design crack proof softwar'
# THE TWEET IS: php library with countries states and cities
# THE PROCESSED TWEET IS: ['php', 'librari', 'countri', 'state', 'citi']
# 1	0.00000000	b'php librari countri state citi'
# THE TWEET IS: visual studio  web projects
# THE PROCESSED TWEET IS: ['visual', 'studio', 'web', 'project']
# 1	0.00000000	b'visual studio web project'
# THE TWEET IS: qprocess doesnt start java app under windows
# THE PROCESSED TWEET IS: ['qprocess', 'doesnt', 'start', 'java', 'app', 'window']
# 1	0.00000000	b'qprocess doesnt start java app window'
# THE TWEET IS: launch activity from url
# THE PROCESSED TWEET IS: ['launch', 'activ', 'url']
# 1	0.00000000	b'launch activ url'
# THE TWEET IS: force all item renderers to commitproperties
# THE PROCESSED TWEET IS: ['forc', 'item', 'render', 'commitproperti']
# 1	0.00000000	b'forc item render commitproperti'
# THE TWEET IS: creating a view using subquerywith alias for columns in oracle i
# THE PROCESSED TWEET IS: ['creat', 'view', 'use', 'subquerywith', 'alia', 'column', 'oracl']
# 1	0.00000000	b'creat view use subquerywith alia column oracl'
# THE TWEET IS: double of total problem
# THE PROCESSED TWEET IS: ['doubl', 'total', 'problem']
# 1	0.00000000	b'doubl total problem'
# THE TWEET IS: how to create a timer using tkinter
# THE PROCESSED TWEET IS: ['creat', 'timer', 'use', 'tkinter']
# 1	0.00000000	b'creat timer use tkinter'
# THE TWEET IS: silverlight  filestream
# THE PROCESSED TWEET IS: ['silverlight', 'filestream']
# 1	0.00000000	b'silverlight filestream'
# THE TWEET IS: xml schema validation for large schema files
# THE PROCESSED TWEET IS: ['xml', 'schema', 'valid', 'larg', 'schema', 'file']
# 1	0.00000000	b'xml schema valid larg schema file'
# THE TWEET IS: cross platform c code architecture
# THE PROCESSED TWEET IS: ['cross', 'platform', 'c', 'code', 'architectur']
# 1	0.00000000	b'cross platform c code architectur'
# THE TWEET IS: calculating the perpendicular plane to a triangle in d space
# THE PROCESSED TWEET IS: ['calcul', 'perpendicular', 'plane', 'triangl', 'space']
# 1	0.00000000	b'calcul perpendicular plane triangl space'
# THE TWEET IS: whats the single best reference on the topic of posix signals
# THE PROCESSED TWEET IS: ['what', 'singl', 'best', 'refer', 'topic', 'posix', 'signal']
# 1	0.00000000	b'what singl best refer topic posix signal'
# THE TWEET IS: how to use nspredicate to catch child objects
# THE PROCESSED TWEET IS: ['use', 'nspredic', 'catch', 'child', 'object']
# 1	0.00000000	b'use nspredic catch child object'
# THE TWEET IS: maven best practice for generating artifacts for multiple environments prod test dev with cihudson support
# THE PROCESSED TWEET IS: ['maven', 'best', 'practic', 'gener', 'artifact', 'multipl', 'environ', 'prod', 'test', 'dev', 'cihudson', 'support']
# 1	0.00000000	b'maven best practic gener artifact multipl environ prod test dev cihudson support'
# THE TWEET IS: jquery ui accordion resize on window resize
# THE PROCESSED TWEET IS: ['jqueri', 'ui', 'accordion', 'resiz', 'window', 'resiz']
# 1	0.00000000	b'jqueri ui accordion resiz window resiz'
# THE TWEET IS: run php script continuously
# THE PROCESSED TWEET IS: ['run', 'php', 'script', 'continu']
# 1	0.00000000	b'run php script continu'
# THE TWEET IS: sql server  permission and encryption
# THE PROCESSED TWEET IS: ['sql', 'server', 'permiss', 'encrypt']
# 1	0.00000000	b'sql server permiss encrypt'
# THE TWEET IS: how to create docking panel in java
# THE PROCESSED TWEET IS: ['creat', 'dock', 'panel', 'java']
# 1	0.00000000	b'creat dock panel java'
# THE TWEET IS: coding the r ight way   avoiding the for loop
# THE PROCESSED TWEET IS: ['code', 'r', 'ight', 'way', 'avoid', 'loop']
# 1	0.00000000	b'code r ight way avoid loop'
# THE TWEET IS: what is considered a long execution time
# THE PROCESSED TWEET IS: ['consid', 'long', 'execut', 'time']
# 1	0.00000000	b'consid long execut time'
# THE TWEET IS: want to extend from javasqlresultset
# THE PROCESSED TWEET IS: ['want', 'extend', 'javasqlresultset']
# 1	0.00000000	b'want extend javasqlresultset'
# THE TWEET IS: post loading  check if an image is in the browser cache
# THE PROCESSED TWEET IS: ['post', 'load', 'check', 'imag', 'browser', 'cach']
# 1	0.00000000	b'post load check imag browser cach'
# THE TWEET IS: cc full file path in assert macro
# THE PROCESSED TWEET IS: ['cc', 'full', 'file', 'path', 'assert', 'macro']
# 1	0.00000000	b'cc full file path assert macro'
# THE TWEET IS: how can i correctly display my avl tree in latex a solo left child hangs straight down
# THE PROCESSED TWEET IS: ['correctli', 'display', 'avl', 'tree', 'latex', 'solo', 'left', 'child', 'hang', 'straight']
# 1	0.00000000	b'correctli display avl tree latex solo left child hang straight'
# THE TWEET IS: how do i pass values to the constructor on my wcf service
# THE PROCESSED TWEET IS: ['pass', 'valu', 'constructor', 'wcf', 'servic']
# 1	0.00000000	b'pass valu constructor wcf servic'
# THE TWEET IS: new scripting language
# THE PROCESSED TWEET IS: ['new', 'script', 'languag']
# 1	0.00000000	b'new script languag'
# THE TWEET IS: how do i search for a number in a d array sorted left to right and top to bottom
# THE PROCESSED TWEET IS: ['search', 'number', 'array', 'sort', 'left', 'right', 'top', 'bottom']
# 1	0.00000000	b'search number array sort left right top bottom'
# THE TWEET IS: jquery load not applying ready function
# THE PROCESSED TWEET IS: ['jqueri', 'load', 'appli', 'readi', 'function']
# 1	0.00000000	b'jqueri load appli readi function'
# THE TWEET IS: rails has many with dynamic conditions
# THE PROCESSED TWEET IS: ['rail', 'mani', 'dynam', 'condit']
# 1	0.00001648	b'rail mani dynam condit'
# THE TWEET IS: javascript content rotator
# THE PROCESSED TWEET IS: ['javascript', 'content', 'rotat']
# 1	0.00000000	b'javascript content rotat'
# THE TWEET IS: checkout or list remote branches in gitpython
# THE PROCESSED TWEET IS: ['checkout', 'list', 'remot', 'branch', 'gitpython']
# 1	0.00000000	b'checkout list remot branch gitpython'
# THE TWEET IS: how to make delphi prism indexed properties visible to c when properties are not default
# THE PROCESSED TWEET IS: ['make', 'delphi', 'prism', 'index', 'properti', 'visibl', 'c', 'properti', 'default']
# 1	0.00000000	b'make delphi prism index properti visibl c properti default'
# THE TWEET IS: hashing password giving different results
# THE PROCESSED TWEET IS: ['hash', 'password', 'give', 'differ', 'result']
# 1	0.00000000	b'hash password give differ result'
# THE TWEET IS: valid json still fails on ie with jquerys ajax or getjson callbacks
# THE PROCESSED TWEET IS: ['valid', 'json', 'still', 'fail', 'ie', 'jqueri', 'ajax', 'getjson', 'callback']
# 1	0.00000000	b'valid json still fail ie jqueri ajax getjson callback'
# THE TWEET IS: how to set default value of hselectoneradio button
# THE PROCESSED TWEET IS: ['set', 'default', 'valu', 'hselectoneradio', 'button']
# 1	0.00000000	b'set default valu hselectoneradio button'
# THE TWEET IS: problem antlrworks code too large
# THE PROCESSED TWEET IS: ['problem', 'antlrwork', 'code', 'larg']
# 1	0.00000000	b'problem antlrwork code larg'
# THE TWEET IS: why are  post variables getting escaped in php
# THE PROCESSED TWEET IS: ['post', 'variabl', 'get', 'escap', 'php']
# 1	0.00000000	b'post variabl get escap php'
# THE TWEET IS: why my inner class do see a non static variable
# THE PROCESSED TWEET IS: ['inner', 'class', 'see', 'non', 'static', 'variabl']
# 1	0.00000000	b'inner class see non static variabl'
# THE TWEET IS: at which line in the following code should i commit my unit of work
# THE PROCESSED TWEET IS: ['line', 'follow', 'code', 'commit', 'unit', 'work']
# 1	0.00000000	b'line follow code commit unit work'
# THE TWEET IS: mvc   same url multiple views
# THE PROCESSED TWEET IS: ['mvc', 'url', 'multipl', 'view']
# 1	0.00000000	b'mvc url multipl view'
# THE TWEET IS: java outprintln how is this possible
# THE PROCESSED TWEET IS: ['java', 'outprintln', 'possibl']
# 1	0.00000000	b'java outprintln possibl'
# THE TWEET IS: can some tell me why i am seg faulting in this simple c program
# THE PROCESSED TWEET IS: ['tell', 'seg', 'fault', 'simpl', 'c', 'program']
# 1	0.00000000	b'tell seg fault simpl c program'
# THE TWEET IS: classpath on mac and how does mac look for mysql connector java binjar
# THE PROCESSED TWEET IS: ['classpath', 'mac', 'mac', 'look', 'mysql', 'connector', 'java', 'binjar']
# 1	0.00000000	b'classpath mac mac look mysql connector java binjar'
# THE TWEET IS: looking for net math method that will zero a negative integer
# THE PROCESSED TWEET IS: ['look', 'net', 'math', 'method', 'zero', 'neg', 'integ']
# 1	0.00000000	b'look net math method zero neg integ'
# THE TWEET IS: bash linux set difference between two text files
# THE PROCESSED TWEET IS: ['bash', 'linux', 'set', 'differ', 'two', 'text', 'file']
# 1	0.00000000	b'bash linux set differ two text file'
# THE TWEET IS: difference in declaring idisposable member in using block or at using block declaration
# THE PROCESSED TWEET IS: ['differ', 'declar', 'idispos', 'member', 'use', 'block', 'use', 'block', 'declar']
# 1	0.00000000	b'differ declar idispos member use block use block declar'
# THE TWEET IS: background job with status in rails
# THE PROCESSED TWEET IS: ['background', 'job', 'statu', 'rail']
# 1	0.00000000	b'background job statu rail'
# THE TWEET IS: why does cs fopen take a const char  as its second argument
# THE PROCESSED TWEET IS: ['cs', 'fopen', 'take', 'const', 'char', 'second', 'argument']
# 1	0.00000000	b'cs fopen take const char second argument'
# THE TWEET IS: no openid endpoint found
# THE PROCESSED TWEET IS: ['openid', 'endpoint', 'found']
# 1	0.00000000	b'openid endpoint found'
# THE TWEET IS: how do i use ws addressing properly in an axis client
# THE PROCESSED TWEET IS: ['use', 'ws', 'address', 'properli', 'axi', 'client']
# 1	0.00000000	b'use ws address properli axi client'
# THE TWEET IS: sql count in view as column
# THE PROCESSED TWEET IS: ['sql', 'count', 'view', 'column']
# 1	0.00000000	b'sql count view column'
# THE TWEET IS: how to get scrolltop of page just after page onload event
# THE PROCESSED TWEET IS: ['get', 'scrolltop', 'page', 'page', 'onload', 'event']
# 1	0.00000000	b'get scrolltop page page onload event'
# THE TWEET IS: how to change brace indentation levels in emacs
# THE PROCESSED TWEET IS: ['chang', 'brace', 'indent', 'level', 'emac']
# 1	0.00000000	b'chang brace indent level emac'
# THE TWEET IS: jquery select text next to an input checkbox
# THE PROCESSED TWEET IS: ['jqueri', 'select', 'text', 'next', 'input', 'checkbox']
# 1	0.00000000	b'jqueri select text next input checkbox'
# THE TWEET IS: does telerik raddatepicker support hijri calendars
# THE PROCESSED TWEET IS: ['telerik', 'raddatepick', 'support', 'hijri', 'calendar']
# 1	0.00000000	b'telerik raddatepick support hijri calendar'
# THE TWEET IS: re ordering collection c
# THE PROCESSED TWEET IS: ['order', 'collect', 'c']
# 1	0.00000000	b'order collect c'
# THE TWEET IS: how to use delphis ascurrency to show currency without currency symbol
# THE PROCESSED TWEET IS: ['use', 'delphi', 'ascurr', 'show', 'currenc', 'without', 'currenc', 'symbol']
# 1	0.00000000	b'use delphi ascurr show currenc without currenc symbol'
# THE TWEET IS: renaming and moving files in bash or perl
# THE PROCESSED TWEET IS: ['renam', 'move', 'file', 'bash', 'perl']
# 1	0.00000000	b'renam move file bash perl'
# THE TWEET IS: latex automatic two column wrapping of content
# THE PROCESSED TWEET IS: ['latex', 'automat', 'two', 'column', 'wrap', 'content']
# 1	0.00000000	b'latex automat two column wrap content'
# THE TWEET IS: c clickonce events
# THE PROCESSED TWEET IS: ['c', 'clickonc', 'event']
# 1	0.00000000	b'c clickonc event'
# THE TWEET IS: composite operations in android canvas
# THE PROCESSED TWEET IS: ['composit', 'oper', 'android', 'canva']
# 1	0.00000000	b'composit oper android canva'
# THE TWEET IS: how to customize  style a uipopovercontroller
# THE PROCESSED TWEET IS: ['custom', 'style', 'uipopovercontrol']
# 1	0.00000000	b'custom style uipopovercontrol'
# THE TWEET IS: facebook application how to check if inside facebook canvas  standalone using php
# THE PROCESSED TWEET IS: ['facebook', 'applic', 'check', 'insid', 'facebook', 'canva', 'standalon', 'use', 'php']
# 1	0.00000000	b'facebook applic check insid facebook canva standalon use php'
# THE TWEET IS: how to do basic authentication using firewatir on ubuntu linux
# THE PROCESSED TWEET IS: ['basic', 'authent', 'use', 'firewatir', 'ubuntu', 'linux']
# 1	0.00000000	b'basic authent use firewatir ubuntu linux'
# THE TWEET IS: writing a batch file to delete files with wildcards
# THE PROCESSED TWEET IS: ['write', 'batch', 'file', 'delet', 'file', 'wildcard']
# 1	0.00000000	b'write batch file delet file wildcard'
# THE TWEET IS: greenspuns th rule in perl
# THE PROCESSED TWEET IS: ['greenspun', 'th', 'rule', 'perl']
# 1	0.00000000	b'greenspun th rule perl'
# THE TWEET IS: looking for an automated logging toollibrary for net
# THE PROCESSED TWEET IS: ['look', 'autom', 'log', 'toollibrari', 'net']
# 1	0.00000000	b'look autom log toollibrari net'
# THE TWEET IS: net xbox live account api
# THE PROCESSED TWEET IS: ['net', 'xbox', 'live', 'account', 'api']
# 1	0.00000000	b'net xbox live account api'
# THE TWEET IS: best practices for setup and management of an open source project
# THE PROCESSED TWEET IS: ['best', 'practic', 'setup', 'manag', 'open', 'sourc', 'project']
# 1	0.00000000	b'best practic setup manag open sourc project'
# THE TWEET IS: trouble understanding the whole osgi web eco system
# THE PROCESSED TWEET IS: ['troubl', 'understand', 'whole', 'osgi', 'web', 'eco', 'system']
# 1	0.00000000	b'troubl understand whole osgi web eco system'
# THE TWEET IS: treeview control problem
# THE PROCESSED TWEET IS: ['treeview', 'control', 'problem']
# 1	0.00000000	b'treeview control problem'
# THE TWEET IS: sql select from data in query where this data is not already in the database
# THE PROCESSED TWEET IS: ['sql', 'select', 'data', 'queri', 'data', 'alreadi', 'databas']
# 1	0.00000000	b'sql select data queri data alreadi databas'
# THE TWEET IS: is epoll the essential reason that tornadowebor nginx is so fast
# THE PROCESSED TWEET IS: ['epol', 'essenti', 'reason', 'tornadowebor', 'nginx', 'fast']
# 1	0.00000000	b'epol essenti reason tornadowebor nginx fast'
# THE TWEET IS: jquery ajax success function returns null
# THE PROCESSED TWEET IS: ['jqueri', 'ajax', 'success', 'function', 'return', 'null']
# 1	0.00000000	b'jqueri ajax success function return null'
# THE TWEET IS: linq select elements that only appear once in a list
# THE PROCESSED TWEET IS: ['linq', 'select', 'element', 'appear', 'list']
# 1	0.00000000	b'linq select element appear list'
# THE TWEET IS: sql   getting the id from a row based on a group by
# THE PROCESSED TWEET IS: ['sql', 'get', 'id', 'row', 'base', 'group']
# 1	0.00000000	b'sql get id row base group'
# THE TWEET IS: passing data from a servlet to javascript code in an ajax application
# THE PROCESSED TWEET IS: ['pass', 'data', 'servlet', 'javascript', 'code', 'ajax', 'applic']
# 1	0.00000000	b'pass data servlet javascript code ajax applic'
# THE TWEET IS: what are the common patterns in web programming
# THE PROCESSED TWEET IS: ['common', 'pattern', 'web', 'program']
# 1	0.00000000	b'common pattern web program'
# THE TWEET IS: drawing raw buffer to cgbitmapcontext
# THE PROCESSED TWEET IS: ['draw', 'raw', 'buffer', 'cgbitmapcontext']
# 1	0.00000000	b'draw raw buffer cgbitmapcontext'
# THE TWEET IS: mprotect   how aligning to multiple of pagesize works
# THE PROCESSED TWEET IS: ['mprotect', 'align', 'multipl', 'pages', 'work']
# 1	0.00001648	b'mprotect align multipl pages work'
# THE TWEET IS: codeigniter benchmarking where are these ms coming from
# THE PROCESSED TWEET IS: ['codeignit', 'benchmark', 'ms', 'come']
# 1	0.00000000	b'codeignit benchmark ms come'
# THE TWEET IS: apache basic authentication before rewrite
# THE PROCESSED TWEET IS: ['apach', 'basic', 'authent', 'rewrit']
# 1	0.00000000	b'apach basic authent rewrit'
# THE TWEET IS: blackberry   how to send email with embedded image from application
# THE PROCESSED TWEET IS: ['blackberri', 'send', 'email', 'embed', 'imag', 'applic']
# 1	0.00000000	b'blackberri send email embed imag applic'
# THE TWEET IS: continuous integration with clearcase and long updating snapshot views
# THE PROCESSED TWEET IS: ['continu', 'integr', 'clearcas', 'long', 'updat', 'snapshot', 'view']
# 1	0.00000000	b'continu integr clearcas long updat snapshot view'
# THE TWEET IS: iphone sdk loading on titanium developer
# THE PROCESSED TWEET IS: ['iphon', 'sdk', 'load', 'titanium', 'develop']
# 1	0.00000000	b'iphon sdk load titanium develop'
# THE TWEET IS: rendering html in java
# THE PROCESSED TWEET IS: ['render', 'html', 'java']
# 1	0.00000000	b'render html java'
# THE TWEET IS: releasing winform program updates
# THE PROCESSED TWEET IS: ['releas', 'winform', 'program', 'updat']
# 1	0.00000000	b'releas winform program updat'
# THE TWEET IS: how is its lifetime of a return value extended to the scope of the calling function when it is bound to a const reference in the calling function
# THE PROCESSED TWEET IS: ['lifetim', 'return', 'valu', 'extend', 'scope', 'call', 'function', 'bound', 'const', 'refer', 'call', 'function']
# 1	0.00000000	b'lifetim return valu extend scope call function bound const refer call function'
# THE TWEET IS: dbdsqlitest execute failed datatype mismatch
# THE PROCESSED TWEET IS: ['dbdsqlitest', 'execut', 'fail', 'datatyp', 'mismatch']
# 1	0.00000000	b'dbdsqlitest execut fail datatyp mismatch'
# THE TWEET IS: how to distinguish between two different udp clients on the same ip address
# THE PROCESSED TWEET IS: ['distinguish', 'two', 'differ', 'udp', 'client', 'ip', 'address']
# 1	0.00000000	b'distinguish two differ udp client ip address'
# THE TWEET IS: string format options for int in net
# THE PROCESSED TWEET IS: ['string', 'format', 'option', 'int', 'net']
# 1	0.00000000	b'string format option int net'
# THE TWEET IS: background not showing behind floating divs
# THE PROCESSED TWEET IS: ['background', 'show', 'behind', 'float', 'div']
# 1	0.00000000	b'background show behind float div'
# THE TWEET IS: choosing suitable background  foreground colour using php
# THE PROCESSED TWEET IS: ['choos', 'suitabl', 'background', 'foreground', 'colour', 'use', 'php']
# 1	0.00000000	b'choos suitabl background foreground colour use php'
# THE TWEET IS: why do c compilers prepend underscores to external names
# THE PROCESSED TWEET IS: ['c', 'compil', 'prepend', 'underscor', 'extern', 'name']
# 1	0.00000000	b'c compil prepend underscor extern name'
# THE TWEET IS: which one can have better performance   linq to ef or nhibernate
# THE PROCESSED TWEET IS: ['one', 'better', 'perform', 'linq', 'ef', 'nhibern']
# 1	0.00000000	b'one better perform linq ef nhibern'
# THE TWEET IS: is it possible to reinterpret pointer as dimensioned array reference
# THE PROCESSED TWEET IS: ['possibl', 'reinterpret', 'pointer', 'dimens', 'array', 'refer']
# 1	0.00000000	b'possibl reinterpret pointer dimens array refer'
# THE TWEET IS: question about compilers and how they work
# THE PROCESSED TWEET IS: ['question', 'compil', 'work']
# 1	0.00000000	b'question compil work'
# THE TWEET IS: c hex shift in binary file
# THE PROCESSED TWEET IS: ['c', 'hex', 'shift', 'binari', 'file']
# 1	0.00000000	b'c hex shift binari file'
# THE TWEET IS: creating simple cnet wrapper step by step
# THE PROCESSED TWEET IS: ['creat', 'simpl', 'cnet', 'wrapper', 'step', 'step']
# 1	0.00000000	b'creat simpl cnet wrapper step step'
# THE TWEET IS: unexpected t else error in php
# THE PROCESSED TWEET IS: ['unexpect', 'els', 'error', 'php']
# 1	0.00000000	b'unexpect els error php'
# THE TWEET IS: calling a c function from java which uses some other function which refers include files
# THE PROCESSED TWEET IS: ['call', 'c', 'function', 'java', 'use', 'function', 'refer', 'includ', 'file']
# 1	0.00000000	b'call c function java use function refer includ file'
# THE TWEET IS: can anyone tell me what  a in a unix shell test condition means
# THE PROCESSED TWEET IS: ['anyon', 'tell', 'unix', 'shell', 'test', 'condit', 'mean']
# 1	0.00000000	b'anyon tell unix shell test condit mean'
# THE TWEET IS: struct bitfield max size c c
# THE PROCESSED TWEET IS: ['struct', 'bitfield', 'max', 'size', 'c', 'c']
# 1	0.00000000	b'struct bitfield max size c c'
# THE TWEET IS: what are the bestpopular libraries for developing cli appsscripts
# THE PROCESSED TWEET IS: ['bestpopular', 'librari', 'develop', 'cli', 'appsscript']
# 1	0.00000000	b'bestpopular librari develop cli appsscript'
# THE TWEET IS: btstask to import policy
# THE PROCESSED TWEET IS: ['btstask', 'import', 'polici']
# 1	0.00000000	b'btstask import polici'
# THE TWEET IS: ajax on rails
# THE PROCESSED TWEET IS: ['ajax', 'rail']
# 1	0.00000000	b'ajax rail'
# THE TWEET IS: improving the performance of an nhibernate data access layer
# THE PROCESSED TWEET IS: ['improv', 'perform', 'nhibern', 'data', 'access', 'layer']
# 1	0.00000000	b'improv perform nhibern data access layer'
# THE TWEET IS: what is the purpose of using a reference to a reference in c
# THE PROCESSED TWEET IS: ['purpos', 'use', 'refer', 'refer', 'c']
# 1	0.00000000	b'purpos use refer refer c'
# THE TWEET IS: indy ftp large files and nat routers
# THE PROCESSED TWEET IS: ['indi', 'ftp', 'larg', 'file', 'nat', 'router']
# 1	0.00000000	b'indi ftp larg file nat router'
# THE TWEET IS: how to find out the html code for a currency
# THE PROCESSED TWEET IS: ['find', 'html', 'code', 'currenc']
# 1	0.00000000	b'find html code currenc'
# THE TWEET IS: how can i pass latitude and longitude values from uiviewcontroller to mkmapview
# THE PROCESSED TWEET IS: ['pass', 'latitud', 'longitud', 'valu', 'uiviewcontrol', 'mkmapview']
# 1	0.00000000	b'pass latitud longitud valu uiviewcontrol mkmapview'
# THE TWEET IS: load two instances of the same dll in delphi
# THE PROCESSED TWEET IS: ['load', 'two', 'instanc', 'dll', 'delphi']
# 1	0.00000000	b'load two instanc dll delphi'
# THE TWEET IS: detect ipad in php
# THE PROCESSED TWEET IS: ['detect', 'ipad', 'php']
# 1	0.00000000	b'detect ipad php'
# THE TWEET IS: what is the scope of require once in php
# THE PROCESSED TWEET IS: ['scope', 'requir', 'php']
# 1	0.00000000	b'scope requir php'
# THE TWEET IS: how to check if receiver is registered in android
# THE PROCESSED TWEET IS: ['check', 'receiv', 'regist', 'android']
# 1	0.00000000	b'check receiv regist android'
# THE TWEET IS: best way to list online users with php but without mysql
# THE PROCESSED TWEET IS: ['best', 'way', 'list', 'onlin', 'user', 'php', 'without', 'mysql']
# 1	0.00000000	b'best way list onlin user php without mysql'
# THE TWEET IS: why cant i use resources as errormessage with dataannotations
# THE PROCESSED TWEET IS: ['cant', 'use', 'resourc', 'errormessag', 'dataannot']
# 1	0.00000000	b'cant use resourc errormessag dataannot'
# THE TWEET IS: limit records fetched in android sqlite database
# THE PROCESSED TWEET IS: ['limit', 'record', 'fetch', 'android', 'sqlite', 'databas']
# 1	0.00000000	b'limit record fetch android sqlite databas'
# THE TWEET IS: htaccess redirect from subdomain to root
# THE PROCESSED TWEET IS: ['htaccess', 'redirect', 'subdomain', 'root']
# 1	0.00000000	b'htaccess redirect subdomain root'
# THE TWEET IS: a better way to do xml in java
# THE PROCESSED TWEET IS: ['better', 'way', 'xml', 'java']
# 1	0.00000000	b'better way xml java'
# THE TWEET IS: killing a deadlocked task in net  tpl
# THE PROCESSED TWEET IS: ['kill', 'deadlock', 'task', 'net', 'tpl']
# 1	0.00000000	b'kill deadlock task net tpl'
# THE TWEET IS: problem accessing variable in a nested form partial
# THE PROCESSED TWEET IS: ['problem', 'access', 'variabl', 'nest', 'form', 'partial']
# 1	0.00000000	b'problem access variabl nest form partial'
# THE TWEET IS: internet explore is unresponsive while loading a large page
# THE PROCESSED TWEET IS: ['internet', 'explor', 'unrespons', 'load', 'larg', 'page']
# 1	0.00000000	b'internet explor unrespons load larg page'
# THE TWEET IS: receiving ajax http response code as
# THE PROCESSED TWEET IS: ['receiv', 'ajax', 'http', 'respons', 'code']
# 1	0.00000000	b'receiv ajax http respons code'
# THE TWEET IS: weird array syntax
# THE PROCESSED TWEET IS: ['weird', 'array', 'syntax']
# 1	0.00000000	b'weird array syntax'
# THE TWEET IS: how to change browser focus from one tab to another
# THE PROCESSED TWEET IS: ['chang', 'browser', 'focu', 'one', 'tab', 'anoth']
# 1	0.00000000	b'chang browser focu one tab anoth'
# THE TWEET IS: how to catch an incoming text message
# THE PROCESSED TWEET IS: ['catch', 'incom', 'text', 'messag']
# 1	0.00000000	b'catch incom text messag'
# THE TWEET IS: my first go with function templates
# THE PROCESSED TWEET IS: ['first', 'go', 'function', 'templat']
# 1	0.00000000	b'first go function templat'
# THE TWEET IS: what is erlangs concurrency model actually
# THE PROCESSED TWEET IS: ['erlang', 'concurr', 'model', 'actual']
# 1	0.00000000	b'erlang concurr model actual'
# THE TWEET IS: showing login view controller before main tab bar controller
# THE PROCESSED TWEET IS: ['show', 'login', 'view', 'control', 'main', 'tab', 'bar', 'control']
# 1	0.00000000	b'show login view control main tab bar control'
# THE TWEET IS: sql server database synchronization issues
# ...
# 1	0.00000000	b'ef store procedur avail'
# THE TWEET IS: attach a file from memorystream to a mailmessage in c
# THE PROCESSED TWEET IS: ['attach', 'file', 'memorystream', 'mailmessag', 'c']
# 1	0.00000000	b'attach file memorystream mailmessag c'
# THE TWEET IS: android how to use getapplication and getapplicationcontext from non activity  service class
# THE PROCESSED TWEET IS: ['android', 'use', 'getappl', 'getapplicationcontext', 'non', 'activ', 'servic', 'class']
# 1	0.00000000	b'android use getappl getapplicationcontext non activ servic class'
# THE TWEET IS: rename files with jpg extension according to its folder name via bash script
# THE PROCESSED TWEET IS: ['renam', 'file', 'jpg', 'extens', 'accord', 'folder', 'name', 'via', 'bash', 'script']
# 1	0.00000000	b'renam file jpg extens accord folder name via bash script'
# THE TWEET IS: text cutting off in sliding banner
# THE PROCESSED TWEET IS: ['text', 'cut', 'slide', 'banner']
# 1	0.00000000	b'text cut slide banner'
# THE TWEET IS: how to pass a lambda expression in elisp
# THE PROCESSED TWEET IS: ['pass', 'lambda', 'express', 'elisp']
# 1	0.00000000	b'pass lambda express elisp'
# THE TWEET IS: detect duplicate values in primitive java array
# THE PROCESSED TWEET IS: ['detect', 'duplic', 'valu', 'primit', 'java', 'array']
# 1	0.00000000	b'detect duplic valu primit java array'
# THE TWEET IS: convert base to image in python
# THE PROCESSED TWEET IS: ['convert', 'base', 'imag', 'python']
# 1	0.00000000	b'convert base imag python'
# THE TWEET IS: for loop randomly hanging on executefetchrequesterror
# THE PROCESSED TWEET IS: ['loop', 'randomli', 'hang', 'executefetchrequesterror']
# 1	0.00000000	b'loop randomli hang executefetchrequesterror'
# THE TWEET IS: how to generate a calling graph for c code
# THE PROCESSED TWEET IS: ['gener', 'call', 'graph', 'c', 'code']
# 1	0.00000000	b'gener call graph c code'
# THE TWEET IS: ef codefirst dropcreatedatabaseifmodelchanges doesnt work
# THE PROCESSED TWEET IS: ['ef', 'codefirst', 'dropcreatedatabaseifmodelchang', 'doesnt', 'work']
# 1	0.00000000	b'ef codefirst dropcreatedatabaseifmodelchang doesnt work'
# THE TWEET IS: css not negation pseudo class not fully supported by firefox
# THE PROCESSED TWEET IS: ['css', 'negat', 'pseudo', 'class', 'fulli', 'support', 'firefox']
# 1	0.00000000	b'css negat pseudo class fulli support firefox'
# THE TWEET IS: how to view a webpage stored in sdcard in android browser
# THE PROCESSED TWEET IS: ['view', 'webpag', 'store', 'sdcard', 'android', 'browser']
# 1	0.00000000	b'view webpag store sdcard android browser'
# THE TWEET IS: convert char to charxx
# THE PROCESSED TWEET IS: ['convert', 'char', 'charxx']
# 1	0.00000000	b'convert char charxx'
# THE TWEET IS: c variadic function in a c wrapper
# THE PROCESSED TWEET IS: ['c', 'variad', 'function', 'c', 'wrapper']
# 1	0.00000000	b'c variad function c wrapper'
# THE TWEET IS: true parallel processing in jbpm
# THE PROCESSED TWEET IS: ['true', 'parallel', 'process', 'jbpm']
# 0	0.99999986	b'true parallel process jbpm'
# THE TWEET IS: iphone  mthumb interlinking
# THE PROCESSED TWEET IS: ['iphon', 'mthumb', 'interlink']
# 0	0.51120982	b'iphon mthumb interlink'
# THE TWEET IS: iphone can i do audioservicesplaysystemsound looping with scheduler
# THE PROCESSED TWEET IS: ['iphon', 'audioservicesplaysystemsound', 'loop', 'schedul']
# 0	1.00000000	b'iphon audioservicesplaysystemsound loop schedul'
# THE TWEET IS: jquery yesconflict
# THE PROCESSED TWEET IS: ['jqueri', 'yesconflict']
# 0	0.51120982	b'jqueri yesconflict'
# THE TWEET IS: jython and implementing httpservletcontextinitialized
# THE PROCESSED TWEET IS: ['jython', 'implement', 'httpservletcontextiniti']
# 0	0.99999739	b'jython implement httpservletcontextiniti'
# THE TWEET IS: secure google authentication
# THE PROCESSED TWEET IS: ['secur', 'googl', 'authent']
# 0	0.51120982	b'secur googl authent'
# THE TWEET IS: which conveniences does cedet bring to dynamic languages
# THE PROCESSED TWEET IS: ['conveni', 'cedet', 'bring', 'dynam', 'languag']
# 0	0.99999891	b'conveni cedet bring dynam languag'
# THE TWEET IS: emacs vimpulse errors
# THE PROCESSED TWEET IS: ['emac', 'vimpuls', 'error']
# 0	0.51120982	b'emac vimpuls error'
# THE TWEET IS: normalising book titles   python
# THE PROCESSED TWEET IS: ['normalis', 'book', 'titl', 'python']
# 0	1.00000000	b'normalis book titl python'
# THE TWEET IS: fatalexecutionengineerror was detected
# THE PROCESSED TWEET IS: ['fatalexecutionengineerror', 'detect']
# 0	0.99955148	b'fatalexecutionengineerror detect'
# THE TWEET IS: how selectorgadget works
# THE PROCESSED TWEET IS: ['selectorgadget', 'work']
# 0	0.51120982	b'selectorgadget work'
# THE TWEET IS: ssrs vs   create a scale break in a line chart
# THE PROCESSED TWEET IS: ['ssr', 'vs', 'creat', 'scale', 'break', 'line', 'chart']
# 0	1.00000000	b'ssr vs creat scale break line chart'
# THE TWEET IS: change httpcontextrequestinputstream
# THE PROCESSED TWEET IS: ['chang', 'httpcontextrequestinputstream']
# 0	0.51120982	b'chang httpcontextrequestinputstream'
# THE TWEET IS: should receive in rspec
# THE PROCESSED TWEET IS: ['receiv', 'rspec']
# 0	1.00000000	b'receiv rspec'
# THE TWEET IS: validation is not working
# THE PROCESSED TWEET IS: ['valid', 'work']
# 0	0.51120982	b'valid work'
# THE TWEET IS: table not echoing out if another table has a zero value
# THE PROCESSED TWEET IS: ['tabl', 'echo', 'anoth', 'tabl', 'zero', 'valu']
# 0	0.99964044	b'tabl echo anoth tabl zero valu'
# THE TWEET IS: trouble with zeroclipboard
# THE PROCESSED TWEET IS: ['troubl', 'zeroclipboard']
# 0	0.51120982	b'troubl zeroclipboard'
# THE TWEET IS: min value from table
# THE PROCESSED TWEET IS: ['min', 'valu', 'tabl']
# 0	0.99999999	b'min valu tabl'
# THE TWEET IS: displaying query results horizontally
# THE PROCESSED TWEET IS: ['display', 'queri', 'result', 'horizont']
# 0	0.51120982	b'display queri result horizont'
# THE TWEET IS: r  bit for windows comparison
# THE PROCESSED TWEET IS: ['r', 'bit', 'window', 'comparison']
# 0	1.00000000	b'r bit window comparison'
# THE TWEET IS: when processor endian awareness is required
# THE PROCESSED TWEET IS: ['processor', 'endian', 'awar', 'requir']
# 0	1.00000000	b'processor endian awar requir'
# THE TWEET IS: advantage and disadvantage of smarty template
# THE PROCESSED TWEET IS: ['advantag', 'disadvantag', 'smarti', 'templat']
# 0	0.51120982	b'advantag disadvantag smarti templat'
# THE TWEET IS: basics of strings
# THE PROCESSED TWEET IS: ['basic', 'string']
# 0	0.51120982	b'basic string'
# THE TWEET IS: a good repartition algorithm
# THE PROCESSED TWEET IS: ['good', 'repartit', 'algorithm']
# 0	1.00000000	b'good repartit algorithm'
# THE TWEET IS: jstl vs old school jsp el conflict
# THE PROCESSED TWEET IS: ['jstl', 'vs', 'old', 'school', 'jsp', 'el', 'conflict']
# 0	1.00000000	b'jstl vs old school jsp el conflict'
# THE TWEET IS: axis using threadsleep to do blocking
# THE PROCESSED TWEET IS: ['axi', 'use', 'threadsleep', 'block']
# 0	0.99903607	b'axi use threadsleep block'
# THE TWEET IS: database modification or start over
# THE PROCESSED TWEET IS: ['databas', 'modif', 'start']
# 0	1.00000000	b'databas modif start'
# THE TWEET IS: additional python installed upon installing matplotlib with macports
# THE PROCESSED TWEET IS: ['addit', 'python', 'instal', 'upon', 'instal', 'matplotlib', 'macport']
# 0	1.00000000	b'addit python instal upon instal matplotlib macport'
# THE TWEET IS: iterate forward and then reverse over stl container
# THE PROCESSED TWEET IS: ['iter', 'forward', 'revers', 'stl', 'contain']
# 0	1.00000000	b'iter forward revers stl contain'
# THE TWEET IS: using multiple temporary tables in delphi with an ado connection to the database produces errors
# THE PROCESSED TWEET IS: ['use', 'multipl', 'temporari', 'tabl', 'delphi', 'ado', 'connect', 'databas', 'produc', 'error']
# 0	1.00000000	b'use multipl temporari tabl delphi ado connect databas produc error'
# THE TWEET IS: scripting alternatives for the iphone
# THE PROCESSED TWEET IS: ['script', 'altern', 'iphon']
# 0	0.99955148	b'script altern iphon'
# THE TWEET IS: glbufferdata fails silently with overly large sizes
# THE PROCESSED TWEET IS: ['glbufferdata', 'fail', 'silent', 'overli', 'larg', 'size']
# 0	0.51120982	b'glbufferdata fail silent overli larg size'
# THE TWEET IS: phpass autologin
# THE PROCESSED TWEET IS: ['phpass', 'autologin']
# 0	0.51120982	b'phpass autologin'
# THE TWEET IS: is systempos in delphi flawed
# THE PROCESSED TWEET IS: ['systempo', 'delphi', 'flaw']
# 0	1.00000000	b'systempo delphi flaw'
# THE TWEET IS: resizing catiledlayers using scale transforms vs bounds manipulation
# THE PROCESSED TWEET IS: ['resiz', 'catiledlay', 'use', 'scale', 'transform', 'vs', 'bound', 'manipul']
# 0	1.00000000	b'resiz catiledlay use scale transform vs bound manipul'
# THE TWEET IS: classifiers not working in maven snapshot repo for ivy
# THE PROCESSED TWEET IS: ['classifi', 'work', 'maven', 'snapshot', 'repo', 'ivi']
# 0	1.00000000	b'classifi work maven snapshot repo ivi'
# THE TWEET IS: not receiving response when using google checkout
# THE PROCESSED TWEET IS: ['receiv', 'respons', 'use', 'googl', 'checkout']
# 0	0.99999981	b'receiv respons use googl checkout'
# THE TWEET IS: python shell and execfile scope
# THE PROCESSED TWEET IS: ['python', 'shell', 'execfil', 'scope']
# 0	1.00000000	b'python shell execfil scope'
# THE TWEET IS: importing issues for products
# THE PROCESSED TWEET IS: ['import', 'issu', 'product']
# 0	0.99955148	b'import issu product'
# THE TWEET IS: as events dispatching and listening
# THE PROCESSED TWEET IS: ['event', 'dispatch', 'listen']
# 0	0.51120982	b'event dispatch listen'
# THE TWEET IS: using cloned git repo instead of gem
# THE PROCESSED TWEET IS: ['use', 'clone', 'git', 'repo', 'instead', 'gem']
# 0	1.00000000	b'use clone git repo instead gem'
# THE TWEET IS: too many database calls
# THE PROCESSED TWEET IS: ['mani', 'databas', 'call']
# 0	0.51120982	b'mani databas call'
# THE TWEET IS: what is bundle identifier for dreamweaver
# THE PROCESSED TWEET IS: ['bundl', 'identifi', 'dreamweav']
# 0	0.99999931	b'bundl identifi dreamweav'
# THE TWEET IS: replacing images inplace
# THE PROCESSED TWEET IS: ['replac', 'imag', 'inplac']
# 0	0.99955148	b'replac imag inplac'
# THE TWEET IS: requiredasset validation attribute
# THE PROCESSED TWEET IS: ['requiredasset', 'valid', 'attribut']
# 0	0.51120982	b'requiredasset valid attribut'
# THE TWEET IS: hibernate executed queries and testing
# THE PROCESSED TWEET IS: ['hibern', 'execut', 'queri', 'test']
# 0	0.51120982	b'hibern execut queri test'
# THE TWEET IS: xxd binary dump problems
# THE PROCESSED TWEET IS: ['xxd', 'binari', 'dump', 'problem']
# 0	0.73722274	b'xxd binari dump problem'
# THE TWEET IS: wait  signal order
# THE PROCESSED TWEET IS: ['wait', 'signal', 'order']
# 0	0.99894156	b'wait signal order'
# THE TWEET IS: copy constructor with reference variable
# THE PROCESSED TWEET IS: ['copi', 'constructor', 'refer', 'variabl']
# 0	1.00000000	b'copi constructor refer variabl'
# THE TWEET IS: benefits and drawbacks for caanimationgroup vs cakeyframeanimation
# THE PROCESSED TWEET IS: ['benefit', 'drawback', 'caanimationgroup', 'vs', 'cakeyframeanim']
# 0	1.00000000	b'benefit drawback caanimationgroup vs cakeyframeanim'
# THE TWEET IS: where to instantiate interface in nunit test
# THE PROCESSED TWEET IS: ['instanti', 'interfac', 'nunit', 'test']
# 0	1.00000000	b'instanti interfac nunit test'
# THE TWEET IS: sending an email with python using the smtp library
# THE PROCESSED TWEET IS: ['send', 'email', 'python', 'use', 'smtp', 'librari']
# 0	1.00000000	b'send email python use smtp librari'
# THE TWEET IS: loading animated images to start from the beginning of animation using jquery
# THE PROCESSED TWEET IS: ['load', 'anim', 'imag', 'start', 'begin', 'anim', 'use', 'jqueri']
# 0	1.00000000	b'load anim imag start begin anim use jqueri'
# THE TWEET IS: showingadding trs dynamically
# THE PROCESSED TWEET IS: ['showingad', 'tr', 'dynam']
# 0	0.51120982	b'showingad tr dynam'
# THE TWEET IS: iphone   preventing attachments from showing
# THE PROCESSED TWEET IS: ['iphon', 'prevent', 'attach', 'show']
# 0	0.51120982	b'iphon prevent attach show'
# THE TWEET IS: retrieving links using jquery
# THE PROCESSED TWEET IS: ['retriev', 'link', 'use', 'jqueri']
# 0	0.51120982	b'retriev link use jqueri'
# THE TWEET IS: analog and digital graph
# THE PROCESSED TWEET IS: ['analog', 'digit', 'graph']
# 0	0.99938042	b'analog digit graph'
# THE TWEET IS: localized version of getfiletitle
# THE PROCESSED TWEET IS: ['local', 'version', 'getfiletitl']
# 0	0.99999040	b'local version getfiletitl'
# THE TWEET IS: iphone nsurlconnection delegates
# THE PROCESSED TWEET IS: ['iphon', 'nsurlconnect', 'deleg']
# 0	0.51120982	b'iphon nsurlconnect deleg'
# THE TWEET IS: installdir on silent installation
# THE PROCESSED TWEET IS: ['installdir', 'silent', 'instal']
# 0	1.00000000	b'installdir silent instal'
# THE TWEET IS: coffeescript classes  zeptojs
# THE PROCESSED TWEET IS: ['coffeescript', 'class', 'zeptoj']
# 0	0.98681045	b'coffeescript class zeptoj'
# THE TWEET IS: saving pendingintents
# THE PROCESSED TWEET IS: ['save', 'pendingint']
# 0	0.51120982	b'save pendingint'
# THE TWEET IS: lucene  features
# THE PROCESSED TWEET IS: ['lucen', 'featur']
# 0	0.51120982	b'lucen featur'
# THE TWEET IS: uilocalnotification and ios
# THE PROCESSED TWEET IS: ['uilocalnotif', 'io']
# 0	0.51120982	b'uilocalnotif io'
# THE TWEET IS: why are my utf  filenames in bugzilla downloading as quoted printable filenames
# THE PROCESSED TWEET IS: ['utf', 'filenam', 'bugzilla', 'download', 'quot', 'printabl', 'filenam']
# 0	0.99999999	b'utf filenam bugzilla download quot printabl filenam'
# THE TWEET IS: is papervision d development alive
# THE PROCESSED TWEET IS: ['papervis', 'develop', 'aliv']
# 0	0.51120982	b'papervis develop aliv'
# THE TWEET IS: disable eclipse validators
# THE PROCESSED TWEET IS: ['disabl', 'eclips', 'valid']
# 0	0.51120982	b'disabl eclips valid'
# THE TWEET IS: git   shorthand for hashes not working
# THE PROCESSED TWEET IS: ['git', 'shorthand', 'hash', 'work']
# 0	1.00000000	b'git shorthand hash work'
# THE TWEET IS: linker issue with boost python on xcode
# THE PROCESSED TWEET IS: ['linker', 'issu', 'boost', 'python', 'xcode']
# 0	1.00000000	b'linker issu boost python xcode'
# THE TWEET IS: with maven  should dependencies be redeclared if they are accessible transitively
# THE PROCESSED TWEET IS: ['maven', 'depend', 'redeclar', 'access', 'transit']
# 0	1.00000000	b'maven depend redeclar access transit'
# THE TWEET IS: fixed sidebar for navigation in website
# THE PROCESSED TWEET IS: ['fix', 'sidebar', 'navig', 'websit']
# 0	0.99992221	b'fix sidebar navig websit'
# THE TWEET IS: passing parameters cleanly
# THE PROCESSED TWEET IS: ['pass', 'paramet', 'cleanli']
# 0	0.51120982	b'pass paramet cleanli'
# THE TWEET IS: where do i start optimizing the jvm
# THE PROCESSED TWEET IS: ['start', 'optim', 'jvm']
# 0	1.00000000	b'start optim jvm'
# THE TWEET IS: maskedtextbox minimummaximum lengths
# THE PROCESSED TWEET IS: ['maskedtextbox', 'minimummaximum', 'length']
# 0	0.51120982	b'maskedtextbox minimummaximum length'
# THE TWEET IS: for vs while loop
# THE PROCESSED TWEET IS: ['vs', 'loop']
# 0	1.00000000	b'vs loop'
# THE TWEET IS: matching closest longitudelatitude
# THE PROCESSED TWEET IS: ['match', 'closest', 'longitudelatitud']
# 0	0.99999991	b'match closest longitudelatitud'
# THE TWEET IS: is it okpossible to modify instance variables inside an enum declaration
# THE PROCESSED TWEET IS: ['okposs', 'modifi', 'instanc', 'variabl', 'insid', 'enum', 'declar']
# 0	1.00000000	b'okposs modifi instanc variabl insid enum declar'
# THE TWEET IS: is this vulnerable to a stack overflow
# THE PROCESSED TWEET IS: ['vulner', 'stack', 'overflow']
# 0	1.00000000	b'vulner stack overflow'
# THE TWEET IS: problems setting up git with github
# THE PROCESSED TWEET IS: ['problem', 'set', 'git', 'github']
# 0	1.00000000	b'problem set git github'
# THE TWEET IS: ctframegetvisiblestringrange equivalent for ios programming
# THE PROCESSED TWEET IS: ['ctframegetvisiblestringrang', 'equival', 'io', 'program']
# 0	0.99955148	b'ctframegetvisiblestringrang equival io program'
# THE TWEET IS: multiple geographical regions or multiple markets
# THE PROCESSED TWEET IS: ['multipl', 'geograph', 'region', 'multipl', 'market']
# 0	0.51120982	b'multipl geograph region multipl market'

# %% [markdown]
# Later in this specialization, we will see how we can use deep learning to improve the prediction performance.

# %% [markdown]
# # Part 6: Predict with your own tweet

# %%
# Feel free to change the tweet below
my_tweet = 'please, tell me more. I want to know more'
print(process_tweet(my_tweet))
y_hat = predict_tweet(my_tweet, freqs, theta)
print(y_hat)
if y_hat > 0.5:
    print('Positive sentiment')
else: 
    print('Negative sentiment')
# Out:
# ['pleas', 'tell', 'want', 'know']
# [[0.]]
# Negative sentiment
# C:\Users\Bull\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: overflow encountered in exp
#   if sys.path[0] == '':
