# %% [markdown]
# # Assignment 2: Naive Bayes
# Welcome to week two of this specialization. You will learn about Naive Bayes. Concretely, you will be using Naive Bayes for sentiment analysis on tweets. Given a tweet, you will decide if it has a positive sentiment or a negative one. Specifically you will:
#
# * Train a naive bayes model on a sentiment analysis task
# * Test using your model
# * Compute ratios of positive words to negative words
# * Do some error analysis
# * Predict on your own tweet
#
# You may already be familiar with Naive Bayes and its justification in terms of conditional probabilities and independence.
# * In this week's lectures and assignments we used the ratio of probabilities between positive and negative sentiments.
# * This approach gives us simpler formulas for these 2-way classification tasks.
#
# Load the cell below to import some packages.
# You  may want to browse the documentation of unfamiliar libraries and functions.

# %%
from utils_model_bayes import process_tweet, lookup
import pdb
from nltk.corpus import stopwords, twitter_samples
import numpy as np
import pandas as pd
import nltk
import string
from nltk.tokenize import TweetTokenizer
from os import getcwd
import csv
import re

# %% [markdown]
# If you are running this notebook in your local computer,
# don't forget to download the twitter samples and stopwords from nltk.
#
# ```
# nltk.download('stopwords')
# nltk.download('twitter_samples')
# ```

# %%
# add folder, tmp2, from our local workspace containing pre-downloaded corpora files to nltk's data path
filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
#Iterator for given file
def iterate_file(file_path):
    with open(file_path, "r", encoding = 'utf8') as f:
        reader = csv.DictReader(f, delimiter=",")
        for row in reader:
            yield row

#Clean sentence (remove non alpha chars)
p = re.compile(r'<.*?>')
def cleanSentence(sentence):    
    sentence = p.sub('', sentence) 
    sentence = ''.join([i.lower() if i.isalpha() else " " if (i==" " or i=="-" or i=="_") else "" for i in sentence])
    return sentence
            
def load_questions(file_path, n=float("inf")):
    positive_questions = []
    negative_questions = []
    cont = 0
    tags =""
    for row in iterate_file(file_path):
        cont += 1 
        if cont %100000==0:
            print("load question idx:",cont)
            print("tags:", tags)

        tags = "".join(" "+tag for tag in row["tags"].split("|"))
#         time = row["creation_date"][10:14]
        sentence = cleanSentence(row["title"]) +" "+tags#+" "+cleanSentence(row["body"]) 
        

        words = sentence.split(" ")
        if float(row["stars"])>= 3.0:
            positive_questions.append(sentence)
        else:
            negative_questions.append(sentence)
        if cont==n:
            break
    
    return positive_questions, negative_questions

#OVERWRITE process_tweet FUNCTION
def process_tweet(s):
    return s.split()

train_pos, train_neg = load_questions("data_english_heavy_train.csv") #
test_pos, test_neg = load_questions("data_english_heavy_test.csv") # 

# print(train_pos[0:20])
for example in train_pos[0:20]:
    print(example)
print("positive tweets:", len(train_pos))
print("negative tweets:", len(train_neg))
# Out:
# when do i use can or could  word-choice tenses politeness subjunctive-mood can-could
# where does the quint in quintessential come from  meaning etymology
# when did while and whilst become interchangeable  word-choice etymology differences conjunctions historical-change
# may  might whats the right context  word-choice grammar modal-verbs auxiliary-verbs
# is it appropriate to use short form of have ve when it means possession  verbs contractions auxiliary-verbs
# which words in a title should be capitalized  capitalization titles headline-case
# when is it appropriate to end a sentence in a preposition  grammaticality prepositions word-order sentence-ends pied-piping
# where did the term okokay come from  etymology
# what is the proper plural of the word freshman  grammatical-number american-english north-american-english
# where did the singular innings come from  grammatical-number sports
# are betwixt trebble etc acceptable in american english  american-english british-english formality
# is it ever acceptable for a period to come after a quote at the end of a sentence  punctuation quotation-marks period
# whats wrong inwith this question  word-choice grammaticality prepositions
# is there a correct gender neutral singular pronoun his vs her vs their  word-choice possessives personal-pronouns singular-they gender-neutral
# can a word be contracted twice eg ivent  punctuation apostrophe pronunciation-vs-spelling contractions
# whats the rule for using who and whom correctly  pronouns grammatical-case relative-pronouns questions whom
# how do i ask a question politely  modal-verbs politeness
# when to use that and when to use which especially in relative clauses  pronouns conjunctions relative-clauses which-that relative-pronouns
# is it acceptable to start a sentence with however  grammaticality word-order conjunctions sentence-starts discourse-markers
# how does one correctly use a semicolon  punctuation semicolon
# positive tweets: 47463
# negative tweets: 50064

# %%
# # get the sets of positive and negative tweets
# all_positive_tweets = twitter_samples.strings('positive_tweets.json')
# all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# # split the data into two pieces, one for training and one for testing (validation set)
# test_pos = all_positive_tweets[4000:]
# train_pos = all_positive_tweets[:4000]
# test_neg = all_negative_tweets[4000:]
# train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# avoid assumptions about the length of all_positive_tweets
train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %% [markdown]
# # Part 1: Process the Data
#
# For any machine learning project, once you've gathered the data, the first step is to process it to make useful inputs to your model.
# - **Remove noise**: You will first want to remove noise from your data -- that is, remove words that don't tell you much about the content. These include all common words like 'I, you, are, is, etc...' that would not give us enough information on the sentiment.
# - We'll also remove stock market tickers, retweet symbols, hyperlinks, and hashtags because they can not tell you a lot of information on the sentiment.
# - You also want to remove all the punctuation from a tweet. The reason for doing this is because we want to treat words with or without the punctuation as the same word, instead of treating "happy", "happy?", "happy!", "happy," and "happy." as different words.
# - Finally you want to use stemming to only keep track of one variation of each word. In other words, we'll treat "motivation", "motivated", and "motivate" similarly by grouping them within the same stem of "motiv-".
#
# We have given you the function `process_tweet()` that does this for you.

# %%
custom_tweet = "RT @Twitter @chapagain Hello There! Have a great day. :) #good++ #morning http://chapagain.com.np"

# print cleaned tweet
print(process_tweet(custom_tweet))
# Out:
# ['RT', '@Twitter', '@chapagain', 'Hello', 'There!', 'Have', 'a', 'great', 'day.', ':)', '#good++', '#morning', 'http://chapagain.com.np']

# %% [markdown]
# ## Part 1.1 Implementing your helper functions
#
# To help train your naive bayes model, you will need to build a dictionary where the keys are a (word, label) tuple and the values are the corresponding frequency.  Note that the labels we'll use here are 1 for positive and 0 for negative.
#
# You will also implement a `lookup()` helper function that takes in the `freqs` dictionary, a word, and a label (1 or 0) and returns the number of times that word and label tuple appears in the collection of tweets.
#
# For example: given a list of tweets `["i am rather excited", "you are rather happy"]` and the label 1, the function will return a dictionary that contains the following key-value pairs:
#
# {
#     ("rather", 1): 2
#     ("happi", 1) : 1
#     ("excit", 1) : 1
# }
#
# - Notice how for each word in the given string, the same label 1 is assigned to each word.
# - Notice how the words "i" and "am" are not saved, since it was removed by process_tweet because it is a stopword.
# - Notice how the word "rather" appears twice in the list of tweets, and so its count value is 2.
#
# #### Instructions
# Create a function `count_tweets()` that takes a list of tweets as input, cleans all of them, and returns a dictionary.
# - The key in the dictionary is a tuple containing the stemmed word and its class label, e.g. ("happi",1).
# - The value the number of times this word appears in the given collection of tweets (an integer).

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Please use the `process_tweet` function that was imported above, and then store the words in their respective dictionaries and sets.</li>
#     <li>You may find it useful to use the `zip` function to match each element in `tweets` with each element in `ys`.</li>
#     <li>Remember to check if the key in the dictionary exists before adding that key to the dictionary, or incrementing its value.</li>
#     <li>Assume that the `result` dictionary that is input will contain clean key-value pairs (you can assume that the values will be integers that can be incremented).  It is good practice to check the datatype before incrementing the value, but it's not required here.</li>
# </ul>
# </p>

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def count_tweets(result, tweets, ys):
    '''
    Input:
        result: a dictionary that will be used to map each pair to its frequency
        tweets: a list of tweets
        ys: a list corresponding to the sentiment of each tweet (either 0 or 1)
    Output:
        result: a dictionary mapping each pair to its frequency
    '''

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    for y, tweet in zip(ys, tweets):
        for word in process_tweet(tweet):
            # define the key, which is the word and label tuple
            pair = (word, y)

            # if the key exists in the dictionary, increment the count
            if pair in result:
                result[pair] += 1

            # else, if the key is new, add it to the dictionary and set the count to 1
            else:
                result[pair] = 1
    ### END CODE HERE ###

    return result

# %%
# Testing your function


result = {}
tweets = ['i am happy', 'i am tricked', 'i am sad', 'i am tired', 'i am tired']
ys = [1, 0, 0, 0, 0]
count_tweets(result, tweets, ys)
# Out:
# {('i', 1): 1,
#  ('am', 1): 1,
#  ('happy', 1): 1,
#  ('i', 0): 4,
#  ('am', 0): 4,
#  ('tricked', 0): 1,
#  ('sad', 0): 1,
#  ('tired', 0): 2}

# %% [markdown]
# **Expected Output**: {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %% [markdown]
# # Part 2: Train your model using Naive Bayes
#
# Naive bayes is an algorithm that could be used for sentiment analysis. It takes a short time to train and also has a short prediction time.
#
# #### So how do you train a Naive Bayes classifier?
# - The first part of training a naive bayes classifier is to identify the number of classes that you have.
# - You will create a probability for each class.
# $P(D_{pos})$ is the probability that the document is positive.
# $P(D_{neg})$ is the probability that the document is negative.
# Use the formulas as follows and store the values in a dictionary:
#
# $$P(D_{pos}) = \frac{D_{pos}}{D}\tag{1}$$
#
# $$P(D_{neg}) = \frac{D_{neg}}{D}\tag{2}$$
#
# Where $D$ is the total number of documents, or tweets in this case, $D_{pos}$ is the total number of positive tweets and $D_{neg}$ is the total number of negative tweets.

# %% [markdown]
# #### Prior and Logprior
#
# The prior probability represents the underlying probability in the target population that a tweet is positive versus negative.  In other words, if we had no specific information and blindly picked a tweet out of the population set, what is the probability that it will be positive versus that it will be negative? That is the "prior".
#
# The prior is the ratio of the probabilities $\frac{P(D_{pos})}{P(D_{neg})}$.
# We can take the log of the prior to rescale it, and we'll call this the logprior
#
# $$\text{logprior} = log \left( \frac{P(D_{pos})}{P(D_{neg})} \right) = log \left( \frac{D_{pos}}{D_{neg}} \right)$$.
#
# Note that $log(\frac{A}{B})$ is the same as $log(A) - log(B)$.  So the logprior can also be calculated as the difference between two logs:
#
# $$\text{logprior} = \log (P(D_{pos})) - \log (P(D_{neg})) = \log (D_{pos}) - \log (D_{neg})\tag{3}$$

# %% [markdown]
# #### Positive and Negative Probability of a Word
# To compute the positive probability and the negative probability for a specific word in the vocabulary, we'll use the following inputs:
#
# - $freq_{pos}$ and $freq_{neg}$ are the frequencies of that specific word in the positive or negative class. In other words, the positive frequency of a word is the number of times the word is counted with the label of 1.
# - $N_{pos}$ and $N_{neg}$ are the total number of positive and negative words for all documents (for all tweets), respectively.
# - $V$ is the number of unique words in the entire set of documents, for all classes, whether positive or negative.
#
# We'll use these to compute the positive and negative probability for a specific word using this formula:
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# Notice that we add the "+1" in the numerator for additive smoothing.  This [wiki article](https://en.wikipedia.org/wiki/Additive_smoothing) explains more about additive smoothing.

# %% [markdown]
# #### Log likelihood
# To compute the loglikelihood of that very same word, we can implement the following equations:
#
# $$\text{loglikelihood} = \log \left(\frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$$

# %% [markdown]
# ##### Create `freqs` dictionary
# - Given your `count_tweets()` function, you can compute a dictionary called `freqs` that contains all the frequencies.
# - In this `freqs` dictionary, the key is the tuple (word, label)
# - The value is the number of times it has appeared.
#
# We will use this dictionary in several parts of this assignment.

# %%
# Build the freqs dictionary for later uses

freqs = count_tweets({}, train_x, train_y)

# %% [markdown]
# #### Instructions
# Given a freqs dictionary, `train_x` (a list of tweets) and a `train_y` (a list of labels for each tweet), implement a naive bayes classifier.
#
# ##### Calculate $V$
# - You can then compute the number of unique words that appear in the `freqs` dictionary to get your $V$ (you can use the `set` function).
#
# ##### Calculate $freq_{pos}$ and $freq_{neg}$
# - Using your `freqs` dictionary, you can compute the positive and negative frequency of each word $freq_{pos}$ and $freq_{neg}$.
#
# ##### Calculate $N_{pos}$ and $N_{neg}$
# - Using `freqs` dictionary, you can also compute the total number of positive words and total number of negative words $N_{pos}$ and $N_{neg}$.
#
# ##### Calculate $D$, $D_{pos}$, $D_{neg}$
# - Using the `train_y` input list of labels, calculate the number of documents (tweets) $D$, as well as the number of positive documents (tweets) $D_{pos}$ and number of negative documents (tweets) $D_{neg}$.
# - Calculate the probability that a document (tweet) is positive $P(D_{pos})$, and the probability that a document (tweet) is negative $P(D_{neg})$
#
# ##### Calculate the logprior
# - the logprior is $log(D_{pos}) - log(D_{neg})$
#
# ##### Calculate log likelihood
# - Finally, you can iterate over each word in the vocabulary, use your `lookup` function to get the positive frequencies, $freq_{pos}$, and the negative frequencies, $freq_{neg}$, for that specific word.
# - Compute the positive probability of each word $P(W_{pos})$, negative probability of each word $P(W_{neg})$ using equations 4 & 5.
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# **Note:** We'll use a dictionary to store the log likelihoods for each word.  The key is the word, the value is the log likelihood of that word).
#
# - You can then compute the loglikelihood: $log \left( \frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$.

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def train_naive_bayes(freqs, train_x, train_y):
    '''
    Input:
        freqs: dictionary from (word, label) to how often the word appears
        train_x: a list of tweets
        train_y: a list of labels correponding to the tweets (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    loglikelihood = {}
    logprior = 0

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###

    # calculate V, the number of unique words in the vocabulary
    vocab = set([pair[0] for pair in freqs.keys()])
    V = len(vocab)

    # calculate N_pos and N_neg
    N_pos = N_neg = 0
    for pair in freqs.keys():
        # if the label is positive (greater than zero)
        if pair[1] > 0:

            # Increment the number of positive words by the count for this (word, label) pair
            N_pos += freqs[pair]

        # else, the label is negative
        else:

            # increment the number of negative words by the count for this (word,label) pair
            N_neg += freqs[pair]

    # Calculate D, the number of documents
    D = len(train_x)

    # Calculate D_pos, the number of positive documents (*hint: use sum(<np_array>))
    D_pos = sum(train_y)

    # Calculate D_neg, the number of negative documents (*hint: compute using D and D_pos)
    D_neg = D-D_pos

    # Calculate logprior
    logprior = np.log(D_pos) - np.log(D_neg)

    # For each word in the vocabulary...
    for word in vocab:
        # get the positive and negative frequency of the word
        freq_pos = freqs.get((word, 1.0),0)
        freq_neg = freqs.get((word, 0.0),0)

        # calculate the probability that each word is positive, and negative
        p_w_pos = (freq_pos+1)/(N_pos+V)
        p_w_neg = (freq_neg+1)/(N_neg+V)

        # calculate the log likelihood of the word
        loglikelihood[word] = np.log(p_w_pos/p_w_neg)

    ### END CODE HERE ###

    return logprior, loglikelihood

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)
print(logprior)
print(len(loglikelihood))
# Out:
# -0.05335172679149025
# 37316

# %% [markdown]
# **Expected Output**:
#
# 0.0
#
# 9089

# %% [markdown]
# # Part 3: Test your naive bayes
#
# Now that we have the `logprior` and `loglikelihood`, we can test the naive bayes function by making predicting on some tweets!
#
# #### Implement `naive_bayes_predict`
# **Instructions**:
# Implement the `naive_bayes_predict` function to make predictions on tweets.
# * The function takes in the `tweet`, `logprior`, `loglikelihood`.
# * It returns the probability that the tweet belongs to the positive or negative class.
# * For each tweet, sum up loglikelihoods of each word in the tweet.
# * Also add the logprior to this sum to get the predicted sentiment of that tweet.
#
# $$ p = logprior + \sum_i^N (loglikelihood_i)$$
#
# #### Note
# Note we calculate the prior from the training data, and that the training data is evenly split between positive and negative labels (4000 positive and 4000 negative tweets).  This means that the ratio of positive to negative 1, and the logprior is 0.
#
# The value of 0.0 means that when we add the logprior to the log likelihood, we're just adding zero to the log likelihood.  However, please remember to include the logprior, because whenever the data is not perfectly balanced, the logprior will be a non-zero value.

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    Input:
        tweet: a string
        logprior: a number
        loglikelihood: a dictionary of words mapping to numbers
    Output:
        p: the sum of all the logliklihoods of each word in the tweet (if found in the dictionary) + logprior (a number)

    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # process the tweet to get a list of words
    word_l = process_tweet(tweet)

    # initialize probability to zero
    p = 0

    # add the logprior
    p += logprior

    for word in word_l:

        # check if the word exists in the loglikelihood dictionary
        if word in loglikelihood:
            # add the log likelihood of that word to the probability
            p += loglikelihood[word]

    ### END CODE HERE ###

    return p

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# Experiment with your own tweet.
my_tweet = 'She smiled.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is -0.05335172679149025

# %% [markdown]
# **Expected Output**:
# - The expected output is around 1.57
# - The sentiment is positive.

# %% [markdown]
# #### Implement test_naive_bayes
# **Instructions**:
# * Implement `test_naive_bayes` to check the accuracy of your predictions.
# * The function takes in your `test_x`, `test_y`, log_prior, and loglikelihood
# * It returns the accuracy of your model.
# * First, use `naive_bayes_predict` function to make predictions for each tweet in text_x.

# %%
# UNQ_C6 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    """
    Input:
        test_x: A list of tweets
        test_y: the corresponding labels for the list of tweets
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    Output:
        accuracy: (# of tweets classified correctly)/(total # of tweets)
    """
    accuracy = 0  # return this properly

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    y_hats = []
    for tweet in test_x:
        # if the prediction is > 0
        if naive_bayes_predict(tweet, logprior, loglikelihood) > 0:
            # the predicted class is 1
            y_hat_i = 1
        else:
            # otherwise the predicted class is 0
            y_hat_i = 0

        # append the predicted class to the list y_hats
        y_hats.append(y_hat_i)

    # error is the average of the absolute values of the differences between y_hats and test_y
    error = np.sum(np.array(y_hats)!=test_y)/len(y_hats)

    # Accuracy is 1 minus the error
    accuracy = 1-error
    
    print("percentage positive predictions:", sum(y_hats)/len(y_hats))
    
    ### END CODE HERE ###

    return accuracy

# %%
print("Naive Bayes accuracy = %0.4f" %
      (test_naive_bayes(test_x, test_y, logprior, loglikelihood)))
# Out:
# percentage positive predictions: 0.4560723514211886
# Naive Bayes accuracy = 0.6059

# %% [markdown]
# **Expected Accuracy**:
#
# 0.9940

# %%
# UNQ_C7 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    # print( '%s -> %f' % (tweet, naive_bayes_predict(tweet, logprior, loglikelihood)))
    p = naive_bayes_predict(tweet, logprior, loglikelihood)
#     print(f'{tweet} -> {p:.2f} ({p_category})')
    print(f'{tweet} -> {p:.2f}')
# Out:
# I am happy -> 0.02
# I am bad -> -0.32
# this movie should have been great. -> -1.27
# great -> -0.83
# great great -> -1.44
# great great great -> -2.06
# great great great great -> -2.67

# %% [markdown]
# **Expected Output**:
# - I am happy -> 2.15
# - I am bad -> -1.29
# - this movie should have been great. -> 2.14
# - great -> 2.14
# - great great -> 4.28
# - great great great -> 6.41
# - great great great great -> 8.55

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'I like how my balls touch each other in the morning'
naive_bayes_predict(my_tweet, logprior, loglikelihood)
# Out:
# 0.10564206564107259

# %% [markdown]
# # Part 4: Filter words by Ratio of positive to negative counts
#
# - Some words have more positive counts than others, and can be considered "more positive".  Likewise, some words can be considered more negative than others.
# - One way for us to define the level of positiveness or negativeness, without calculating the log likelihood, is to compare the positive to negative frequency of the word.
#     - Note that we can also use the log likelihood calculations to compare relative positivity or negativity of words.
# - We can calculate the ratio of positive to negative frequencies of a word.
# - Once we're able to calculate these ratios, we can also filter a subset of words that have a minimum ratio of positivity / negativity or higher.
# - Similarly, we can also filter a subset of words that have a maximum ratio of positivity / negativity or lower (words that are at least as negative, or even more negative than a given threshold).
#
# #### Implement `get_ratio()`
# - Given the `freqs` dictionary of words and a particular word, use `lookup(freqs,word,1)` to get the positive count of the word.
# - Similarly, use the `lookup()` function to get the negative count of that word.
# - Calculate the ratio of positive divided by negative counts
#
# $$ ratio = \frac{\text{pos_words} + 1}{\text{neg_words} + 1} $$
#
# Where pos_words and neg_words correspond to the frequency of the words in their respective classes.
# <table>
#     <tr>
#         <td>
#             <b>Words</b>
#         </td>
#         <td>
#         Positive word count
#         </td>
#          <td>
#         Negative Word Count
#         </td>
#   </tr>
#     <tr>
#         <td>
#         glad
#         </td>
#          <td>
#         41
#         </td>
#     <td>
#         2
#         </td>
#   </tr>
#     <tr>
#         <td>
#         arriv
#         </td>
#          <td>
#         57
#         </td>
#     <td>
#         4
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :(
#         </td>
#          <td>
#         1
#         </td>
#     <td>
#         3663
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :-(
#         </td>
#          <td>
#         0
#         </td>
#     <td>
#         378
#         </td>
#   </tr>
# </table>

# %%
# UNQ_C8 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def get_ratio(freqs, word):
    '''
    Input:
        freqs: dictionary containing the words
        word: string to lookup

    Output: a dictionary with keys 'positive', 'negative', and 'ratio'.
        Example: {'positive': 10, 'negative': 20, 'ratio': 0.5}
    '''
    pos_neg_ratio = {'positive': 0, 'negative': 0, 'ratio': 0.0}
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # use lookup() to find positive counts for the word (denoted by the integer 1)
    pos_neg_ratio['positive'] = lookup(freqs,word,1)

    # use lookup() to find negative counts for the word (denoted by integer 0)
    pos_neg_ratio['negative'] = lookup(freqs,word,0)

    # calculate the ratio of positive to negative counts for the word
    pos_neg_ratio['ratio'] = (pos_neg_ratio["positive"]+1)/(pos_neg_ratio["negative"]+1)
    ### END CODE HERE ###
    return pos_neg_ratio

# %%
get_ratio(freqs, 'happi')
# Out:
# {'positive': 0, 'negative': 0, 'ratio': 1.0}

# %% [markdown]
# #### Implement `get_words_by_threshold(freqs,label,threshold)`
#
# * If we set the label to 1, then we'll look for all words whose threshold of positive/negative is at least as high as that threshold, or higher.
# * If we set the label to 0, then we'll look for all words whose threshold of positive/negative is at most as low as the given threshold, or lower.
# * Use the `get_ratio()` function to get a dictionary containing the positive count, negative count, and the ratio of positive to negative counts.
# * Append a dictionary to a list, where the key is the word, and the dictionary is the dictionary `pos_neg_ratio` that is returned by the `get_ratio()` function.
# An example key-value pair would have this structure:
# ```
# {'happi':
#     {'positive': 10, 'negative': 20, 'ratio': 0.5}
# }
# ```

# %%
# UNQ_C9 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def get_words_by_threshold(freqs, label, threshold):
    '''
    Input:
        freqs: dictionary of words
        label: 1 for positive, 0 for negative
        threshold: ratio that will be used as the cutoff for including a word in the returned dictionary
    Output:
        word_set: dictionary containing the word and information on its positive count, negative count, and ratio of positive to negative counts.
        example of a key value pair:
        {'happi':
            {'positive': 10, 'negative': 20, 'ratio': 0.5}
        }
    '''
    word_list = {}

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    for key in freqs.keys():
        word, _ = key

        # get the positive/negative ratio for a word
        pos_neg_ratio = get_ratio(freqs, word)

        # if the label is 1 and the ratio is greater than or equal to the threshold...
        if label == 1 and pos_neg_ratio["ratio"]>=threshold:

            # Add the pos_neg_ratio to the dictionary
            word_list[word]=pos_neg_ratio

        # If the label is 0 and the pos_neg_ratio is less than or equal to the threshold...
        elif label == 0 and pos_neg_ratio["ratio"]<=threshold:

            # Add the pos_neg_ratio to the dictionary
            word_list[word]=pos_neg_ratio

        # otherwise, do not include this word in the list (do nothing)

    ### END CODE HERE ###
    return word_list

# %%
# Test your function: find negative words at or below a threshold
get_words_by_threshold(freqs, label=0, threshold=0.05)
# Out:
# {'virtuemart': {'positive': 0, 'negative': 23, 'ratio': 0.041666666666666664}}

# %%
# Test your function; find positive words at or above a threshold
get_words_by_threshold(freqs, label=1, threshold=10)
# Out:
# {'pip': {'positive': 21, 'negative': 1, 'ratio': 11.0},
#  'imaging': {'positive': 10, 'negative': 0, 'ratio': 11.0},
#  'datasnap': {'positive': 9, 'negative': 0, 'ratio': 10.0},
#  'gitignore': {'positive': 12, 'negative': 0, 'ratio': 13.0},
#  'scalatest': {'positive': 10, 'negative': 0, 'ratio': 11.0},
#  'ghci': {'positive': 13, 'negative': 0, 'ratio': 14.0},
#  'mnesia': {'positive': 9, 'negative': 0, 'ratio': 10.0},
#  'beamer': {'positive': 11, 'negative': 0, 'ratio': 12.0},
#  'decltype': {'positive': 11, 'negative': 0, 'ratio': 12.0},
#  'proguard': {'positive': 24, 'negative': 0, 'ratio': 25.0},
#  'joda': {'positive': 9, 'negative': 0, 'ratio': 10.0},
#  'upsert': {'positive': 12, 'negative': 0, 'ratio': 13.0},
#  'implicit-conversion': {'positive': 9, 'negative': 0, 'ratio': 10.0},
#  'moose': {'positive': 11, 'negative': 0, 'ratio': 12.0},
#  'cabal': {'positive': 17, 'negative': 0, 'ratio': 18.0},
#  'memset': {'positive': 10, 'negative': 0, 'ratio': 11.0},
#  'multiprocessing': {'positive': 25, 'negative': 1, 'ratio': 13.0},
#  'keytool': {'positive': 10, 'negative': 0, 'ratio': 11.0},
#  'jvisualvm': {'positive': 9, 'negative': 0, 'ratio': 10.0},
#  'flask': {'positive': 22, 'negative': 0, 'ratio': 23.0},
#  'leiningen': {'positive': 10, 'negative': 0, 'ratio': 11.0},
#  'wlst': {'positive': 9, 'negative': 0, 'ratio': 10.0},
#  'dbpedia': {'positive': 17, 'negative': 0, 'ratio': 18.0},
#  'tastypie': {'positive': 10, 'negative': 0, 'ratio': 11.0}}

# %% [markdown]
# Notice the difference between the positive and negative ratios. Emojis like :( and words like 'me' tend to have a negative connotation. Other words like 'glad', 'community', and 'arrives' tend to be found in the positive tweets.

# %% [markdown]
# # Part 5: Error Analysis
#
# In this part you will see some tweets that your model missclassified. Why do you think the misclassifications happened? Were there any assumptions made by the naive bayes model?

# %%
# Some error analysis done for you
print('Truth Predicted Tweet')
for x, y in zip(test_x, test_y):
    y_hat = naive_bayes_predict(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        print('%d\t%0.2f\t%s' % (y, np.sign(y_hat) > 0, ' '.join(
            process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Truth Predicted Tweet
# 1	0.00	b'how can i list all deployed jax ws webservices java jax-ws servlets'
# 1	0.00	b'flash lite javascript javascript flash actionscript mp3 wii'
# 1	0.00	b'from html to servlet java servlets'
# 1	0.00	b'htaccess redirect all files in one folder to exact same in another folder .htaccess mod-rewrite url-rewriting'
# 1	0.00	b'android how to stop reading getview function again if the content is already downloaded in the listview android listview'
# 1	0.00	b'qt application simulating modal behaviour enabledisable user input c++ qt qt4'
# 1	0.00	b'sending an sms message with aspnet asp.net'
# 1	0.00	b'mvc model get and set vs straight up model var val php model-view-controller'
# 1	0.00	b'how to filter rows with null refrences in google app engine db google-app-engine google-cloud-datastore'
# 1	0.00	b'db cant connect from clients after restart db2'
# 1	0.00	b'mysql update select query mysql select combinations'
# 1	0.00	b'iis ftp extensibility iftplogprovider and logging ftp failures to the event log c# ftp event-log iis-7.5'
# 1	0.00	b'wp list categories does not show current category wordpress wp-list-categories'
# 1	0.00	b'reporting engine guidance pentaho jasperreports birt php mysql business-intelligence'
# 1	0.00	b'alternative to httpcontext when using ninject with a wcf service hosted in was using msmq binding wcf ninject was msmqbinding'
# 1	0.00	b'how to delete mysql database through shell command mysql database linux shell ubuntu'
# 1	0.00	b'why browsable attribute makes property not bindable c# .net winforms data-binding bindingsource'
# 1	0.00	b'problem with binding dependency property on a usercontrol wpf xaml binding dependency-properties'
# 1	0.00	b'jquerychange firing on page load javascript jquery'
# 1	0.00	b'dynamically expanding the width of a td html css html-table word-wrap'
# 1	0.00	b'silverlight making content size to page size silverlight telerik-scheduler'
# 1	0.00	b'has anyone got experience with riak with a large dataset dataset riak'
# 1	0.00	b'how to show iplmage format on the gui of c instead of showing it in another windows c++ opencv c++builder'
# 1	0.00	b'deleting specific values from an array in ksh arrays function ksh'
# 1	0.00	b'iphone how set uinavigationbar height iphone height uinavigationbar'
# 1	0.00	b'use javascript to intercept all document link clicks html internet-explorer firefox javascript-events'
# 1	0.00	b'how do i display appsettings in an aspnet mvc web application asp.net-mvc'
# 1	0.00	b'is cookie phpsessid the only key to for a session in php php session'
# 1	0.00	b'why is this linq expression not working c# asp.net linq linq-to-entities'
# 1	0.00	b'how to sendreceive sms using at commands python sms at-command'
# 1	0.00	b'having both mousedownmouseup and dblclick in jquery jquery events'
# 1	0.00	b'when should i use the addsubview method of a view controller iphone sdk view controller push'
# 1	0.00	b'sql server production db schema vs reporting db schema should they be the same sql-server reporting'
# 1	0.00	b'in android browser link does not always execute onclick causing focus instead android webkit focus onclick webview'
# 1	0.00	b'sql server transaction log is always too big sql-server-2005 transaction-log'
# 1	0.00	b'how to set the text of a back button on a uinavigationbar iphone xcode uinavigationcontroller uinavigationbar'
# 1	0.00	b'convert gd image back to binary data php image gd'
# 1	0.00	b'js to keep active state of menu in relation to iframe content javascript css'
# 1	0.00	b'deploying aspnet mvc app to multiple virtual directories issues with url references js files javascript asp.net-mvc html-helper urlhelper'
# 1	0.00	b'which is a better method for storing images folder or sql server as binary sql-server database-design image asp.net-3.5'
# 1	0.00	b'pushviewcontroller with tableviewcontroller in viewcontroller iphone uiviewcontroller uinavigationcontroller uitableview pushviewcontroller'
# 1	0.00	b'report is being generated runs forever in ie but works with firefox c# reportserver'
# 1	0.00	b'how to modify web page elements loaded in a browser javascript html events dynamic firefox-addon'
# 1	0.00	b'prevent exit fullscreen when esc is pressed in flex apache-flex events fullscreen projector'
# 1	0.00	b'tomcat webxml change web inflib directory classpath classloader tomcat5.5 jrubyonrails'
# 1	0.00	b'computing trending topics php mysql'
# 1	0.00	b'jquery with smarty and json jquery json smarty'
# 1	0.00	b'how can i change the ui language of qt creator qt-creator'
# 1	0.00	b'validation framework in net that can do edits between fields c# .net validation validationrules'
# 1	0.00	b'how to get the value of a multiple option dropdown javascript jquery'
# 1	0.00	b'webview crash with garbage collector on cocoa crash webview core-media'
# 1	0.00	b'passing parameters in redirection rails ruby-on-rails'
# 1	0.00	b'maven tomcat plugin with mysql driver in catalina homelib mysql tomcat maven-2 jar plugins'
# 1	0.00	b'jquery first child of this javascript jquery jquery-selectors css-selectors'
# 1	0.00	b'does zend acl suit my needs php zend-framework zend-auth zend-acl'
# 1	0.00	b'design time error while writing nested type in xaml c# wpf xaml user-controls nested'
# 1	0.00	b'vb gui interface to run vbs script user-interface vbscript batch-file'
# 1	0.00	b'loading presentmodalviewcontroller in viewdidappear causes exc bad access objective-c exc-bad-access'
# 1	0.00	b'propertiessettingssave only saves on first call c# .net datagridview persistence settings'
# 1	0.00	b'spgridview current item in sharepoint sharepoint'
# 1	0.00	b'simple insert works with phpmyadmin but not with php php mysql'
# 1	0.00	b'how to select a value in the same table as the value for an update for each row sql tsql'
# 1	0.00	b'jquery vs yui which one to choose jquery yui jquery-1.4 yui3'
# 1	0.00	b'drupal form validation not working for me php validation drupal drupal-6 drupal-fapi'
# 1	0.00	b'flash components with flex sdk apache-flex flash actionscript-3'
# 1	0.00	b'need advice to design crack proof software security'
# 1	0.00	b'php library with countries states and cities php open-source map'
# 1	0.00	b'visual studio web projects asp.net visual-studio visual-studio-2003'
# 1	0.00	b'force all item renderers to commitproperties apache-flex datagrid itemrenderer'
# 1	0.00	b'creating a view using subquerywith alias for columns in oracle i oracle oracle9i'
# 1	0.00	b'double of total problem sql sql-server sql-server-2005'
# 1	0.00	b'silverlight filestream silverlight filestream'
# 1	0.00	b'xml schema validation for large schema files xsd'
# 1	0.00	b'how to use nspredicate to catch child objects objective-c cocoa cocoa-touch core-data nspredicate'
# 1	0.00	b'jquery ui accordion resize on window resize jquery jquery-ui jquery-plugins accordion'
# 1	0.00	b'run php script continuously php'
# 1	0.00	b'sql server permission and encryption sql sql-server-2008 encryption database-permissions'
# 1	0.00	b'how to create docking panel in java java swing'
# 1	0.00	b'want to extend from javasqlresultset java jdbc'
# 1	0.00	b'post loading check if an image is in the browser cache javascript jquery caching lazy-loading'
# 1	0.00	b'jquery load not applying ready function javascript jquery ajax'
# 1	0.00	b'rails has many with dynamic conditions ruby-on-rails model'
# 1	0.00	b'valid json still fails on ie with jquerys ajax or getjson callbacks jquery ajax json'
# 1	0.00	b'how to set default value of hselectoneradio button jsf'
# 1	0.00	b'why are post variables getting escaped in php php ajax post escaping'
# 1	0.00	b'mvc same url multiple views model-view-controller'
# 1	0.00	b'can some tell me why i am seg faulting in this simple c program c malloc segmentation-fault'
# 1	0.00	b'classpath on mac and how does mac look for mysql connector java binjar java jdbc classpath'
# 1	0.00	b'background job with status in rails ruby-on-rails backgroundworker delayed-job'
# 1	0.00	b'how do i use ws addressing properly in an axis client java axis2 ws-addressing'
# 1	0.00	b'sql count in view as column sql sql-server sql-server-2005 view count'
# 1	0.00	b'how to get scrolltop of page just after page onload event javascript dom-events onload scrolltop onscroll'
# 1	0.00	b'jquery select text next to an input checkbox jquery jquery-selectors'
# 1	0.00	b'does telerik raddatepicker support hijri calendars c# calendar telerik'
# 1	0.00	b'c clickonce events c# clickonce'
# 1	0.00	b'facebook application how to check if inside facebook canvas standalone using php php facebook'
# 1	0.00	b'how to do basic authentication using firewatir on ubuntu linux watir firewatir'
# 1	0.00	b'trouble understanding the whole osgi web eco system tomcat osgi equinox apache-felix'
# 1	0.00	b'treeview control problem c# asp.net treeview controls'
# 1	0.00	b'sql select from data in query where this data is not already in the database sql mysql'
# 1	0.00	b'jquery ajax success function returns null javascript jquery ajax codeigniter'
# 1	0.00	b'linq select elements that only appear once in a list c# linq'
# 1	0.00	b'sql getting the id from a row based on a group by sql group-by'
# 1	0.00	b'passing data from a servlet to javascript code in an ajax application jquery ajax jsp servlets'
# 1	0.00	b'drawing raw buffer to cgbitmapcontext cocoa'
# 1	0.00	b'mprotect how aligning to multiple of pagesize works linux memory-management'
# 1	0.00	b'apache basic authentication before rewrite apache mod-rewrite basic-authentication'
# 1	0.00	b'blackberry how to send email with embedded image from application image email blackberry java-me'
# 1	0.00	b'iphone sdk loading on titanium developer iphone loading titanium appcelerator'
# 1	0.00	b'releasing winform program updates c# winforms windows-installer release'
# 1	0.00	b'dbdsqlitest execute failed datatype mismatch perl dbi type-mismatch'
# 1	0.00	b'background not showing behind floating divs css html'
# 1	0.00	b'unexpected t else error in php php if-statement syntax-error'
# 1	0.00	b'btstask to import policy biztalk policy biztalk-rule-engine'
# 1	0.00	b'ajax on rails ruby-on-rails ajax'
# 1	0.00	b'improving the performance of an nhibernate data access layer .net wcf performance nhibernate data-access-layer'
# 1	0.00	b'how can i pass latitude and longitude values from uiviewcontroller to mkmapview iphone objective-c uiviewcontroller mkmapview mkcoordinateregion'
# 1	0.00	b'detect ipad in php php ipad'
# 1	0.00	b'best way to list online users with php but without mysql php mysql flash'
# 1	0.00	b'limit records fetched in android sqlite database sql android sqlite pagination'
# 1	0.00	b'htaccess redirect from subdomain to root .htaccess'
# 1	0.00	b'problem accessing variable in a nested form partial ruby-on-rails forms partial-views nested-forms'
# 1	0.00	b'internet explore is unresponsive while loading a large page asp.net javascript jquery html internet-explorer'
# 1	0.00	b'receiving ajax http response code as ajax httpresponse'
# 1	0.00	b'weird array syntax php syntax arrays'
# 1	0.00	b'how to change browser focus from one tab to another javascript focus'
# 1	0.00	b'derbyjavadb vs sqlitejdbc java sqlite derby javadb sqlitejdbc'
# 1	0.00	b'showing login view controller before main tab bar controller iphone ipad uiviewcontroller uitabbarcontroller'
# 1	0.00	b'sql server database synchronization issues sql-server-2008'
# 1	0.00	b'hg serve simply hangs in terminal ubuntu mercurial'
# 1	0.00	b'bind width on ui element to width of another ui element wpf data-binding width'
# 1	0.00	b'netbeans add jarfolder folder added yet package does not exist netbeans classpath'
# 1	0.00	b'how to insert a uiimage into an e mail with html content html uiimage mfmailcomposeviewcontroller'
# 1	0.00	b'grab remaining text after last in a php string php string'
# 1	0.00	b'ipodmusicplayer doesnt send notifications if it is created in background iphone multithreading mpmusicplayercontroller'
# 1	0.00	b'how to quickly search an array of objects in objective c objective-c cocoa search'
# 1	0.00	b'uinavigationcontroller back button half works in ipad landscape orientation ipad uinavigationcontroller orientation'
# 1	0.00	b'nvp request createrecurringpaymentsprofile c# asp.net-mvc paypal'
# 1	0.00	b'the http verb post used to access path documentstestnotedocumentsaddnote is not allowed asp.net-mvc json'
# 1	0.00	b'why border of th and thead both not showing here css'
# 1	0.00	b'mtu mismatch between getifentry and netsh windows-vista netsh mtu iphelper'
# 1	0.00	b'not able to install gdb on fedora gdb'
# 1	0.00	b'how can i compile an iphone app with flash cs without a developer license iphone flash flash-cs5'
# 1	0.00	b'javascript event windowonload not triggered javascript onload onload-event'
# 1	0.00	b'do the htmlwindow returned from the htmlpagepopupwindow can invoke or eval javascript javascript html silverlight popupwindow'
# 1	0.00	b'sql query to return all rows that contain duplicate data from one field sql sql-server'
# 1	0.00	b'vehicle vehicle communication questions java c++ database gps wireless'
# 1	0.00	b'parse livescores from web site php screen-scraping'
# 1	0.00	b'prevent cookies from being sent on ajax request ajax jquery'
# 1	0.00	b'call a phone number and pass dtmf using ios ios iphone dtmf'
# 1	0.00	b'rotating cursor according to rotated textbox c# .net wpf cursor rotation'
# 1	0.00	b'fql facebook application php php facebook-fql'
# 1	0.00	b'php preg replace regexp php regex preg-replace'
# 1	0.00	b'border inset on background fill css css'
# 1	0.00	b'how can i transfer a file via xmpp using python python xmpp file-transfer'
# 1	0.00	b'visual studio has stopped working on win visual-studio visual-studio-2008 windows-7 compiler-errors'
# 1	0.00	b'windows message when mouse leave a control c++ c winapi'
# 1	0.00	b'html css cross browser semi transparency html css'
# 1	0.00	b'failed to obtain jdbc driver for mysql under tomcat environment java jsp tomcat jdbc'
# 1	0.00	b'using a join model to relate a model to itself ruby-on-rails activerecord'
# 1	0.00	b'iptables blocking memcached ubuntu memcached iptables'
# 1	0.00	b'firefox dynamically embedding svg element in svg javascript firefox svg'
# 1	0.00	b'execute a function when a link element has finished loading javascript jquery'
# 1	0.00	b'jquery ui draggable is not a function jquery draggable'
# 1	0.00	b'using named scope with counts of child models ruby-on-rails activerecord ruby-on-rails-2 named-scope'
# 1	0.00	b'c how can i make a listbox dropdown like a combobox does c# winforms'
# 1	0.00	b'box sizing support in ie css internet-explorer-7'
# 1	0.00	b'error installing feedzirra ruby-on-rails ruby rubygems feedparser feedzirra'
# 1	0.00	b'uiviewcontroller not oreintating methods not called uiviewcontroller screen-orientation'
# 1	0.00	b'c container allowing you to sort items by when they where last accessed c++'
# 1	0.00	b'accept method and new socket unix tcp'
# 1	0.00	b'get tweets of a public twitter profile java api twitter twitter4j'
# 1	0.00	b'how to enable flash plugin in webview android flash webview'
# 1	0.00	b'postgresql multiple insert with select query postgresql select insert'
# 1	0.00	b'howto update db row with save for prior to change state sql sql-server'
# 1	0.00	b'auto attach file in php mail php email'
# 1	0.00	b'mysql query blog posts and comments with limit php mysql greatest-n-per-group'
# 1	0.00	b'javascript get the current executing script node javascript dom'
# 1	0.00	b'concatenating text in an aspnet localized label asp.net localization'
# 1	0.00	b'where can an absolute beginner of kohana php go to learn how to use it from the ground up php kohana'
# 1	0.00	b'android sdk not recognizing debug able device android'
# 1	0.00	b'can two or more people edit an excel document at the same time excel sharepoint sharepoint-2010'
# 1	0.00	b'lite javascript gallery can i position the img absolutely in relationship to the lis javascript css image-gallery'
# 1	0.00	b'a custom auto sizing wpf panel class c# wpf custom-controls panel'
# 1	0.00	b'google gadgets and external scripts javascript external google-gadget'
# 1	0.00	b'django username in url instead of id django url friendly-url username'
# 1	0.00	b'monitoring dom changes in jquery jquery javascript-events'
# 1	0.00	b'sortable clone helper not working javascript jquery jquery-ui jquery-ui-sortable'
# 1	0.00	b'nested form habtm ruby-on-rails ruby has-and-belongs-to-many nested-forms'
# 1	0.00	b'suggestions for wysiwyg editor for web based data entry screens html forms user-interface'
# 1	0.00	b'sql server reporting services how to count rows that are not null any hints for calculating totals sql-server-2005 tsql reporting-services report grouping'
# 1	0.00	b'jsf problem java jsf jsf-2 primefaces'
# 1	0.00	b'how to display inline elements in list display django django-admin'
# 1	0.00	b'eventlet or gevent or stackless twisted pylons django and sql alchemy python gevent pypy eventlet python-stackless'
# 1	0.00	b'facebook invalid mark up on fbml fbml'
# 1	0.00	b'iphone uipicker default position iphone uipickerview'
# 1	0.00	b'how to select specific number of child entities instead of all in entity framework entity-framework linq-to-entities'
# 1	0.00	b'wpf drag cursor in default cursors wpf drag-and-drop cursor'
# 1	0.00	b'jquery generate valid tag of string jquery string replace'
# 1	0.00	b'getting the exit code from a process submitted with qsub on sun grid engine exit-code qsub single-threaded sungridengine'
# 1	0.00	b'is there new line constant in actionscript or flex apache-flex actionscript-3 actionscript flex4'
# 1	0.00	b'looking for dataset to test fulltext style searches on mysql database core-data dataset corpus'
# 1	0.00	b'can a table be copied to another table by an equal sign if not then how c# asp.net visual-studio-2008'
# 1	0.00	b'xquery to extract text in html xpath xquery'
# 1	0.00	b'assigning xml generated by a while loop to a variable php mysql xml'
# 1	0.00	b'static variables in iis hosted web applications asp.net iis multithreading static-variables'
# 1	0.00	b'handeling single uitextfield within uitableview objective-c iphone uitableview cocoa-touch uitextfield'
# 1	0.00	b'automatic email notifications based on date in django django email django-admin notifications'
# 1	0.00	b'jquery validation how do i create a custom error message element not just text jquery jquery-plugins jquery-validate'
# 1	0.00	b'drag n drop from uipopovercontroller to other uiview iphone ipad uiview uipopovercontroller uigesturerecognizer'
# 1	0.00	b'how to work with viewmodellocator in mvvm light silverlight mvvm mvvm-light'
# 1	0.00	b'how to hide div by onclick using javascript javascript onclick hide'
# 1	0.00	b'get url for the page being opened next in windowonunload event javascript html onunload window.onunload'
# 1	0.00	b'when converting a nsstring to a char using utfstring how to retain it iphone objective-c memory-management'
# 1	0.00	b'mysql replication best practices mysql replication'
# 1	0.00	b'exploding rootwar java perl tomcat'
# 1	0.00	b'can i assign the same file pointer a second file c file text file-io'
# 1	0.00	b'eliminate flash of unstyled content css fouc'
# 1	0.00	b'checking capslock status java windows gwt'
# 1	0.00	b'css fixed position with auto margin css'
# 1	0.00	b'how do i create pin wheellike daisy wheel in iphone animation ios4'
# 1	0.00	b'how to debug accessviolationexception coming from native code c# .net visual-studio visual-studio-2008 access-violation'
# 1	0.00	b'click button or execute javascript function with vba javascript vba excel'
# 1	0.00	b'processing a mutlidimensional html array in javascript javascript html multidimensional-array'
# 1	0.00	b'jquery and wcf service problem asp.net jquery ajax wcf'
# 1	0.00	b'jquery check to see if div is shown jquery css html'
# 1	0.00	b'how to determine which node was clicked silverlight treeview wpf silverlight'
# 1	0.00	b'nodejs wont return data to jquerygetjson jquery node.js getjson'
# 1	0.00	b'using stored procedures as the business logic layer sql-server stored-procedures'
# 1	0.00	b'setting server bindings of iis programmatically c# vb.net iis'
# 1	0.00	b'how to close android browser after redirecting to my app android'
# 1	0.00	b'zk how to create component and register databinding java data-binding zk'
# 1	0.00	b'can we execute a batch file bat using application domain c# .net'
# 1	0.00	b'migrating content from legacy blogging platform to wordpress sql database wordpress blogs'
# 1	0.00	b'php html parsing how can be taken charset value of webpage with simple html dom parser php parsing html-parsing simple-html-dom php-parser'
# 1	0.00	b'how to don incremental multi user updates with nhibernate nhibernate locking domain-driven-design multi-user'
# 1	0.00	b'cufonrefresh after aspnet ajax refresh asp.net asp.net-ajax callback cufon'
# 1	0.00	b'inhertiance of layout details on template standard values sitecore sitecore6'
# 1	0.00	b'jquery sliding notice on top of screen jquery-ui'
# 1	0.00	b'incoming call dynamically override default ringtone android ringtone'
# 1	0.00	b'how to provide your own locationprovider on android android'
# 1	0.00	b'extract frame from multi page tiff c c#'
# 1	0.00	b'get filename and path from uri from mediastore android uri absolute-path mediastore'
# 1	0.00	b'how to add a usercontrol to a window in blenddesigner wpf blend'
# 1	0.00	b'how to convert a symbol to html code c# symbols html-encode'
# 1	0.00	b'find record that has all associated records ruby-on-rails activerecord find has-and-belongs-to-many'
# 1	0.00	b'column not found unknown column category ids in field list php magento'
# 1	0.00	b'iphone how to set repeat dailyhourly local notification iphone ios4 local notifications repeat'
# 1	0.00	b'how to communicate between objects iphone cocoa-touch uikit ios4'
# 1	0.00	b'anybody uses wmi whats the future c# wmi'
# 1	0.00	b'sharing nsmanagedobjectcontext and other service classes between iphoneipad tabs ipad core-data uitabbarcontroller ios4 uitabbar'
# 1	0.00	b'some built in to pad a list in python python list list-manipulation'
# 1	0.00	b'include file mess c++ class header header-files'
# 1	0.00	b'is it possible to pin a dll in memory to prevent unloading c++ windows dll'
# 1	0.00	b'standard for loops in xml xml loops'
# 1	0.00	b'how to assign a rank number to an array when ties exist php'
# 1	0.00	b'delete records from a table recursively sql server .net sql sql-server'
# 1	0.00	b'how to compute a point on a line in cgal c++ computational-geometry cgal'
# 1	0.00	b'opening a file in the browser instead of downloading it c# .net reporting-services download ssrs-2008'
# 1	0.00	b'load image from memory buffer using atl cimage c++ winapi atl'
# 1	0.00	b'fixed headerscrollable table with variable width javascript css'
# 1	0.00	b'single file aspx and linq c# .net asp.net single-file'
# 1	0.00	b'dynamic shortcodes and functions in wordpress wordpress shortcode'
# 1	0.00	b'jquery variable nth child jquery jquery-selectors'
# 1	0.00	b'using xslt to change surrounding data based on an empty tag html xml xslt'
# 1	0.00	b'issues updating a mysql table using pythons mysqldb python sql mysql'
# 1	0.00	b'australian bank lookup via bsb using javascript javascript validation bank'
# 1	0.00	b'how to maintain data in an sqlite database on an iphone at a version update of the application iphone objective-c sqlite'
# 1	0.00	b'activating mouse event in visual object in wpf wpf'
# 1	0.00	b'checking inside of the div tag with innerhtml in javascript php html javascript ajax dom'
# 1	0.00	b'jquery click event javascript jquery ajax dom'
# 1	0.00	b'listening for javascript touch events but still allowing default scrolling behaviour javascript mobile touch'
# 1	0.00	b'web service with attachment failed on ways ssl connection java web-services ssl jax-ws'
# 1	0.00	b'django remove on delete cascade behaviour of django django'
# 1	0.00	b'cruisecontrolnet force build not working from cctray cruisecontrol.net cctray'
# 1	0.00	b'what mysql field should i use for a yesno checkbox value mysql html'
# 1	0.00	b'sharepoint integrate c application c# sharepoint'
# 1	0.00	b'how to get a before filter in mailer ruby-on-rails actionmailer mailer'
# 1	0.00	b'ie bottom in positionabsolute behaves like positionfixed css internet-explorer-8'
# 1	0.00	b'exchange web services create meeting request working example calendar exchange-server exchangewebservices'
# 1	0.00	b'a large paged gridview rollup and grand totals with sqldatasource c# asp.net sql-server gridview sqldatasource'
# 1	0.00	b'iphone store float in sqlite thru coredata iphone cocoa core-data floating-point'
# 1	0.00	b'open pdf from aspnet page asp.net'
# 1	0.00	b'how to cut a large sprite png into smaller uiimages iphone uiimage'
# 1	0.00	b'showing empty view when listview is empty android listview'
# 1	0.00	b'output domain computername and logged in username spreadsheet windows active-directory batch-file'
# 1	0.00	b'apply an affine transformation to view in interface builder iphone interface-builder transformation'
# 1	0.00	b'insert new item in array on any position in php php arrays insert'
# 1	0.00	b'cannot add constraint to datatable which is a child table in two nested relations c#-2.0'
# 1	0.00	b'detect malicious url destination web-services security url malware-detection'
# 1	0.00	b'custom design in iphone applications iphone'
# 1	0.00	b'login to google bookmarks service using cmd line curl curl'
# 1	0.00	b'why cant i view the contents of my wcf services wsdl wcf wsdl endpoint'
# 1	0.00	b'aspnet membership add custom column asp.net database asp.net-membership'
# 1	0.00	b'jquery ui datepicker back button jumps to jquery jquery-ui jquery-ui-datepicker'
# 1	0.00	b'jquery referencing a jquery object jquery jquery-ui'
# 1	0.00	b'how to get height of div in px dimension javascript jquery html css'
# 1	0.00	b'best way to replace file on server php .htaccess deployment'
# 1	0.00	b'execute php script before every php script php'
# 1	0.00	b'mysql stored procedures delete record logically or phisically depending on existing table references mysql sql stored-procedures'
# 1	0.00	b'form input from link php jquery input hyperlink'
# 1	0.00	b'magento admin panel gives when trying to enter cms pages magento'
# 1	0.00	b'how can i use automapper to map an object to an unknown destination type c# automapper'
# 1	0.00	b'how to redirect from a controller using a named url mapping grails grails-controller url-mapping'
# 1	0.00	b'cant create handler inside thread that has not called looperprepare android ui-thread android-toast'
# 1	0.00	b'can i use both devexpress and telerik on the same web page asp.net telerik devexpress'
# 1	0.00	b'get all html between two elements javascript jquery c#-3.0'
# 1	0.00	b'distinct with select sql'
# 1	0.00	b'how to parse and modify html file in java java html html-parsing'
# 1	0.00	b'correct way of processing user input strings in sql and php php sql mysql'
# 1	0.00	b'connect to non discoverable bluetooth device android java-me bluetooth'
# 1	0.00	b'subclassed nsmanagedobject does not call description when nslogd objective-c core-data'
# 1	0.00	b'sql query to show multiple entries and its count sql sql-server'
# 1	0.00	b'nspredicate problem with column name objective-c core-data'
# 1	0.00	b'c winform drawn image flashing c# winforms'
# 1	0.00	b'xcode declaring static methods in class iphone objective-c xcode ipad static-methods'
# 1	0.00	b'how to draw a nsview on a nsview cocoa nsview'
# 1	0.00	b'connecting to a socks proxy to do ftps in java java ftp apache-commons socks'
# 1	0.00	b'connect to sql server from mysql mysql linked-server'
# 1	0.00	b'qt creator how to write the ui c++ qt user-interface designer qt-creator'
# 1	0.00	b'correct way to use sizethatfits and sizetofit with uilabel iphone resize uilabel sizetofit'
# 1	0.00	b'how to display tooltip in xaml wpf xaml tooltip'
# 1	0.00	b'how do i read a get variable from javascriptjquery javascript jquery'
# 1	0.00	b'mysql optimize premature kill mysql'
# 1	0.00	b'mysql error code got error from storage engine ive tried to delete data from my database mysql database mysql-error-1030'
# 1	0.00	b'easy way to password protect php page php password-protection'
# 1	0.00	b'how do you control the minimum width of a table cell html css html-table'
# 1	0.00	b'in flex how do i adjust the font size to align a label to an icon apache-flex'
# 1	0.00	b'how to read the query string in php and html php html query-string'
# 1	0.00	b'can i access qt signalsslots of objects out of scope c++ qt scope signals-slots'
# 1	0.00	b'django display nested categories in admin multiple select django django-admin'
# 1	0.00	b'select query with date condition sql date ms-access'
# 1	0.00	b'mvc jquery datepicker to display events c# asp.net jquery asp.net-mvc-2 jquery-ui'
# 1	0.00	b'insert output ids into another table sql sql-server sql-server-2005 tsql'
# 1	0.00	b'need an automatic image tagging api any suggestions image-processing annotations tagging inference photo-tagging'
# 1	0.00	b'how to execute click after jquery animation completes jquery click slideup slidedown'
# 1	0.00	b'how to use datepickerdialog as a preference android'
# 1	0.00	b'html pre tag causes linebreaks html css newline line-breaks pre'
# 1	0.00	b'how to make a div always float on the screen in top right corner javascript css'
# 1	0.00	b'os x version of bringsubviewtofront objective-c cocoa macos'
# 1	0.00	b'proper way to prevent doctrine record from being deleted php doctrine record'
# 1	0.00	b'go to definition gedit plugin ctags gedit'
# 1	0.00	b'how to generate heatmap for a group of points in objective c iphone objective-c graphics'
# 1	0.00	b'use normal html button to call controller in aspnet mvc c# asp.net-mvc-2'
# 1	0.00	b'how to capture from a dvb t stick to an avi file c# streaming video-streaming capture audio-streaming'
# 1	0.00	b'mybatis how to return the id of the inserted object under postgres annotations ibatis mybatis'
# 1	0.00	b'ajax security post or get ajax post get'
# 1	0.00	b'select rows with checkbox in slickgrid select checkbox slickgrid'
# 1	0.00	b'jquery ui accordion how to remove style completly jquery jquery-ui accordion'
# 1	0.00	b'calling an instance method from another class objective-c'
# 1	0.00	b'why doesnt my app widget update in api or java android android-widget android-appwidget'
# 1	0.00	b'jquery any suggestions how to preload all images in dom sequentially jquery preload'
# 1	0.00	b'use spring form tags or not forms spring-mvc'
# 1	0.00	b'stop browsers asking to resend form data on refresh html firefox post'
# 1	0.00	b'how to link scrollbar and scrollviewer wpf scrollbar scrollviewer'
# 1	0.00	b'deploying mvc to iis or asp.net-mvc-2 iis iis-5'
# 1	0.00	b'parsing an email attachment w paperclip possible wo a tempfile ruby-on-rails ruby-on-rails-3 paperclip actionmailer'
# 1	0.00	b'jquery animate div to same position as another div jquery position jquery-animate offset'
# 1	0.00	b'can i install ssis designer without having an instance of sql server installed on my local machine sql-server-2008 ssis'
# 1	0.00	b'facebook error error validating verification code php facebook urlencode'
# 1	0.00	b'changing webconfig from command line asp.net iis web-config'
# 1	0.00	b'sql server profiler how to measure execution time of insert statement with trigger sql-server-2005 triggers insert sql-server-profiler'
# 1	0.00	b'how to restart android emulator and preserve system data android android-emulator'
# 1	0.00	b'java datagramsocket receive data multicast socket send data java sockets networking'
# 1	0.00	b'how can i obtain gps location in android webkit or opera mobile android gps opera opera-mobile'
# 1	0.00	b'how big is too big for a mysql table mysql size limit'
# 1	0.00	b'is it necessary to close zodb connections after only reading data zodb'
# 1	0.00	b'select single column from dataset with linq c# linq linq-to-dataset'
# 1	0.00	b'deploying sql ce to iis special permissions needed asp.net sql-server-ce'
# 1	0.00	b'speed of parsing json structures json database-design'
# 1	0.00	b'ms sql server row guid column sql-server sql-server-2008 guid'
# 1	0.00	b'jquery javascript variable scope javascript jquery ajax scope'
# 1	0.00	b'edit a read only view sqlite'
# 1	0.00	b'how to detect a link click with custom attributes with jquery jquery'
# 1	0.00	b'how to use ajax to show php in a modal pop up php html jquery'
# 1	0.00	b'get dimensions after setlayoutparams in android android layout view'
# 1	0.00	b'how to detect the same user in different iphones iphone web-services'
# 1	0.00	b'datatypecurrency attribute fails on sign asp.net-mvc'
# 1	0.00	b'can rails sweepers work across different controllers ruby-on-rails caching sweeper'
# 1	0.00	b'jquery ui sortable sorting images jquery jquery-ui'
# 1	0.00	b'django check users messages every request django'
# 1	0.00	b'displaying images in a list box keeps files locked c# wpf image listbox'
# 1	0.00	b'copy list items with automapper automapper'
# 1	0.00	b'getting hold of a reference to the object created by joptionpane static methods java swing joptionpane'
# 1	0.00	b'memory alignment attribute aligned c'
# 1	0.00	b'how do i select a sql server sql sql-server'
# 0	1.00	b'how to mimic vbs control array in python for wincom python win32com'
# 0	1.00	b'how to connect with microsoft localization center windows unicode windows-7 localization keyboard-layout'
# 0	1.00	b'sql server cast and rounding sql sql-server'
# 0	1.00	b'if there any better way to read bb function souce codei was very faint python'
# 0	1.00	b'opengl es coordinates opengl-es coordinates viewport'
# 0	1.00	b'iphone mthumb interlinking iphone gcc compilation arm'
# 0	1.00	b'how to print the return type of a function in visual studio c c++ visual-studio ide'
# 0	1.00	b'how can i smooth an array in r r spline'
# 0	1.00	b'is there any difference between sql server that comes with vs and sql server express sql-server sql-server-2008'
# 0	1.00	b'response time increasing worsening over time with consistent load ruby-on-rails heroku weborb'
# 0	1.00	b'how to get iunknown from wdm driver createinstance python com ctypes iunknown'
# 0	1.00	b'sort by date using acts as solr ruby-on-rails ruby search sorting solr'
# 0	1.00	b'how to write a efficient to get the difference from two table sql sql-server tsql sql-server-2008'
# 0	1.00	b'how do i get a list of recipients whose mailbox i have shared access to via outlook interop interop outlook'
# 0	1.00	b'uml relation between usecases extendinclude uml use-case'
# 0	1.00	b'problem with breadth first tree generation python tree breadth-first-search'
# 0	1.00	b'eclipse style help system swt eclipse swt'
# 0	1.00	b'how do i get a timestamp from an nsstring date iphone datetime nsstring timestamp'
# 0	1.00	b'wxpython gui migrating gnuplot to matplotlib python wxpython matplotlib'
# 0	1.00	b'force source insight to recognize a new macro macros source-insight'
# 0	1.00	b'recommended django setup python django apache'
# 0	1.00	b'how to restrict a software for only time use encoding drm'
# 0	1.00	b'how do i check for a bit z buffer using managed directd .net directx c++-cli direct3d managed-directx'
# 0	1.00	b'creating a tiled world with opengl opengl 3d textures tiles'
# 0	1.00	b'uiwebview to use customer font ttf fonts uiwebview true-type-fonts'
# 0	1.00	b'is there any way to specify delete permissions in svn svn permissions authorization'
# 0	1.00	b'uielement to png text slightly blurred silverlight png writeablebitmap uielement'
# 0	1.00	b'best programming language to periodically search a website parse it and mail results web-applications programming-languages'
# 0	1.00	b'jython and implementing httpservletcontextinitialized servlets jython'
# 0	1.00	b'what strategy should i use for multiple room booking selection without js user-interface accessibility javascript'
# 0	1.00	b'translate local quaternion rotation into global gyro c# math 3d quaternions euler-angles'
# 0	1.00	b'what is the basepage equivalent in mvc asp.net-mvc'
# 0	1.00	b'eclipse galileo proxy detection by url eclipse proxy galileo'
# 0	1.00	b'using rspec to test code prone to external infuence ruby-on-rails ruby tdd rspec'
# 0	1.00	b'alternative http port c++ browser chat'
# 0	1.00	b'how can i hide a window while keeping it on the taskbar and the alttab list windows delphi'
# 0	1.00	b'aspnet resourcing detect when resourceprovider is invoked at compile time vs run time asp.net compile-time'
# 0	1.00	b'secure google authentication c# authentication google-login'
# 0	1.00	b'migrating from vba excel migration ms-office excel-2003'
# 0	1.00	b'which conveniences does cedet bring to dynamic languages emacs dynamic-languages cedet'
# 0	1.00	b'qt pros transformed into nmake makefiles cant handle staticlibs same thing in vs solution works qt nmake'
# 0	1.00	b'emacs vimpulse errors emacs vimpulse'
# 0	1.00	b'documentation for liferay hooks liferay hook'
# 0	1.00	b'how to process input typefile nametestf in php php http file form-submit'
# 0	1.00	b'normalising book titles python python django string data-cleaning'
# 0	1.00	b'process incoming emails with script php ruby'
# 0	1.00	b'generate visual studio project templates with cruisecontrolnet or msbuild visual-studio templates msbuild cruisecontrol.net'
# 0	1.00	b'searching and replacing brackets in a string in oracle g oracle oracle10g replace'
# 0	1.00	b'fatalexecutionengineerror was detected .net'
# 0	1.00	b'controlling if exceptions are swallowed by a static boolean java exception-handling'
# 0	1.00	b'is there a clean way to determine rss version xml rss syndication'
# 0	1.00	b'unknown linking error linker ld linker-scripts'
# 0	1.00	b'linq statement as if condition c#'
# 0	1.00	b'shell script pattern matching regex shell ftp scripting'
# 0	1.00	b'ruby hpricot does not like dash in symbol is there a workaround ruby-on-rails ruby'
# 0	1.00	b'scanf with signals c++ unix signals scanf qnx'
# 0	1.00	b'import utility in oracle sql oracle oracle11g'
# 0	1.00	b'fxcop for silverlight code analysis net silverlight fxcop'
# 0	1.00	b'did anyone give these smart pointers auto any scoped any shared any a test drive c++ memory smart-pointers'
# 0	1.00	b'simple vector program error c++ vector instantiation'
# 0	1.00	b'ssis how to get the timestamp properties for a file sql-server-2005 ssis'
# 0	1.00	b'c stl vector iterator but got runtime error c++ stl vector iterator'
# 0	1.00	b'recommendations for compatibility between osgi platform releases java osgi'
# 0	1.00	b'java apache commons users java apache-commons'
# 0	1.00	b'libpcap packet size c linux gcc libpcap'
# 0	1.00	b'nullpointerexception when calling webservice in weblogic java web-services weblogic'
# 0	1.00	b'method not found error when inheriting abstract method in perl oop perl oop inheritance abstract'
# 0	1.00	b'mocha no longer can be loaded after installing will paginate pre ruby-on-rails ruby-on-rails-3 will-paginate mocha'
# 0	1.00	b'different levels in code igniter codeigniter'
# 0	1.00	b'what do you call functions which get and set oop accessor nomenclature mutators'
# 0	1.00	b'django complex filter parameters or django django-admin django-queryset'
# 0	1.00	b'how to build a sentence parser using only the c standared library c++ parsing'
# 0	1.00	b'ssrs vs create a scale break in a line chart charts graph line reportingservices-2005'
# 0	1.00	b'qt qstackedwidget solution qt memory memory-management'
# 0	1.00	b'how do you clear rootlayoutpanel in gwt gwt'
# 0	1.00	b'how to create network interface programmatically c#'
# 0	1.00	b'should receive in rspec ruby-on-rails class rspec message expectations'
# 0	1.00	b'the entity framework and database agnostic programming possibilities mysql sql-server oracle entity-framework database-agnostic'
# 0	1.00	b'oracle can we create global temp tables or any tables in stored proc oracle plsql toad ora-00955'
# 0	1.00	b'best java libraryies for forgiving command interpreter java parsing interpreter'
# 0	1.00	b'is it possible to use kitd in wpf if so how wpf silverlight 3d'
# 0	1.00	b'helper functions prototype methods to replace heavy frameworks javascript frameworks helpers prototype'
# 0	1.00	b'threaded application sleeps with other application pthreads'
# 0	1.00	b'ruby on rails truncate text can i use it for a combination of title and content ruby-on-rails truncate'
# 0	1.00	b'kdevelop has no build menu ubuntu kdevelop'
# 0	1.00	b'c file inputoutput c++ pointers file-io'
# 0	1.00	b'need a workaround to filter on related model and aggregated fields in django python sql django orm'
# 0	1.00	b'can i get a socket using schannel windows winapi ssl schannel'
# 0	1.00	b'c problem maybe with types c++'
# 0	1.00	b'httpwatch automation code doesnt work in ie c# testing automation httpwatch'
# 0	1.00	b'nhibernate createsqlquery data conversion from bit to boolean error c# mysql nhibernate'
# 0	1.00	b'is there a structured source of holland code riasec data available database'
# 0	1.00	b'template class ctor against function new c standard c++ templates function constructor'
# 0	1.00	b'java circular garbage collection java'
# 0	1.00	b'nsstring library anyone know of a helper library for nsstring iphone objective-c nsstring'
# 0	1.00	b'how would i convert decimal into binary c++ binary decimal'
# 0	1.00	b'c net application crashes immediately after starting c# .net deployment windows-installer version'
# 0	1.00	b'boost doesnt bind to member function even using this c++ boost boost-bind'
# 0	1.00	b'log user authentication in grailsacegi grails spring-security'
# 0	1.00	b'how to subtract dates in yyyymmdd format .net vb.net datetime date'
# 0	1.00	b'why entered key word is not store in database php mysql'
# 0	1.00	b'compiling a class using java code using process java compiler-construction'
# 0	1.00	b'is there a way to disconnect from facebook login without calling logout ios session facebook-ios-sdk logout'
# 0	1.00	b'pass a pointer of a class c++'
# 0	1.00	b'how is the setup of a program created c# installation'
# 0	1.00	b'how to putextra in searchable dictionary example java android'
# 0	1.00	b'repeated rake task using delayed job ruby-on-rails rake ruby-on-rails-plugins'
# 0	1.00	b'why might the large object heap grow rather than throw an exception c# .net memory-management fragmentation large-object-heap'
# 0	1.00	b'php time zone adjustment php timezone date'
# 0	1.00	b'http authentication with apache httpcomponents java authentication httpclient'
# 0	1.00	b'solrnetsolr logging need to log specific information on whether a document is added or updated logging solr solrnet'
# 0	1.00	b'what is the delimiter name of a c project file c# solution vcproj'
# 0	1.00	b'r bit for windows comparison r'
# 0	1.00	b'comsunmailhandlerstext plain cannot be cast to javaxactivationdatacontenthandler java coldfusion'
# 0	1.00	b'rand for c with variables c++ srand random'
# 0	1.00	b'c is there a problem with division c#'
# 0	1.00	b'how to omit extra bits in a file c++ mfc cstring'
# 0	1.00	b'how do i programmatically translate a linq query to readable english text that correctly describes the linq expression linq c#-3.0 predicatebuilder'
# 0	1.00	b'when processor endian awareness is required macos endianness'
# 0	1.00	b'void in main and keeping dos program from dying c++ void'
# 0	1.00	b'what is the base open source java package to filtermatch urls java url matching'
# 0	1.00	b'advantage and disadvantage of smarty template php templates smarty'
# 0	1.00	b'variables expired before aspnet membership provider automatically logout c# asp.net-membership'
# 0	1.00	b'sql express vs sql plus sql sql-server oracle'
# 0	1.00	b'multiple login locations for an online app php security web-applications authorization'
# 0	1.00	b'are there any modern gui toolkits which implement a heirarchical menu buffer zone user-interface menu usability'
# 0	1.00	b'imagemagick convert command equivalent for iphone iphone imagemagick'
# 0	1.00	b'basics of strings string'
# 0	1.00	b'bounding heritrix depth web-crawler'
# 0	1.00	b'a good repartition algorithm c++ algorithm memcached'
# 0	1.00	b'interface forwarding from member variable using c templates c++ templates'
# 0	1.00	b'problems running a bit delphi app on a bit windows platform delphi winapi printing compatibility win64'
# 0	1.00	b'how do i know if incrementdecrement on jspinner is pressed java jspinner'
# 0	1.00	b'database backup robocopy sql backup robocopy'
# 0	1.00	b'oracle utl nla array dbl does not exist sql oracle permissions packages'
# 0	1.00	b'ca warning from code analysis for oracleconnection disposal visual-studio-2010 code-analysis odp.net ca2202'
# 0	1.00	b'how do you decide what process to kill in sql server activity monitor sql database process maintenance activity-monitor'
# 0	1.00	b'jstl vs old school jsp el conflict jsp web-applications jstl'
# 0	1.00	b'using public amazon machine image c# amazon-ec2'
# 0	1.00	b'techniques to prevent overdraw opengl c++ c opengl'
# 0	1.00	b'what beans do you wire in a spring mvc app java spring spring-mvc inversion-of-control'
# 0	1.00	b'axis using threadsleep to do blocking java thread-safety axis2 sleep'
# 0	1.00	b'storing struct data to binary file python header-files binaryfiles'
# 0	1.00	b'how exactly should i implement a shuffle or random number algorithm for an array to display quotes in random order c++ random shuffle'
# 0	1.00	b'mouse directinput for osx macos mouse'
# 0	1.00	b'database modification or start over sql database'
# 0	1.00	b'does reversion work for django cms when page template is changed django django-cms reversion'
# 0	1.00	b'ruby rails gems question ruby-on-rails'
# 0	1.00	b'vb progress bar resetting maximum value winforms user-interface vb6 progress-bar'
# 0	1.00	b'actionscript pixel perfect collision how to learning purposes actionscript-3 bitmap rotation pixel collision'
# 0	1.00	b'return options as list from select box with python mechanizetwill python mechanize twill'
# 0	1.00	b'how to overcome android webview file size limit when loading a file android android-webview'
# 0	1.00	b'additional python installed upon installing matplotlib with macports python matplotlib macports'
# 0	1.00	b'garbage collection rate vs object allocation rate java garbage-collection'
# 0	1.00	b'why is this array selection causing such a glitchy phenomenon c++ arrays opengl'
# 0	1.00	b'matlab plot xy from loop matlab plot'
# 0	1.00	b'silverlight mediaelement double buffering silverlight buffer mediaelement'
# 0	1.00	b'how to hide html elements depending on what title they have with jquery javascript jquery'
# 0	1.00	b'block outgoing text android'
# 0	1.00	b'iterate forward and then reverse over stl container c++ stl'
# 0	1.00	b'using multiple temporary tables in delphi with an ado connection to the database produces errors sql sql-server delphi ado'
# 0	1.00	b'finger drag on motorola droid android touch'
# 0	1.00	b'variantclear throws an exception when called on a variant containing a safearray c++ visual-c++ memory-leaks msdn variant'
# 0	1.00	b'how to substitute broken images with javascript in a html document javascript error-handling replace'
# 0	1.00	b'problems with using trackpopupmenu on win winapi mfc contextmenu aero'
# 0	1.00	b'how can i rotatey an element without dipping underneath the page in d space javascript jquery css safari webkit'
# 0	1.00	b'ioc container hurdle for aspnet mvc newb asp.net-mvc dependency-injection inversion-of-control structuremap ninject'
# 0	1.00	b'what the error message afccreateresampler avafcinfo bused in samplerate outsamplerate mean android'
# 0	1.00	b'glbufferdata fails silently with overly large sizes c++ opengl nvidia'
# 0	1.00	b'how to make an instance of an unknown class to use as a parameter for a method invocation using reflection c# .net reflection'
# 0	1.00	b'how can i get html content from a browser that can do the html correction and js scripting java python browser'
# 0	1.00	b'pdf parsing for an ebook app uiwebview cgpdfdocument'
# 0	1.00	b'ruby on rails is it okay to use old school database access without migrations ruby-on-rails postgresql'
# 0	1.00	b'is there any api supported by android for recording phone call android'
# 0	1.00	b'recording video with ffmpeg gives the filename directory name or volume label syntax is incorrect python ffmpeg video-streaming'
# 0	1.00	b'is it worthwhile to learn objective c x before objective c x objective-c'
# 0	1.00	b'why would i use mockrunner over normalhand rolled dependency injection java dependency-injection mockrunner'
# 0	1.00	b'python data attributes in sqlalchemy model python sqlalchemy'
# 0	1.00	b'help write a one line memory managed objective c assignment macro iphone'
# 0	1.00	b'passing array from javascript to java servlet using jackson java javascript json servlets jackson'
# 0	1.00	b'technical code into the viewmodel in wpf wpf properties viewmodel dependencies code-behind'
# 0	1.00	b'strtok is using wrong delimiter c delimiter strtok'
# 0	1.00	b'convert hibernate persistable object to sql insert statement java hibernate log4j'
# 0	1.00	b'how to achieve a captionless bordered aero window c# .net window border aero'
# 0	1.00	b'error rendering reportviewer in localmode directly to pdf when passing in an empty recordset .net reportviewer'
# 0	1.00	b'ordering fulltext searches on relevance and other fields sql mysql full-text-search'
# 0	1.00	b'is systempos in delphi flawed delphi delphi-2009'
# 0	1.00	b'lucene usage on trec data indexing lucene'
# 0	1.00	b'template classes and the friend keyword in c specific example refers to boostmulti index c++ boost friend multi-index'
# 0	1.00	b'dear java why do most of the tutorials look as if they are leftovers of the s java concurrency'
# 0	1.00	b'fluent error invalid object name hibernate unique key fluent-nhibernate'
# 0	1.00	b'resizing catiledlayers using scale transforms vs bounds manipulation objective-c cocoa resize calayer catiledlayer'
# 0	1.00	b'how can i fix these errors in c c'
# 0	1.00	b'classifiers not working in maven snapshot repo for ivy maven-2 ivy'
# 0	1.00	b'sift implementation matlab matlab sift'
# 0	1.00	b'how to go about user interface design changes user-interface'
# 0	1.00	b'composite primary key verses one column based primary key database-design'
# 0	1.00	b'spring project segmentation best practices spring spring-security'
# 0	1.00	b'perl uri escape utf inconsistent behaviour or programmer error perl url escaping'
# 0	1.00	b'python shell and execfile scope python ipython execfile'
# 0	1.00	b'have you ever set a class for your css that uses it multiple times css'
# 0	1.00	b'what does this c string format mean c# string'
# 0	1.00	b'css properties of x syntax css css-selectors'
# 0	1.00	b'what is the command to access exchange management tools from c code in exchange c# .net asp.net powershell exchange-server'
# 0	1.00	b'random code affects unrelated code iphone objective-c++'
# 0	1.00	b'getting around the lack of isnumeric function in sql ce sql-server-ce'
# 0	1.00	b'is there any way to auto merge a tfs baseless merge tfs merge'
# 0	1.00	b'examples of android applications that use direct database access instead of content providers android database android-contentprovider'
# 0	1.00	b'sed awk script to correct illegal characters from xml ampersand xml sed awk bash'
# 0	1.00	b'splitting a word from a read file c++ file-io stringstream'
# 0	1.00	b'using cloned git repo instead of gem ruby ubuntu rubygems'
# 0	1.00	b'using jmx to read ejb manifest jar and ejb jarxml in ejb jar inside ear java weblogic ejb jmx'
# 0	1.00	b'clean prototype fork good idea javascript jquery prototype js.class'
# 0	1.00	b'goofy unicode problem m unicode encoding'
# 0	1.00	b'create ranked dict with list comprehension python list-comprehension'
# 0	1.00	b'itext generated pdf viewing in ie pdf internet-explorer-7 itext web.xml'
# 0	1.00	b'set minimum and exact length in bytes of column values in sql server sql-server'
# 0	1.00	b'can i store the alias info when i use sqlite sql sqlite alias'
# 0	1.00	b'gdkpixbuf memory leak in vala or something else memory gtk memory-leaks vala'
# 0	1.00	b'where to getextract relational data on administrative regions of the world web-services geolocation openstreetmap extraction'
# 0	1.00	b'rspec and rails problems while testing libraries in the lib directory ruby-on-rails specifications'
# 0	1.00	b'mysql client console broken for some utf encoded characters console character-encoding mysql'
# 0	1.00	b'how would one check a returned image link with soapui testing image testing soapui'
# 0	1.00	b'position of nowplayingitem in a playlistadding categories to mpmediaitem iphone categories mpmusicplayercontroller mpmediaitem'
# 0	1.00	b'how to convert c code to c c#'
# 0	1.00	b'what is bundle identifier for dreamweaver macos dreamweaver'
# 0	1.00	b'xcode has poor syntax checking for objective c properties objective-c xcode xcode3.2'
# 0	1.00	b'how to make it runanalyseget mean ruby'
# 0	1.00	b'preventing scale on bitmap created in execution time for imageview android android image bitmap imageview scale'
# 0	1.00	b'javascript bitwise operations javascript bit-manipulation bitwise-operators'
# 0	1.00	b'what is the smallest audio file format iphone blackberry audio file-format aac'
# 0	1.00	b'cannot find webbrowsernavigatetostring method c# .net winforms webbrowser-control'
# 0	1.00	b'requiredasset validation attribute c# attributes data-annotations'
# 0	1.00	b'enumerated type with arbitrary integer values c++ enums'
# 0	1.00	b'select data from solr server in java java apache solr'
# 0	1.00	b'hibernate executed queries and testing hibernate testing'
# 0	1.00	b'how to send serialized java objects via apache camel java messaging apache-camel'
# 0	1.00	b'whats the best way to manage dependencies with counterclockwiseeclipse eclipse jar clojure dependencies'
# 0	1.00	b'problem with a spring applicaiton finding class orgspringframeworkwebservletdispatcherservlet ide is eclipse jakarta-ee'
# 0	1.00	b'converting c printf formatting tofrom vb net string formatting .net c++ vb.net printing string-formatting'
# 0	1.00	b'what does class poco generics'
# 0	1.00	b'zend framework modules and reflection php zend-framework reflection namespaces'
# 0	1.00	b'stack overflow in multi threaded application c# stack-overflow stack overflow'
# 0	1.00	b'any free debug softwares that would allow me to peek into the workings of a compiled pyexe file python debugging executable'
# 0	1.00	b'coldfusion orm creates wrong data type orm coldfusion'
# 0	1.00	b'ssis issue when communicating with oracle t sql vs plsql oracle tsql datetime ssis plsql'
# 0	1.00	b'single technology stack vs multiple technologies for high scale site ruby-on-rails django architecture frameworks'
# 0	1.00	b'xxd binary dump problems c hexdump'
# 0	1.00	b'git workflow to fork a local repository git svn'
# 0	1.00	b'cocosd boxd rotation towards point rotation cocos2d-iphone box2d-iphone'
# 0	1.00	b'winforms c outlook like interface c#-4.0'
# 0	1.00	b'nlog not logging in simple app vb.net nlog'
# 0	1.00	b'how can i extract an array from a two dimensional array in perl arrays perl multidimensional-array'
# 0	1.00	b'stringindexoutofboundsexception while adding contacts to group in samsung galaxy s java android exception-handling'
# 0	1.00	b'php class variables with constants php class constants class-constants'
# 0	1.00	b'how to read in arguments passed via ant to testngxml xml ant shell sh'
# 0	1.00	b'java collection that allows objects with a custom annotation java collections annotations'
# 0	1.00	b'does it make sense to check variable before initalizie it php oop'
# 0	1.00	b'wait signal order c pthreads semaphore'
# 0	1.00	b'what is wrong with this functions recursion settimeout issue javascript jquery recursion timeout marquee'
# 0	1.00	b'copy constructor with reference variable c++'
# 0	1.00	b'getting an error in example vaadin java vaadin'
# 0	1.00	b'how to get div coordinates within html canvas html canvas'
# 0	1.00	b'benefits and drawbacks for caanimationgroup vs cakeyframeanimation iphone performance optimization core-animation caanimation'
# 0	1.00	b'insertion into cassandra via thrift client doesnt work after removing a row via cassandra cli cassandra thrift'
# 0	1.00	b'in the python version of google appengine mapreduce what is the most efficient way to validate that key references are valid google-app-engine'
# 0	1.00	b'pattern match numbersoperators java regex'
# 0	1.00	b'anyone have a large folder tree sample testing tree'
# 0	1.00	b'adding generic test cases to tfs in c c# tfs tfs-sdk generic-test'
# 0	1.00	b'full joinintersection in couchdb nosql couchdb set intersection'
# 0	1.00	b'lock source file in perforce while using maven release plugin hudson perforce maven-release-plugin'
# 0	1.00	b'where to instantiate interface in nunit test c# asp.net asp.net-mvc-2 nunit'
# 0	1.00	b'merging inner hashes in perl perl hash perl-data-structures'
# 0	1.00	b'text vs html emails email smtp html-email email-spam'
# 0	1.00	b'c liststring to lambda expression with starter example refactor to handle the list c# entity-framework-4 lambda'
# 0	1.00	b'need help in writing to a file java iostream'
# 0	1.00	b'set comparator type expected error c++ templates stl set'
# 0	1.00	b'removing keychain data on uninstall iphone objective-c cocoa-touch keychain'
# 0	1.00	b'abstraction hindering use of custom types what are the rules to follow in an implementation c# implementation base-class type-systems'
# 0	1.00	b'how to parse an arbitrary text file using only the mysql command line client mysql command-line'
# 0	1.00	b'lambda expression apply logical not to a boolean method call c# lambda'
# 0	1.00	b'update database in the middle of the transaction possible java hibernate jpa transactions'
# 0	1.00	b'calculating a tangent arc between two points on two circles computational-geometry geometry geometric-arc'
# 0	1.00	b'using css what is the most elegant way to vertical align a short title and a description not using a table css vertical-alignment'
# 0	1.00	b'sending an email with python using the smtp library python email smtp'
# 0	1.00	b'update grouping names delimited by ampersand in excel excel grouping delimiter names ampersand'
# 0	1.00	b'class with multiple return types c++'
# 0	1.00	b'debugging root application on linux with gdb debugging process gdb'
# 0	1.00	b'reading csv file in java start from line java csv arraylist'
# 0	1.00	b'multidimensional array with hyperlinked item php arrays multidimensional-array'
# 0	1.00	b'is this correct use of pattern matching and active patterns f#'
# 0	1.00	b'cygwin parse error before loff t in typesh c cygwin'
# 0	1.00	b'when boost thread is recycled temp variables created in it are erased from memory c++ multithreading data-structures boost'
# 0	1.00	b'edit and continue on visual studio express for windows phone visual-studio-2010 windows-phone-7'
# 0	1.00	b'hashm xor m hashm xor hash m is this true in case of sha hash cryptography'
# 0	1.00	b'messages without a matching method signature will be assume to return id iphone ipad'
# 0	1.00	b'why is nutch parsing applicationx javascript files plugins nutch'
# 0	1.00	b'loading animated images to start from the beginning of animation using jquery jquery animated-gif image-rotation'
# 0	1.00	b'split string adding extra string when no data is there asp.net vb.net string split'
# 0	1.00	b'is there a way to measure java servlet io traffic java http servlets servlet-filters'
# 0	1.00	b'image and audio feature extraction in java java feature-extraction'
# 0	1.00	b'android custom view bitmap size exceeds vm budget android out-of-memory'
# 0	1.00	b'first n positions of true values from a bit pattern c#'
# 0	1.00	b'django addition django django-templates'
# 0	1.00	b'what would the c code display c'
# 0	1.00	b'cglib compiler jdk compliance java spring jakarta-ee aop cglib'
# 0	1.00	b'lucene and solr lucene'
# 0	1.00	b'migration error in cassandra ruby-on-rails cassandra'
# 0	1.00	b'if a sum value returns null use currently have it casting to a nullable double c# linq group-by nullable sum'
# 0	1.00	b'ajax load in conjunction with getters and setters javascript jquery getter-setter'
# 0	1.00	b'cocosd sprite explosion cocos2d-iphone ip'
# 0	1.00	b'about java bytearrayoutputstream class java arrays image processing'
# 0	1.00	b'analog and digital graph java user-interface'
# 0	1.00	b'localized version of getfiletitle windows-7 file localization metadata'
# 0	1.00	b'documentwrite is stalling the rest of my javascript solutions javascript jquery optimization'
# 0	1.00	b'how to achieve this c++ puzzle'
# 0	1.00	b'enumerate all pixel formats with agl how mac os x macos opengl opentk pixelformat'
# 0	1.00	b'web template layout methodologies design-patterns templates web-frameworks'
# 0	1.00	b'installdir on silent installation properties wix silent'
# 0	1.00	b'how to auto press tab key when user press dash key in javascript javascript html'
# 0	1.00	b'coffeescript classes zeptojs javascript coffeescript'
# 0	1.00	b'multi column attribute rails ruby-on-rails'
# 0	1.00	b'aspnet entity framework guid asp.net entity-framework guid'
# 0	1.00	b'how often should i remind the user on rate the app iphone ios app-store review period'
# 0	1.00	b'graph api vs ios sdk in facebook app ios facebook facebook-graph-api facebook-ios-sdk'
# 0	1.00	b'saving pendingintents sql android arraylist android-pendingintent'
# 0	1.00	b'unexpected result while joining two datatables c# .net linq ado.net datatable'
# 0	1.00	b'testing embedded spaces in c c'
# 0	1.00	b'extending wcf datacontract just to use it in gui layer winforms wcf user-interface data-binding datacontract'
# 0	1.00	b'encrypting connection strings in appconfig for winforms app winforms encryption connection-string rsaprotectedconfiguration'
# 0	1.00	b'lucene features java lucene'
# 0	1.00	b'xna game studio and visual studio xna xna-4.0 xna-3.0'
# 0	1.00	b'error object reference not set to an instance of an object c# asp.net'
# 0	1.00	b'uilocalnotification and ios iphone audio notifications local alert'
# 0	1.00	b'problems with file io in c c file-io printf'
# 0	1.00	b'swapping bytes in a file in c file pointers'
# 0	1.00	b'wrapping callercallbacks in a single function asynchronous callback wrapper'
# 0	1.00	b'google app engine how to uniquely identify jvms instances measure parallelism java google-app-engine jvm'
# 0	1.00	b'find command with regex and exec regex help needed regex bash find'
# 0	1.00	b'php bug the if is not work php operators if-statement file-get-contents'
# 0	1.00	b'use name of data frame passed to function as plot title r ggplot2 dataframe'
# 0	1.00	b'javalangclasscastexception in weblogic after recompile java jakarta-ee weblogic-10.x weblogic11g weblogic9.x'
# 0	1.00	b'java web application httpservletrequest in an httpsessionlistener java servlets servlet-filters servlet-listeners'
# 0	1.00	b'what is the bug in this javascript code using raphaeljs javascript raphael'
# 0	1.00	b'how do i convert an elem with liftsurround to a liftresponse templates lift'
# 0	1.00	b'designing android app best practice android'
# 0	1.00	b'corporate espionage of website source code security repository code-access-security copy-protection'
# 0	1.00	b'parse a string with placeholders into an array with php php wildcard string-parsing'
# 0	1.00	b'is it bad to use special symbols in url url url-encoding'
# 0	1.00	b'jcs notify on expireremove java notify jcs'
# 0	1.00	b'is there any low effort way to embed a scripting language in a net application with intellisense support .net scripting automation intellisense scripting-language'
# 0	1.00	b'passing query parameters to query statement in mapserver php gis openlayers mapserver'
# 0	1.00	b'what does override and extends page mean java'
# 0	1.00	b'temporaries in member functions c c++'
# 0	1.00	b'javascript difference between conditions and ifelse javascript if-statement'
# 0	1.00	b'jaxb how to get sources annotated by generated by ant task jaxb xjc'
# 0	1.00	b'forcing to not to process an event c# winforms event-handling'
# 0	1.00	b'android notification bar showhide toggle android hide show android-notification-bar'

# %% [markdown]
# # Part 6: Predict with your own tweet
#
# In this part you can predict the sentiment of your own tweet.

# %%
# Test with your own tweet - feel free to modify `my_tweet`
my_tweet = 'I enjoy how my balls touch each other in the morning'

p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print(p)
# Out:
# -1.3663857951020875

# %% [markdown]
# Congratulations on completing this assignment. See you next week!
